# %%
# %pip install tensorflow seaborn


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.impute import KNNImputer
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_curve, auc

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# Out:
# Requirement already satisfied: tensorflow in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (2.10.1)
# Requirement already satisfied: seaborn in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (0.13.2)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (4.11.0)
# Requirement already satisfied: keras<2.11,>=2.10.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (3.19.6)
# Requirement already satisfied: setuptools in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (69.5.1)
# Requirement already satisfied: six>=1.12.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: numpy>=1.20 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (0.31.0)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: packaging in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (23.2)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (1.64.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (2.10.1)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from seaborn) (3.9.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: pillow>=8 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.3.0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (3.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (3.0.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.32.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.29.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.4.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (5.3.3)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (2.0.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2024.8.30)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (3.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (0.13.0)
# Requirement already satisfied: numpy<3,>=1.24.3 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from imbalanced-learn) (1.26.4)
# Requirement already satisfied: scikit-learn<2,>=1.3.2 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from imbalanced-learn) (1.5.0)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from imbalanced-learn) (0.1.3)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from imbalanced-learn) (3.5.0)
# Requirement already satisfied: joblib<2,>=1.1.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from imbalanced-learn) (1.4.2)
# Requirement already satisfied: scipy<2,>=1.10.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from imbalanced-learn) (1.13.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# load dataset

# %%
# Load Pima Indian Diabetes dataset
df = pd.read_csv("F:/RUSL/4- 1/ICT 4302 - Intelligent Systems/miniProject1/diabetes.csv")

df.columns = df.columns.str.strip()  # Clean header spaces
for col in df.columns:
    if col != 'Outcome':
        df[col] = pd.to_numeric(df[col], errors='coerce')  # Convert non-numeric to NaN

numeric_df = df.select_dtypes(include=['number'])

df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# Data preprocessing

# %% [markdown]
# step 1 - Replace invalid zeros with NaN (handle missing values)

# %%
cols_with_missing = ["Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI"]

# Replace 0 with np.nan only for these features
df[cols_with_missing] = df[cols_with_missing].replace(0, np.nan)

# %%
# Remove rows with too many missing values
def drop_rows_with_many_missing(df, threshold_cols=4):
    return df[df[cols_with_missing].isnull().sum(axis=1) < threshold_cols]

df = drop_rows_with_many_missing(df)

# %%
# Define columns for different strategies
median_columns = ["Glucose", "BloodPressure"]
knn_columns = ["SkinThickness", "Insulin", "BMI"]

# %% [markdown]
# step 2 - fill missing values using the median of the same class

# %%
# Apply same-class median imputation
def impute_same_class_median(df, columns, class_col="Outcome"):
    for col in columns:
        df[col] = df.groupby(class_col)[col].transform(lambda x: x.fillna(x.median()))
    return df

df = impute_same_class_median(df, median_columns)

# %%
# Apply KNN Imputer for selected columns
def knn_impute(df, columns, n_neighbors=5):
    imputer = KNNImputer(n_neighbors=n_neighbors)
    df[columns] = imputer.fit_transform(df[columns])
    return df

df = knn_impute(df, knn_columns)

# %%
# Normalize features (optional but recommended)
from sklearn.preprocessing import MinMaxScaler


features = df.columns[:-1]  # Exclude Outcome
scaler = MinMaxScaler()
df[features] = scaler.fit_transform(df[features])

# %%
print("✅ Cleaned dataset ready for model:")
display(df.head())
# Out:
# ✅ Cleaned dataset ready for model:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     0.352941  0.670968       0.489796       0.304348  0.213221  0.314928
# 1     0.058824  0.264516       0.428571       0.239130  0.128125  0.171779
# 2     0.470588  0.896774       0.408163       0.106522  0.106010  0.104294
# 3     0.058824  0.290323       0.428571       0.173913  0.096154  0.202454
# 4     0.000000  0.600000       0.163265       0.304348  0.185096  0.509202
#
#    DiabetesPedigreeFunction       Age  Outcome
# 0                  0.234415  0.483333        1
# 1                  0.116567  0.166667        0
# 2                  0.253629  0.183333        1
# 3                  0.038002  0.000000        0
# 4                  0.943638  0.200000        1

# %%
# Step 1: Split features and labels
X = df.drop("Outcome", axis=1)
y = df["Outcome"]

# Step 2: Apply SMOTE
from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state=42)
X_resampled, y_resampled = sm.fit_resample(X, y)

# %% [markdown]
# data split

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.1)

# %% [markdown]
# build custom keras model

# %%
model = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    layers.Dropout(0.2),
    layers.Dense(16, activation='relu'),
    layers.Dropout(0.1),
    layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='RMSprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])
#add extra hidden layer and change number of nodes in each layer

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 32)                288
#
#  dense_1 (Dense)             (None, 16)                528
#
#  dense_2 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 833
# Trainable params: 833
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Train the model

# %%
history = model.fit(X_train, y_train, epochs=80, batch_size=16, validation_split=0.2, verbose=2) #change validation split from 0.2-> 0.1
# Out:
# Epoch 1/80
# 45/45 - 2s - loss: 0.6812 - accuracy: 0.5134 - val_loss: 0.6708 - val_accuracy: 0.6011 - 2s/epoch - 34ms/step
# Epoch 2/80
# 45/45 - 0s - loss: 0.6628 - accuracy: 0.6062 - val_loss: 0.6527 - val_accuracy: 0.6798 - 151ms/epoch - 3ms/step
# Epoch 3/80
# 45/45 - 0s - loss: 0.6418 - accuracy: 0.6751 - val_loss: 0.6338 - val_accuracy: 0.7247 - 153ms/epoch - 3ms/step
# Epoch 4/80
# 45/45 - 0s - loss: 0.6199 - accuracy: 0.7440 - val_loss: 0.6133 - val_accuracy: 0.7528 - 250ms/epoch - 6ms/step
# Epoch 5/80
# 45/45 - 0s - loss: 0.5984 - accuracy: 0.7440 - val_loss: 0.5955 - val_accuracy: 0.7697 - 243ms/epoch - 5ms/step
# Epoch 6/80
# 45/45 - 0s - loss: 0.5788 - accuracy: 0.7609 - val_loss: 0.5805 - val_accuracy: 0.7697 - 207ms/epoch - 5ms/step
# Epoch 7/80
# 45/45 - 0s - loss: 0.5616 - accuracy: 0.7553 - val_loss: 0.5702 - val_accuracy: 0.7697 - 176ms/epoch - 4ms/step
# Epoch 8/80
# 45/45 - 0s - loss: 0.5467 - accuracy: 0.7567 - val_loss: 0.5564 - val_accuracy: 0.7753 - 163ms/epoch - 4ms/step
# Epoch 9/80
# 45/45 - 0s - loss: 0.5335 - accuracy: 0.7651 - val_loss: 0.5573 - val_accuracy: 0.7697 - 246ms/epoch - 5ms/step
# Epoch 10/80
# 45/45 - 0s - loss: 0.5193 - accuracy: 0.7595 - val_loss: 0.5383 - val_accuracy: 0.7135 - 176ms/epoch - 4ms/step
# Epoch 11/80
# 45/45 - 0s - loss: 0.5102 - accuracy: 0.7553 - val_loss: 0.5313 - val_accuracy: 0.7472 - 144ms/epoch - 3ms/step
# Epoch 12/80
# 45/45 - 0s - loss: 0.5044 - accuracy: 0.7595 - val_loss: 0.5252 - val_accuracy: 0.7247 - 141ms/epoch - 3ms/step
# Epoch 13/80
# 45/45 - 0s - loss: 0.4963 - accuracy: 0.7665 - val_loss: 0.5223 - val_accuracy: 0.7472 - 148ms/epoch - 3ms/step
# Epoch 14/80
# 45/45 - 0s - loss: 0.4906 - accuracy: 0.7651 - val_loss: 0.5375 - val_accuracy: 0.7809 - 123ms/epoch - 3ms/step
# Epoch 15/80
# 45/45 - 0s - loss: 0.4863 - accuracy: 0.7567 - val_loss: 0.5153 - val_accuracy: 0.7528 - 206ms/epoch - 5ms/step
# Epoch 16/80
# 45/45 - 0s - loss: 0.4852 - accuracy: 0.7609 - val_loss: 0.5129 - val_accuracy: 0.7472 - 241ms/epoch - 5ms/step
# Epoch 17/80
# 45/45 - 0s - loss: 0.4809 - accuracy: 0.7609 - val_loss: 0.5119 - val_accuracy: 0.7416 - 213ms/epoch - 5ms/step
# Epoch 18/80
# 45/45 - 0s - loss: 0.4804 - accuracy: 0.7539 - val_loss: 0.5111 - val_accuracy: 0.7416 - 151ms/epoch - 3ms/step
# Epoch 69/80
# 45/45 - 0s - loss: 0.4394 - accuracy: 0.7834 - val_loss: 0.5048 - val_accuracy: 0.7809 - 149ms/epoch - 3ms/step
# Epoch 70/80
# 45/45 - 0s - loss: 0.4380 - accuracy: 0.7947 - val_loss: 0.5021 - val_accuracy: 0.7753 - 131ms/epoch - 3ms/step
# Epoch 71/80
# 45/45 - 0s - loss: 0.4395 - accuracy: 0.7778 - val_loss: 0.5009 - val_accuracy: 0.7753 - 123ms/epoch - 3ms/step
# Epoch 72/80
# 45/45 - 0s - loss: 0.4384 - accuracy: 0.7932 - val_loss: 0.5009 - val_accuracy: 0.7528 - 162ms/epoch - 4ms/step
# Epoch 73/80
# 45/45 - 0s - loss: 0.4356 - accuracy: 0.7876 - val_loss: 0.5059 - val_accuracy: 0.7809 - 148ms/epoch - 3ms/step
# Epoch 74/80
# 45/45 - 0s - loss: 0.4381 - accuracy: 0.7876 - val_loss: 0.5007 - val_accuracy: 0.7528 - 136ms/epoch - 3ms/step
# Epoch 75/80
# 45/45 - 0s - loss: 0.4355 - accuracy: 0.7707 - val_loss: 0.5166 - val_accuracy: 0.7978 - 123ms/epoch - 3ms/step
# Epoch 76/80
# 45/45 - 0s - loss: 0.4362 - accuracy: 0.7764 - val_loss: 0.5101 - val_accuracy: 0.8034 - 118ms/epoch - 3ms/step
# Epoch 77/80
# 45/45 - 0s - loss: 0.4345 - accuracy: 0.7975 - val_loss: 0.5047 - val_accuracy: 0.7865 - 126ms/epoch - 3ms/step
# Epoch 78/80
# 45/45 - 0s - loss: 0.4351 - accuracy: 0.7848 - val_loss: 0.5062 - val_accuracy: 0.7865 - 141ms/epoch - 3ms/step
# Epoch 79/80
# 45/45 - 0s - loss: 0.4363 - accuracy: 0.7806 - val_loss: 0.5074 - val_accuracy: 0.7865 - 241ms/epoch - 5ms/step
# Epoch 80/80
# 45/45 - 0s - loss: 0.4350 - accuracy: 0.7834 - val_loss: 0.5024 - val_accuracy: 0.7584 - 135ms/epoch - 3ms/step

# %% [markdown]
# Evaluate the model

# %%
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, confusion_matrix, classification_report
)

# Predict probabilities
y_pred_prob = model.predict(X_test).ravel()

# Convert to binary output
y_pred = (y_pred_prob >= 0.5).astype(int)

# Classification report
print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))

# Confusion Matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# Predict probabilities and convert to binary
y_pred_prob = model.predict(X_test).ravel()
y_pred = (y_pred_prob >= 0.5).astype(int)

# Generate confusion matrix
cm = confusion_matrix(y_test, y_pred)
labels = ['No Diabetes', 'Diabetes']

# Plot
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)

plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.tight_layout()
plt.show()


# Individual metrics
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall:", recall_score(y_test, y_pred))
print("F1 Score:", f1_score(y_test, y_pred))
# Out:
# 4/4 [==============================] - 0s 2ms/step
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.75      0.71        48
#            1       0.73      0.65      0.69        51
#
#     accuracy                           0.70        99
#    macro avg       0.70      0.70      0.70        99
# weighted avg       0.70      0.70      0.70        99
#
# 4/4 [==============================] - 0s 3ms/step
# Accuracy: 0.696969696969697
# Precision: 0.7333333333333333
# Recall: 0.6470588235294118
# F1 Score: 0.6875

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot training & validation loss
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# Predict probabilities for the test set
y_pred_prob = model.predict(X_test).ravel()  # Already flattened

# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)

# Calculate AUC score
auc_score = roc_auc_score(y_test, y_pred_prob)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC Curve (AUC = {auc_score:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')  # Diagonal line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()
# Out:
# 4/4 [==============================] - 0s 2ms/step
