# %%
# %pip install tensorflow seaborn


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.impute import KNNImputer
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_curve, auc

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# Out:
# [notice] A new release of pip available: 22.2.2 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: tensorflow in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (2.10.1)
# Requirement already satisfied: seaborn in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (0.13.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (4.11.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (0.31.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: setuptools in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (69.5.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: packaging in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (23.2)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: keras<2.11,>=2.10.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (1.64.0)
# Requirement already satisfied: numpy>=1.20 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (3.19.6)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (2.10.1)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from seaborn) (3.9.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.0)
# Requirement already satisfied: pillow>=8 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.6.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.32.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (3.0.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.29.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (3.6)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.4.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (2.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2024.8.30)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2.2.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (3.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (0.13.0)
# Requirement already satisfied: joblib<2,>=1.1.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from imbalanced-learn) (1.4.2)
# Requirement already satisfied: scipy<2,>=1.10.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from imbalanced-learn) (1.13.1)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from imbalanced-learn) (3.5.0)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from imbalanced-learn) (0.1.3)
# Requirement already satisfied: numpy<3,>=1.24.3 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from imbalanced-learn) (1.26.4)
# Requirement already satisfied: scikit-learn<2,>=1.3.2 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from imbalanced-learn) (1.5.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# load dataset

# %%
# Load Pima Indian Diabetes dataset
df = pd.read_csv("F:/RUSL/4- 1/ICT 4302 - Intelligent Systems/miniProject1/diabetes.csv")

df.columns = df.columns.str.strip()  # Clean header spaces
for col in df.columns:
    if col != 'Outcome':
        df[col] = pd.to_numeric(df[col], errors='coerce')  # Convert non-numeric to NaN

numeric_df = df.select_dtypes(include=['number'])

df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# Data preprocessing

# %% [markdown]
# step 1 - Replace invalid zeros with NaN (handle missing values)

# %%
cols_with_missing = ["Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI"]

# Replace 0 with np.nan only for these features
df[cols_with_missing] = df[cols_with_missing].replace(0, np.nan)

# %%
# Remove rows with too many missing values
def drop_rows_with_many_missing(df, threshold_cols=4):
    return df[df[cols_with_missing].isnull().sum(axis=1) < threshold_cols]

df = drop_rows_with_many_missing(df)

# %%
# Define columns for different strategies
median_columns = ["Glucose", "BloodPressure"]
knn_columns = ["SkinThickness", "Insulin", "BMI"]

# %% [markdown]
# step 2 - fill missing values using the median of the same class

# %%
# Apply same-class median imputation
def impute_same_class_median(df, columns, class_col="Outcome"):
    for col in columns:
        df[col] = df.groupby(class_col)[col].transform(lambda x: x.fillna(x.median()))
    return df

df = impute_same_class_median(df, median_columns)

# %%
# Apply KNN Imputer for selected columns
def knn_impute(df, columns, n_neighbors=5):
    imputer = KNNImputer(n_neighbors=n_neighbors)
    df[columns] = imputer.fit_transform(df[columns])
    return df

df = knn_impute(df, knn_columns)

# %%
# Normalize features (optional but recommended)
from sklearn.preprocessing import MinMaxScaler


features = df.columns[:-1]  # Exclude Outcome
scaler = MinMaxScaler()
df[features] = scaler.fit_transform(df[features])

# %%
print("✅ Cleaned dataset ready for model:")
display(df.head())
# Out:
# ✅ Cleaned dataset ready for model:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     0.352941  0.670968       0.489796       0.304348  0.213221  0.314928
# 1     0.058824  0.264516       0.428571       0.239130  0.128125  0.171779
# 2     0.470588  0.896774       0.408163       0.106522  0.106010  0.104294
# 3     0.058824  0.290323       0.428571       0.173913  0.096154  0.202454
# 4     0.000000  0.600000       0.163265       0.304348  0.185096  0.509202
#
#    DiabetesPedigreeFunction       Age  Outcome
# 0                  0.234415  0.483333        1
# 1                  0.116567  0.166667        0
# 2                  0.253629  0.183333        1
# 3                  0.038002  0.000000        0
# 4                  0.943638  0.200000        1

# %%
# Step 1: Split features and labels
X = df.drop("Outcome", axis=1)
y = df["Outcome"]

# Step 2: Apply SMOTE
from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state=42)
X_resampled, y_resampled = sm.fit_resample(X, y)

# %% [markdown]
# data split

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.1)

# %% [markdown]
# build custom keras model

# %%
model = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    layers.Dropout(0.2),
    layers.Dense(16, activation='relu'),
    layers.Dropout(0.1),
    layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='RMSprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])
#add extra hidden layer and change number of nodes in each layer

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                576
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 16)                1040
#
#  dropout_1 (Dropout)         (None, 16)                0
#
#  dense_2 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 1,633
# Trainable params: 1,633
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Train the model

# %%
history = model.fit(X_train, y_train, epochs=100, batch_size=16, validation_split=0.2, verbose=2) #change validation split from 0.2-> 0.1
# Out:
# Epoch 1/100
# 45/45 - 6s - loss: 0.6798 - accuracy: 0.5401 - val_loss: 0.6712 - val_accuracy: 0.5787 - 6s/epoch - 135ms/step
# Epoch 2/100
# 45/45 - 1s - loss: 0.6613 - accuracy: 0.6568 - val_loss: 0.6575 - val_accuracy: 0.5899 - 949ms/epoch - 21ms/step
# Epoch 3/100
# 45/45 - 1s - loss: 0.6420 - accuracy: 0.6737 - val_loss: 0.6359 - val_accuracy: 0.6854 - 738ms/epoch - 16ms/step
# Epoch 4/100
# 45/45 - 1s - loss: 0.6186 - accuracy: 0.7243 - val_loss: 0.6170 - val_accuracy: 0.7022 - 655ms/epoch - 15ms/step
# Epoch 5/100
# 45/45 - 1s - loss: 0.5961 - accuracy: 0.7271 - val_loss: 0.5913 - val_accuracy: 0.7360 - 559ms/epoch - 12ms/step
# Epoch 6/100
# 45/45 - 1s - loss: 0.5778 - accuracy: 0.7328 - val_loss: 0.5678 - val_accuracy: 0.7472 - 532ms/epoch - 12ms/step
# Epoch 7/100
# 45/45 - 1s - loss: 0.5537 - accuracy: 0.7511 - val_loss: 0.5500 - val_accuracy: 0.7697 - 528ms/epoch - 12ms/step
# Epoch 8/100
# 45/45 - 0s - loss: 0.5341 - accuracy: 0.7567 - val_loss: 0.5369 - val_accuracy: 0.7809 - 448ms/epoch - 10ms/step
# Epoch 9/100
# 45/45 - 1s - loss: 0.5169 - accuracy: 0.7609 - val_loss: 0.5223 - val_accuracy: 0.7416 - 522ms/epoch - 12ms/step
# Epoch 10/100
# 45/45 - 1s - loss: 0.5032 - accuracy: 0.7539 - val_loss: 0.5241 - val_accuracy: 0.7753 - 539ms/epoch - 12ms/step
# Epoch 11/100
# 45/45 - 0s - loss: 0.4984 - accuracy: 0.7595 - val_loss: 0.5167 - val_accuracy: 0.7809 - 460ms/epoch - 10ms/step
# Epoch 12/100
# 45/45 - 0s - loss: 0.5018 - accuracy: 0.7679 - val_loss: 0.5096 - val_accuracy: 0.7697 - 409ms/epoch - 9ms/step
# Epoch 13/100
# 45/45 - 0s - loss: 0.4868 - accuracy: 0.7764 - val_loss: 0.5047 - val_accuracy: 0.7640 - 413ms/epoch - 9ms/step
# Epoch 14/100
# 45/45 - 1s - loss: 0.4758 - accuracy: 0.7567 - val_loss: 0.4981 - val_accuracy: 0.7472 - 532ms/epoch - 12ms/step
# Epoch 15/100
# 45/45 - 1s - loss: 0.4695 - accuracy: 0.7750 - val_loss: 0.5540 - val_accuracy: 0.7584 - 596ms/epoch - 13ms/step
# Epoch 16/100
# 45/45 - 0s - loss: 0.4719 - accuracy: 0.7820 - val_loss: 0.5162 - val_accuracy: 0.7697 - 484ms/epoch - 11ms/step
# Epoch 17/100
# 45/45 - 1s - loss: 0.4648 - accuracy: 0.7722 - val_loss: 0.5452 - val_accuracy: 0.7640 - 518ms/epoch - 12ms/step
# Epoch 18/100
# 45/45 - 1s - loss: 0.4875 - accuracy: 0.7651 - val_loss: 0.5137 - val_accuracy: 0.7640 - 639ms/epoch - 14ms/step
# Epoch 19/100
# 45/45 - 1s - loss: 0.4761 - accuracy: 0.7623 - val_loss: 0.5136 - val_accuracy: 0.7697 - 534ms/epoch - 12ms/step
# Epoch 20/100
# 45/45 - 0s - loss: 0.4677 - accuracy: 0.7876 - val_loss: 0.5285 - val_accuracy: 0.7697 - 469ms/epoch - 10ms/step
# Epoch 21/100
# 45/45 - 0s - loss: 0.4514 - accuracy: 0.7876 - val_loss: 0.4913 - val_accuracy: 0.7697 - 422ms/epoch - 9ms/step
# Epoch 22/100
# 45/45 - 0s - loss: 0.4506 - accuracy: 0.7848 - val_loss: 0.4889 - val_accuracy: 0.7753 - 500ms/epoch - 11ms/step
# Epoch 23/100
# 45/45 - 0s - loss: 0.4581 - accuracy: 0.7707 - val_loss: 0.5203 - val_accuracy: 0.7584 - 487ms/epoch - 11ms/step
# Epoch 24/100
# 45/45 - 0s - loss: 0.4591 - accuracy: 0.7679 - val_loss: 0.4853 - val_accuracy: 0.7753 - 452ms/epoch - 10ms/step
# Epoch 25/100
# 45/45 - 0s - loss: 0.4488 - accuracy: 0.7904 - val_loss: 0.4833 - val_accuracy: 0.7697 - 457ms/epoch - 10ms/step
# Epoch 26/100
# 45/45 - 0s - loss: 0.4546 - accuracy: 0.7764 - val_loss: 0.5015 - val_accuracy: 0.7528 - 426ms/epoch - 9ms/step
# Epoch 27/100
# 45/45 - 0s - loss: 0.4493 - accuracy: 0.7848 - val_loss: 0.5241 - val_accuracy: 0.7697 - 489ms/epoch - 11ms/step
# Epoch 28/100
# 45/45 - 0s - loss: 0.4530 - accuracy: 0.7806 - val_loss: 0.4831 - val_accuracy: 0.7753 - 451ms/epoch - 10ms/step
# Epoch 29/100
# 45/45 - 0s - loss: 0.4492 - accuracy: 0.7848 - val_loss: 0.5142 - val_accuracy: 0.7640 - 405ms/epoch - 9ms/step
# Epoch 30/100
# 45/45 - 0s - loss: 0.4513 - accuracy: 0.7961 - val_loss: 0.4729 - val_accuracy: 0.7753 - 464ms/epoch - 10ms/step
# Epoch 31/100
# 45/45 - 1s - loss: 0.4533 - accuracy: 0.7778 - val_loss: 0.4908 - val_accuracy: 0.7640 - 618ms/epoch - 14ms/step
# Epoch 32/100
# 45/45 - 1s - loss: 0.4402 - accuracy: 0.7820 - val_loss: 0.4703 - val_accuracy: 0.7865 - 576ms/epoch - 13ms/step
# Epoch 33/100
# 45/45 - 0s - loss: 0.4431 - accuracy: 0.7876 - val_loss: 0.5030 - val_accuracy: 0.7697 - 476ms/epoch - 11ms/step
# Epoch 34/100
# 45/45 - 1s - loss: 0.4380 - accuracy: 0.8031 - val_loss: 0.4821 - val_accuracy: 0.7697 - 566ms/epoch - 13ms/step
# Epoch 35/100
# 45/45 - 1s - loss: 0.4394 - accuracy: 0.8017 - val_loss: 0.4972 - val_accuracy: 0.7753 - 658ms/epoch - 15ms/step
# Epoch 36/100
# 45/45 - 1s - loss: 0.4387 - accuracy: 0.7961 - val_loss: 0.4793 - val_accuracy: 0.7753 - 715ms/epoch - 16ms/step
# Epoch 37/100
# 45/45 - 1s - loss: 0.4348 - accuracy: 0.8073 - val_loss: 0.4847 - val_accuracy: 0.7753 - 531ms/epoch - 12ms/step
# Epoch 38/100
# 45/45 - 1s - loss: 0.4449 - accuracy: 0.7932 - val_loss: 0.4789 - val_accuracy: 0.7809 - 934ms/epoch - 21ms/step
# Epoch 39/100
# 45/45 - 1s - loss: 0.4425 - accuracy: 0.7932 - val_loss: 0.4873 - val_accuracy: 0.7753 - 542ms/epoch - 12ms/step
# Epoch 40/100
# 45/45 - 1s - loss: 0.4340 - accuracy: 0.7989 - val_loss: 0.4987 - val_accuracy: 0.7753 - 503ms/epoch - 11ms/step
# Epoch 41/100
# 45/45 - 1s - loss: 0.4438 - accuracy: 0.7932 - val_loss: 0.4853 - val_accuracy: 0.7697 - 575ms/epoch - 13ms/step
# Epoch 42/100
# 45/45 - 1s - loss: 0.4245 - accuracy: 0.8003 - val_loss: 0.4672 - val_accuracy: 0.7921 - 522ms/epoch - 12ms/step
# Epoch 43/100
# 45/45 - 2s - loss: 0.4433 - accuracy: 0.7975 - val_loss: 0.4690 - val_accuracy: 0.7809 - 2s/epoch - 45ms/step
# Epoch 44/100
# 45/45 - 3s - loss: 0.4301 - accuracy: 0.8017 - val_loss: 0.4806 - val_accuracy: 0.7809 - 3s/epoch - 56ms/step
# Epoch 45/100
# 45/45 - 2s - loss: 0.4317 - accuracy: 0.8017 - val_loss: 0.4574 - val_accuracy: 0.7640 - 2s/epoch - 42ms/step
# Epoch 46/100
# 45/45 - 2s - loss: 0.4229 - accuracy: 0.8101 - val_loss: 0.4663 - val_accuracy: 0.7865 - 2s/epoch - 38ms/step
# Epoch 47/100
# 45/45 - 2s - loss: 0.4342 - accuracy: 0.7932 - val_loss: 0.4651 - val_accuracy: 0.7921 - 2s/epoch - 38ms/step
# Epoch 48/100
# 45/45 - 2s - loss: 0.4226 - accuracy: 0.8045 - val_loss: 0.4765 - val_accuracy: 0.7809 - 2s/epoch - 44ms/step
# Epoch 49/100
# 45/45 - 1s - loss: 0.4280 - accuracy: 0.8003 - val_loss: 0.4709 - val_accuracy: 0.7809 - 1s/epoch - 28ms/step
# Epoch 50/100
# 45/45 - 2s - loss: 0.4268 - accuracy: 0.7932 - val_loss: 0.4617 - val_accuracy: 0.7978 - 2s/epoch - 39ms/step
# Epoch 51/100
# 45/45 - 1s - loss: 0.4280 - accuracy: 0.8087 - val_loss: 0.4648 - val_accuracy: 0.7978 - 1s/epoch - 23ms/step
# Epoch 52/100
# 45/45 - 1s - loss: 0.4121 - accuracy: 0.8101 - val_loss: 0.4614 - val_accuracy: 0.8034 - 1s/epoch - 30ms/step
# Epoch 53/100
# 45/45 - 1s - loss: 0.4216 - accuracy: 0.8158 - val_loss: 0.4645 - val_accuracy: 0.7865 - 1s/epoch - 32ms/step
# Epoch 54/100
# 45/45 - 1s - loss: 0.4225 - accuracy: 0.8143 - val_loss: 0.4731 - val_accuracy: 0.7865 - 1s/epoch - 29ms/step
# Epoch 55/100
# 45/45 - 1s - loss: 0.4201 - accuracy: 0.8031 - val_loss: 0.5038 - val_accuracy: 0.7528 - 1s/epoch - 26ms/step
# Epoch 56/100
# 45/45 - 2s - loss: 0.4048 - accuracy: 0.8200 - val_loss: 0.4586 - val_accuracy: 0.7809 - 2s/epoch - 47ms/step
# Epoch 57/100
# 45/45 - 3s - loss: 0.4102 - accuracy: 0.8158 - val_loss: 0.4727 - val_accuracy: 0.7865 - 3s/epoch - 61ms/step
# Epoch 58/100
# 45/45 - 2s - loss: 0.4347 - accuracy: 0.8059 - val_loss: 0.5151 - val_accuracy: 0.7640 - 2s/epoch - 36ms/step
# Epoch 59/100
# 45/45 - 1s - loss: 0.4141 - accuracy: 0.8186 - val_loss: 0.4798 - val_accuracy: 0.7865 - 1s/epoch - 29ms/step
# Epoch 60/100
# 45/45 - 1s - loss: 0.4326 - accuracy: 0.8003 - val_loss: 0.4787 - val_accuracy: 0.7753 - 1s/epoch - 27ms/step
# Epoch 61/100
# 45/45 - 2s - loss: 0.4129 - accuracy: 0.8101 - val_loss: 0.4729 - val_accuracy: 0.7809 - 2s/epoch - 44ms/step
# Epoch 62/100
# 45/45 - 2s - loss: 0.4149 - accuracy: 0.8073 - val_loss: 0.4708 - val_accuracy: 0.7865 - 2s/epoch - 39ms/step
# Epoch 63/100
# 45/45 - 1s - loss: 0.4208 - accuracy: 0.8087 - val_loss: 0.4611 - val_accuracy: 0.8034 - 1s/epoch - 31ms/step
# Epoch 64/100
# 45/45 - 1s - loss: 0.4198 - accuracy: 0.7989 - val_loss: 0.4974 - val_accuracy: 0.7528 - 1s/epoch - 29ms/step
# Epoch 65/100
# 45/45 - 1s - loss: 0.4119 - accuracy: 0.8087 - val_loss: 0.4658 - val_accuracy: 0.8034 - 1s/epoch - 32ms/step
# Epoch 66/100
# 45/45 - 1s - loss: 0.4116 - accuracy: 0.8200 - val_loss: 0.4718 - val_accuracy: 0.7921 - 1s/epoch - 32ms/step
# Epoch 67/100
# 45/45 - 2s - loss: 0.4048 - accuracy: 0.8242 - val_loss: 0.4696 - val_accuracy: 0.7921 - 2s/epoch - 36ms/step
# Epoch 68/100
# 45/45 - 1s - loss: 0.4106 - accuracy: 0.8017 - val_loss: 0.4617 - val_accuracy: 0.8034 - 1s/epoch - 33ms/step
# Epoch 69/100
# 45/45 - 2s - loss: 0.4046 - accuracy: 0.8256 - val_loss: 0.4634 - val_accuracy: 0.8034 - 2s/epoch - 37ms/step
# Epoch 70/100
# 45/45 - 2s - loss: 0.4219 - accuracy: 0.8045 - val_loss: 0.4818 - val_accuracy: 0.7697 - 2s/epoch - 50ms/step
# Epoch 71/100
# 45/45 - 3s - loss: 0.4006 - accuracy: 0.8143 - val_loss: 0.4736 - val_accuracy: 0.7865 - 3s/epoch - 60ms/step
# Epoch 72/100
# 45/45 - 2s - loss: 0.4011 - accuracy: 0.8200 - val_loss: 0.4838 - val_accuracy: 0.7697 - 2s/epoch - 44ms/step
# Epoch 73/100
# 45/45 - 2s - loss: 0.3957 - accuracy: 0.8228 - val_loss: 0.4784 - val_accuracy: 0.7809 - 2s/epoch - 54ms/step
# Epoch 74/100
# 45/45 - 5s - loss: 0.4096 - accuracy: 0.8158 - val_loss: 0.4728 - val_accuracy: 0.7978 - 5s/epoch - 102ms/step
# Epoch 75/100
# 45/45 - 2s - loss: 0.4069 - accuracy: 0.8186 - val_loss: 0.4576 - val_accuracy: 0.8034 - 2s/epoch - 54ms/step
# Epoch 76/100
# 45/45 - 2s - loss: 0.4054 - accuracy: 0.8087 - val_loss: 0.4610 - val_accuracy: 0.8034 - 2s/epoch - 49ms/step
# Epoch 77/100
# 45/45 - 2s - loss: 0.3992 - accuracy: 0.8129 - val_loss: 0.4616 - val_accuracy: 0.8090 - 2s/epoch - 50ms/step
# Epoch 78/100
# 45/45 - 3s - loss: 0.4119 - accuracy: 0.8045 - val_loss: 0.4664 - val_accuracy: 0.8034 - 3s/epoch - 63ms/step
# Epoch 79/100
# 45/45 - 2s - loss: 0.3960 - accuracy: 0.8200 - val_loss: 0.4603 - val_accuracy: 0.8090 - 2s/epoch - 40ms/step
# Epoch 80/100
# 45/45 - 2s - loss: 0.4036 - accuracy: 0.8172 - val_loss: 0.4659 - val_accuracy: 0.7978 - 2s/epoch - 35ms/step
# Epoch 81/100
# 45/45 - 1s - loss: 0.3987 - accuracy: 0.8045 - val_loss: 0.4799 - val_accuracy: 0.7921 - 1s/epoch - 33ms/step
# Epoch 82/100
# 45/45 - 2s - loss: 0.3913 - accuracy: 0.8186 - val_loss: 0.4620 - val_accuracy: 0.8090 - 2s/epoch - 46ms/step
# Epoch 83/100
# 45/45 - 2s - loss: 0.3996 - accuracy: 0.8158 - val_loss: 0.4760 - val_accuracy: 0.7865 - 2s/epoch - 53ms/step
# Epoch 84/100
# 45/45 - 2s - loss: 0.4008 - accuracy: 0.8158 - val_loss: 0.4670 - val_accuracy: 0.8034 - 2s/epoch - 44ms/step
# Epoch 85/100
# 45/45 - 2s - loss: 0.3886 - accuracy: 0.8186 - val_loss: 0.4578 - val_accuracy: 0.8090 - 2s/epoch - 49ms/step
# Epoch 86/100
# 45/45 - 2s - loss: 0.3990 - accuracy: 0.8158 - val_loss: 0.4631 - val_accuracy: 0.7978 - 2s/epoch - 36ms/step
# Epoch 87/100
# 45/45 - 2s - loss: 0.3970 - accuracy: 0.8312 - val_loss: 0.4544 - val_accuracy: 0.8202 - 2s/epoch - 42ms/step
# Epoch 88/100
# 45/45 - 2s - loss: 0.3856 - accuracy: 0.8312 - val_loss: 0.4845 - val_accuracy: 0.7809 - 2s/epoch - 45ms/step
# Epoch 89/100
# 45/45 - 2s - loss: 0.3843 - accuracy: 0.8270 - val_loss: 0.4736 - val_accuracy: 0.7865 - 2s/epoch - 49ms/step
# Epoch 90/100
# 45/45 - 2s - loss: 0.3986 - accuracy: 0.8298 - val_loss: 0.4857 - val_accuracy: 0.7809 - 2s/epoch - 49ms/step
# Epoch 91/100
# 45/45 - 3s - loss: 0.3859 - accuracy: 0.8284 - val_loss: 0.4766 - val_accuracy: 0.7809 - 3s/epoch - 57ms/step
# Epoch 92/100
# 45/45 - 2s - loss: 0.4003 - accuracy: 0.8200 - val_loss: 0.4727 - val_accuracy: 0.7978 - 2s/epoch - 52ms/step
# Epoch 93/100
# 45/45 - 2s - loss: 0.3963 - accuracy: 0.8242 - val_loss: 0.4619 - val_accuracy: 0.8146 - 2s/epoch - 53ms/step
# Epoch 94/100
# 45/45 - 3s - loss: 0.4022 - accuracy: 0.8298 - val_loss: 0.4769 - val_accuracy: 0.7865 - 3s/epoch - 72ms/step
# Epoch 95/100
# 45/45 - 3s - loss: 0.3897 - accuracy: 0.8200 - val_loss: 0.4759 - val_accuracy: 0.7921 - 3s/epoch - 71ms/step
# Epoch 96/100
# 45/45 - 3s - loss: 0.3975 - accuracy: 0.8256 - val_loss: 0.4675 - val_accuracy: 0.8090 - 3s/epoch - 58ms/step
# Epoch 97/100
# 45/45 - 3s - loss: 0.3936 - accuracy: 0.8115 - val_loss: 0.4757 - val_accuracy: 0.7921 - 3s/epoch - 76ms/step
# Epoch 98/100
# 45/45 - 2s - loss: 0.3916 - accuracy: 0.8242 - val_loss: 0.4842 - val_accuracy: 0.7753 - 2s/epoch - 42ms/step
# Epoch 99/100
# 45/45 - 2s - loss: 0.3882 - accuracy: 0.8270 - val_loss: 0.4649 - val_accuracy: 0.8146 - 2s/epoch - 41ms/step
# Epoch 100/100
# 45/45 - 2s - loss: 0.3964 - accuracy: 0.8214 - val_loss: 0.4656 - val_accuracy: 0.8146 - 2s/epoch - 35ms/step

# %% [markdown]
# Evaluate the model

# %%
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, confusion_matrix, classification_report
)

# Predict probabilities
y_pred_prob = model.predict(X_test).ravel()

# Convert to binary output
y_pred = (y_pred_prob >= 0.5).astype(int)

# Classification report
print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))

# Confusion Matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# Predict probabilities and convert to binary
y_pred_prob = model.predict(X_test).ravel()
y_pred = (y_pred_prob >= 0.5).astype(int)

# Generate confusion matrix
cm = confusion_matrix(y_test, y_pred)
labels = ['No Diabetes', 'Diabetes']

# Plot
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)

plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.tight_layout()
plt.show()


# Individual metrics
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall:", recall_score(y_test, y_pred))
print("F1 Score:", f1_score(y_test, y_pred))
# Out:
# 4/4 [==============================] - 5s 22ms/step
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.63      0.73        59
#            1       0.61      0.88      0.72        40
#
#     accuracy                           0.73        99
#    macro avg       0.75      0.75      0.73        99
# weighted avg       0.77      0.73      0.73        99
#
# 4/4 [==============================] - 0s 13ms/step
# Accuracy: 0.7272727272727273
# Precision: 0.6140350877192983
# Recall: 0.875
# F1 Score: 0.7216494845360825

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot training & validation loss
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# Predict probabilities for the test set
y_pred_prob = model.predict(X_test).ravel()  # Already flattened

# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)

# Calculate AUC score
auc_score = roc_auc_score(y_test, y_pred_prob)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC Curve (AUC = {auc_score:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')  # Diagonal line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()
# Out:
# 4/4 [==============================] - 0s 20ms/step
