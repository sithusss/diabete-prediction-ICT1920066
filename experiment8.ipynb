# %%
# %pip install tensorflow seaborn

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.impute import KNNImputer
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_curve, auc, classification_report

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# Out:
# Requirement already satisfied: tensorflow in c:\users\ww\anaconda3\envs\iis\lib\site-packages (2.11.0)
# Requirement already satisfied: seaborn in c:\users\ww\anaconda3\envs\iis\lib\site-packages (0.12.2)
# Requirement already satisfied: tensorflow-intel==2.11.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.8.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (18.1.1)
# Requirement already satisfied: numpy>=1.20 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.21.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (24.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.19.6)
# Requirement already satisfied: setuptools in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (65.6.3)
# Requirement already satisfied: six>=1.12.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (4.7.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.62.2)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.2)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.31.0)
# Requirement already satisfied: pandas>=0.25 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from seaborn) (1.3.5)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from seaborn) (3.5.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.5.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from pandas>=0.25->seaborn) (2024.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.29.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.4.4)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.0)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (6.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.1.5)
# Requirement already satisfied: zipp>=0.5 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.15.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# load dataset

# %%
# Load Pima Indian Diabetes dataset
df = pd.read_csv("F:/RUSL/4- 1/ICT 4302 - Intelligent Systems/miniProject1/diabetes.csv")

df.columns = df.columns.str.strip()  # Clean header spaces
for col in df.columns:
    if col != 'Outcome':
        df[col] = pd.to_numeric(df[col], errors='coerce')  # Convert non-numeric to NaN

numeric_df = df.select_dtypes(include=['number'])

df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# Data preprocessing

# %% [markdown]
# step 1 - Replace invalid zeros with NaN (handle missing values)

# %%
cols_with_missing = ["Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI"]

# Replace 0 with np.nan only for these features
df[cols_with_missing] = df[cols_with_missing].replace(0, np.nan)

# %%
# Remove rows with too many missing values
def drop_rows_with_many_missing(df, threshold_cols=4):
    return df[df[cols_with_missing].isnull().sum(axis=1) < threshold_cols]

df = drop_rows_with_many_missing(df)

# %%
# Define columns for different strategies
median_columns = ["Glucose", "BloodPressure"]
knn_columns = ["SkinThickness", "Insulin", "BMI"]

# %% [markdown]
# step 2 - fill missing values using the median of the same class

# %%
# Apply same-class median imputation
def impute_same_class_median(df, columns, class_col="Outcome"):
    for col in columns:
        df[col] = df.groupby(class_col)[col].transform(lambda x: x.fillna(x.median()))
    return df

df = impute_same_class_median(df, median_columns)

# %%
# Apply KNN Imputer for selected columns
def knn_impute(df, columns, n_neighbors=5):
    imputer = KNNImputer(n_neighbors=n_neighbors)
    df[columns] = imputer.fit_transform(df[columns])
    return df

df = knn_impute(df, knn_columns)

# %%
# Normalize features (optional but recommended)
from sklearn.preprocessing import MinMaxScaler


features = df.columns[:-1]  # Exclude Outcome
scaler = MinMaxScaler()
df[features] = scaler.fit_transform(df[features])

# %%
print("✅ Cleaned dataset ready for model:")
display(df.head())
# Out:
# ✅ Cleaned dataset ready for model:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     0.352941  0.670968       0.489796       0.304348  0.213221  0.314928
# 1     0.058824  0.264516       0.428571       0.239130  0.128125  0.171779
# 2     0.470588  0.896774       0.408163       0.106522  0.106010  0.104294
# 3     0.058824  0.290323       0.428571       0.173913  0.096154  0.202454
# 4     0.000000  0.600000       0.163265       0.304348  0.185096  0.509202
#
#    DiabetesPedigreeFunction       Age  Outcome
# 0                  0.234415  0.483333        1
# 1                  0.116567  0.166667        0
# 2                  0.253629  0.183333        1
# 3                  0.038002  0.000000        0
# 4                  0.943638  0.200000        1

# %%
# ----- AFTER preprocessing and missing value handling -----

# Balance the dataset
class_0 = df[df['Outcome'] == 0]
class_1 = df[df['Outcome'] == 1]

min_size = min(len(class_0), len(class_1))
class_0_sampled = class_0.sample(n=min_size, random_state=42)
class_1_sampled = class_1.sample(n=min_size, random_state=42)

balanced_df = pd.concat([class_0_sampled, class_1_sampled], axis=0)
balanced_df = balanced_df.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
X = balanced_df.drop("Outcome", axis=1)
y = balanced_df["Outcome"]

# %% [markdown]
# data split

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

# %% [markdown]
# build custom keras model

# %%
model = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    layers.Dropout(0.3),  # Dropout layer to prevent overfitting
    layers.Dense(32, activation='relu'),
    layers.Dropout(0.2),  # Dropout layer to prevent overfitting
    layers.Dense(16, activation='relu'),
    layers.Dense(1, activation='sigmoid')  # Binary output
])

model.compile(optimizer='RMSprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])
#add extra hidden layer and change number of nodes in each layer

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 64)                576
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 16)                1040
#
#  dense_5 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 1,633
# Trainable params: 1,633
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Train the model

# %%
history = model.fit(X_train, y_train, epochs=100, batch_size=16, validation_split=0.1, verbose=2) #change validation0split from 0.2-> 0.1
#change batch_size to 8
# Out:
# Epoch 1/100
# 54/54 - 0s - loss: 0.4917 - accuracy: 0.7616 - val_loss: 0.5162 - val_accuracy: 0.7917 - 235ms/epoch - 4ms/step
# Epoch 2/100
# 54/54 - 0s - loss: 0.4798 - accuracy: 0.7639 - val_loss: 0.4990 - val_accuracy: 0.7292 - 180ms/epoch - 3ms/step
# Epoch 3/100
# 54/54 - 0s - loss: 0.4742 - accuracy: 0.7662 - val_loss: 0.4935 - val_accuracy: 0.7292 - 204ms/epoch - 4ms/step
# Epoch 4/100
# 54/54 - 0s - loss: 0.4872 - accuracy: 0.7639 - val_loss: 0.4950 - val_accuracy: 0.7292 - 205ms/epoch - 4ms/step
# Epoch 5/100
# 54/54 - 0s - loss: 0.4828 - accuracy: 0.7662 - val_loss: 0.4966 - val_accuracy: 0.7292 - 220ms/epoch - 4ms/step
# Epoch 6/100
# 54/54 - 0s - loss: 0.4659 - accuracy: 0.7847 - val_loss: 0.5028 - val_accuracy: 0.7917 - 271ms/epoch - 5ms/step
# Epoch 7/100
# 54/54 - 0s - loss: 0.4864 - accuracy: 0.7593 - val_loss: 0.4984 - val_accuracy: 0.7917 - 289ms/epoch - 5ms/step
# Epoch 8/100
# 54/54 - 0s - loss: 0.4636 - accuracy: 0.7801 - val_loss: 0.5013 - val_accuracy: 0.7917 - 260ms/epoch - 5ms/step
# Epoch 9/100
# 54/54 - 0s - loss: 0.4702 - accuracy: 0.7801 - val_loss: 0.4991 - val_accuracy: 0.7500 - 267ms/epoch - 5ms/step
# Epoch 10/100
# 54/54 - 0s - loss: 0.4853 - accuracy: 0.7801 - val_loss: 0.4933 - val_accuracy: 0.7500 - 238ms/epoch - 4ms/step
# Epoch 11/100
# 54/54 - 0s - loss: 0.4731 - accuracy: 0.7755 - val_loss: 0.4964 - val_accuracy: 0.7500 - 268ms/epoch - 5ms/step
# Epoch 12/100
# 54/54 - 0s - loss: 0.4598 - accuracy: 0.7870 - val_loss: 0.4911 - val_accuracy: 0.7917 - 274ms/epoch - 5ms/step
# Epoch 13/100
# 54/54 - 0s - loss: 0.4688 - accuracy: 0.7894 - val_loss: 0.4889 - val_accuracy: 0.7292 - 323ms/epoch - 6ms/step
# Epoch 14/100
# 54/54 - 0s - loss: 0.4669 - accuracy: 0.7639 - val_loss: 0.5126 - val_accuracy: 0.7708 - 441ms/epoch - 8ms/step
# Epoch 15/100
# 54/54 - 0s - loss: 0.4755 - accuracy: 0.7847 - val_loss: 0.4933 - val_accuracy: 0.7500 - 293ms/epoch - 5ms/step
# Epoch 16/100
# 54/54 - 0s - loss: 0.4711 - accuracy: 0.7778 - val_loss: 0.4879 - val_accuracy: 0.7708 - 307ms/epoch - 6ms/step
# Epoch 17/100
# 54/54 - 0s - loss: 0.4643 - accuracy: 0.7847 - val_loss: 0.4879 - val_accuracy: 0.7500 - 293ms/epoch - 5ms/step
# Epoch 18/100
# 54/54 - 0s - loss: 0.4666 - accuracy: 0.8032 - val_loss: 0.4948 - val_accuracy: 0.7917 - 269ms/epoch - 5ms/step
# Epoch 19/100
# 54/54 - 0s - loss: 0.4739 - accuracy: 0.7662 - val_loss: 0.4986 - val_accuracy: 0.7917 - 396ms/epoch - 7ms/step
# Epoch 20/100
# 54/54 - 0s - loss: 0.4747 - accuracy: 0.7755 - val_loss: 0.4950 - val_accuracy: 0.7708 - 463ms/epoch - 9ms/step
# Epoch 21/100
# 54/54 - 0s - loss: 0.4725 - accuracy: 0.7801 - val_loss: 0.4954 - val_accuracy: 0.7500 - 320ms/epoch - 6ms/step
# Epoch 22/100
# 54/54 - 0s - loss: 0.4693 - accuracy: 0.7731 - val_loss: 0.4971 - val_accuracy: 0.7500 - 350ms/epoch - 6ms/step
# Epoch 23/100
# 54/54 - 0s - loss: 0.4635 - accuracy: 0.7708 - val_loss: 0.4959 - val_accuracy: 0.7500 - 279ms/epoch - 5ms/step
# Epoch 24/100
# 54/54 - 0s - loss: 0.4560 - accuracy: 0.7755 - val_loss: 0.4965 - val_accuracy: 0.7708 - 251ms/epoch - 5ms/step
# Epoch 25/100
# 54/54 - 0s - loss: 0.4686 - accuracy: 0.7917 - val_loss: 0.5035 - val_accuracy: 0.7917 - 447ms/epoch - 8ms/step
# Epoch 26/100
# 54/54 - 1s - loss: 0.4698 - accuracy: 0.7824 - val_loss: 0.5019 - val_accuracy: 0.7917 - 652ms/epoch - 12ms/step
# Epoch 27/100
# 54/54 - 1s - loss: 0.4692 - accuracy: 0.7847 - val_loss: 0.4906 - val_accuracy: 0.7708 - 747ms/epoch - 14ms/step
# Epoch 28/100
# 54/54 - 1s - loss: 0.4537 - accuracy: 0.7870 - val_loss: 0.5290 - val_accuracy: 0.7708 - 566ms/epoch - 10ms/step
# Epoch 29/100
# 54/54 - 0s - loss: 0.4480 - accuracy: 0.7963 - val_loss: 0.4931 - val_accuracy: 0.7917 - 474ms/epoch - 9ms/step
# Epoch 30/100
# 54/54 - 1s - loss: 0.4658 - accuracy: 0.7801 - val_loss: 0.4995 - val_accuracy: 0.7708 - 556ms/epoch - 10ms/step
# Epoch 31/100
# 54/54 - 1s - loss: 0.4649 - accuracy: 0.7894 - val_loss: 0.4950 - val_accuracy: 0.7500 - 536ms/epoch - 10ms/step
# Epoch 32/100
# 54/54 - 0s - loss: 0.4678 - accuracy: 0.7593 - val_loss: 0.4999 - val_accuracy: 0.7917 - 408ms/epoch - 8ms/step
# Epoch 33/100
# 54/54 - 0s - loss: 0.4657 - accuracy: 0.7755 - val_loss: 0.4972 - val_accuracy: 0.7708 - 365ms/epoch - 7ms/step
# Epoch 34/100
# 54/54 - 0s - loss: 0.4631 - accuracy: 0.7778 - val_loss: 0.4925 - val_accuracy: 0.7500 - 328ms/epoch - 6ms/step
# Epoch 35/100
# 54/54 - 0s - loss: 0.4512 - accuracy: 0.7755 - val_loss: 0.4996 - val_accuracy: 0.7917 - 335ms/epoch - 6ms/step
# Epoch 36/100
# 54/54 - 0s - loss: 0.4601 - accuracy: 0.7731 - val_loss: 0.5064 - val_accuracy: 0.7708 - 449ms/epoch - 8ms/step
# Epoch 37/100
# 54/54 - 0s - loss: 0.4657 - accuracy: 0.7778 - val_loss: 0.4901 - val_accuracy: 0.7708 - 339ms/epoch - 6ms/step
# Epoch 38/100
# 54/54 - 0s - loss: 0.4660 - accuracy: 0.7755 - val_loss: 0.4970 - val_accuracy: 0.7708 - 296ms/epoch - 5ms/step
# Epoch 39/100
# 54/54 - 0s - loss: 0.4637 - accuracy: 0.7685 - val_loss: 0.4999 - val_accuracy: 0.7500 - 337ms/epoch - 6ms/step
# Epoch 40/100
# 54/54 - 0s - loss: 0.4447 - accuracy: 0.8009 - val_loss: 0.5025 - val_accuracy: 0.7708 - 285ms/epoch - 5ms/step
# Epoch 41/100
# 54/54 - 0s - loss: 0.4533 - accuracy: 0.7894 - val_loss: 0.5037 - val_accuracy: 0.7500 - 256ms/epoch - 5ms/step
# Epoch 42/100
# 54/54 - 0s - loss: 0.4547 - accuracy: 0.7824 - val_loss: 0.5001 - val_accuracy: 0.7708 - 299ms/epoch - 6ms/step
# Epoch 43/100
# 54/54 - 0s - loss: 0.4412 - accuracy: 0.7824 - val_loss: 0.5071 - val_accuracy: 0.7708 - 333ms/epoch - 6ms/step
# Epoch 44/100
# 54/54 - 0s - loss: 0.4598 - accuracy: 0.7731 - val_loss: 0.5014 - val_accuracy: 0.7500 - 322ms/epoch - 6ms/step
# Epoch 45/100
# 54/54 - 0s - loss: 0.4548 - accuracy: 0.7755 - val_loss: 0.5099 - val_accuracy: 0.7917 - 287ms/epoch - 5ms/step
# Epoch 46/100
# 54/54 - 0s - loss: 0.4489 - accuracy: 0.7731 - val_loss: 0.5127 - val_accuracy: 0.7708 - 431ms/epoch - 8ms/step
# Epoch 47/100
# 54/54 - 0s - loss: 0.4534 - accuracy: 0.7801 - val_loss: 0.4898 - val_accuracy: 0.7708 - 484ms/epoch - 9ms/step
# Epoch 48/100
# 54/54 - 0s - loss: 0.4440 - accuracy: 0.7870 - val_loss: 0.5062 - val_accuracy: 0.7917 - 290ms/epoch - 5ms/step
# Epoch 49/100
# 54/54 - 0s - loss: 0.4400 - accuracy: 0.7824 - val_loss: 0.5172 - val_accuracy: 0.7708 - 329ms/epoch - 6ms/step
# Epoch 50/100
# 54/54 - 1s - loss: 0.4489 - accuracy: 0.7685 - val_loss: 0.5040 - val_accuracy: 0.7500 - 531ms/epoch - 10ms/step
# Epoch 51/100
# 54/54 - 0s - loss: 0.4457 - accuracy: 0.7940 - val_loss: 0.5072 - val_accuracy: 0.7917 - 356ms/epoch - 7ms/step
# Epoch 52/100
# 54/54 - 0s - loss: 0.4479 - accuracy: 0.7940 - val_loss: 0.5165 - val_accuracy: 0.7708 - 395ms/epoch - 7ms/step
# Epoch 53/100
# 54/54 - 0s - loss: 0.4589 - accuracy: 0.7778 - val_loss: 0.5019 - val_accuracy: 0.7708 - 453ms/epoch - 8ms/step
# Epoch 54/100
# 54/54 - 0s - loss: 0.4586 - accuracy: 0.7801 - val_loss: 0.4979 - val_accuracy: 0.7917 - 428ms/epoch - 8ms/step
# Epoch 55/100
# 54/54 - 1s - loss: 0.4455 - accuracy: 0.7778 - val_loss: 0.4981 - val_accuracy: 0.7708 - 535ms/epoch - 10ms/step
# Epoch 56/100
# 54/54 - 1s - loss: 0.4562 - accuracy: 0.7801 - val_loss: 0.5095 - val_accuracy: 0.7708 - 506ms/epoch - 9ms/step
# Epoch 57/100
# 54/54 - 0s - loss: 0.4634 - accuracy: 0.7801 - val_loss: 0.5081 - val_accuracy: 0.7500 - 319ms/epoch - 6ms/step
# Epoch 58/100
# 54/54 - 0s - loss: 0.4507 - accuracy: 0.7731 - val_loss: 0.4950 - val_accuracy: 0.7917 - 353ms/epoch - 7ms/step
# Epoch 59/100
# 54/54 - 0s - loss: 0.4479 - accuracy: 0.7940 - val_loss: 0.5028 - val_accuracy: 0.7708 - 290ms/epoch - 5ms/step
# Epoch 60/100
# 54/54 - 0s - loss: 0.4582 - accuracy: 0.7778 - val_loss: 0.4952 - val_accuracy: 0.7708 - 267ms/epoch - 5ms/step
# Epoch 61/100
# 54/54 - 0s - loss: 0.4500 - accuracy: 0.7917 - val_loss: 0.5101 - val_accuracy: 0.7500 - 299ms/epoch - 6ms/step
# Epoch 62/100
# 54/54 - 0s - loss: 0.4666 - accuracy: 0.7847 - val_loss: 0.5016 - val_accuracy: 0.7500 - 357ms/epoch - 7ms/step
# Epoch 63/100
# 54/54 - 0s - loss: 0.4673 - accuracy: 0.7940 - val_loss: 0.5005 - val_accuracy: 0.7500 - 415ms/epoch - 8ms/step
# Epoch 64/100
# 54/54 - 0s - loss: 0.4522 - accuracy: 0.7778 - val_loss: 0.4919 - val_accuracy: 0.8125 - 376ms/epoch - 7ms/step
# Epoch 65/100
# 54/54 - 0s - loss: 0.4524 - accuracy: 0.7894 - val_loss: 0.5042 - val_accuracy: 0.7708 - 327ms/epoch - 6ms/step
# Epoch 66/100
# 54/54 - 0s - loss: 0.4344 - accuracy: 0.7917 - val_loss: 0.5069 - val_accuracy: 0.7708 - 293ms/epoch - 5ms/step
# Epoch 67/100
# 54/54 - 0s - loss: 0.4517 - accuracy: 0.7894 - val_loss: 0.5026 - val_accuracy: 0.7708 - 256ms/epoch - 5ms/step
# Epoch 68/100
# 54/54 - 0s - loss: 0.4400 - accuracy: 0.7870 - val_loss: 0.5094 - val_accuracy: 0.7708 - 267ms/epoch - 5ms/step
# Epoch 69/100
# 54/54 - 0s - loss: 0.4596 - accuracy: 0.7940 - val_loss: 0.5054 - val_accuracy: 0.7708 - 266ms/epoch - 5ms/step
# Epoch 70/100
# 54/54 - 0s - loss: 0.4440 - accuracy: 0.7963 - val_loss: 0.5056 - val_accuracy: 0.7708 - 304ms/epoch - 6ms/step
# Epoch 71/100
# 54/54 - 0s - loss: 0.4494 - accuracy: 0.7755 - val_loss: 0.4965 - val_accuracy: 0.8125 - 348ms/epoch - 6ms/step
# Epoch 72/100
# 54/54 - 0s - loss: 0.4514 - accuracy: 0.7847 - val_loss: 0.5111 - val_accuracy: 0.7917 - 265ms/epoch - 5ms/step
# Epoch 73/100
# 54/54 - 0s - loss: 0.4574 - accuracy: 0.7847 - val_loss: 0.5009 - val_accuracy: 0.8125 - 253ms/epoch - 5ms/step
# Epoch 74/100
# 54/54 - 0s - loss: 0.4313 - accuracy: 0.7870 - val_loss: 0.5100 - val_accuracy: 0.7917 - 240ms/epoch - 4ms/step
# Epoch 75/100
# 54/54 - 0s - loss: 0.4404 - accuracy: 0.7847 - val_loss: 0.5085 - val_accuracy: 0.7708 - 292ms/epoch - 5ms/step
# Epoch 76/100
# 54/54 - 0s - loss: 0.4487 - accuracy: 0.7731 - val_loss: 0.5001 - val_accuracy: 0.8125 - 236ms/epoch - 4ms/step
# Epoch 77/100
# 54/54 - 0s - loss: 0.4315 - accuracy: 0.7917 - val_loss: 0.5039 - val_accuracy: 0.7708 - 254ms/epoch - 5ms/step
# Epoch 78/100
# 54/54 - 0s - loss: 0.4488 - accuracy: 0.7940 - val_loss: 0.5111 - val_accuracy: 0.7917 - 272ms/epoch - 5ms/step
# Epoch 79/100
# 54/54 - 0s - loss: 0.4390 - accuracy: 0.7986 - val_loss: 0.5166 - val_accuracy: 0.7708 - 280ms/epoch - 5ms/step
# Epoch 80/100
# 54/54 - 0s - loss: 0.4438 - accuracy: 0.7847 - val_loss: 0.5063 - val_accuracy: 0.7917 - 346ms/epoch - 6ms/step
# Epoch 81/100
# 54/54 - 0s - loss: 0.4416 - accuracy: 0.7917 - val_loss: 0.5028 - val_accuracy: 0.7917 - 485ms/epoch - 9ms/step
# Epoch 82/100
# 54/54 - 0s - loss: 0.4464 - accuracy: 0.7940 - val_loss: 0.5255 - val_accuracy: 0.7500 - 385ms/epoch - 7ms/step
# Epoch 83/100
# 54/54 - 0s - loss: 0.4391 - accuracy: 0.7917 - val_loss: 0.5141 - val_accuracy: 0.7917 - 451ms/epoch - 8ms/step
# Epoch 84/100
# 54/54 - 0s - loss: 0.4445 - accuracy: 0.7847 - val_loss: 0.5214 - val_accuracy: 0.7708 - 448ms/epoch - 8ms/step
# Epoch 85/100
# 54/54 - 0s - loss: 0.4436 - accuracy: 0.8009 - val_loss: 0.5121 - val_accuracy: 0.7708 - 363ms/epoch - 7ms/step
# Epoch 86/100
# 54/54 - 0s - loss: 0.4544 - accuracy: 0.7917 - val_loss: 0.5141 - val_accuracy: 0.8125 - 344ms/epoch - 6ms/step
# Epoch 87/100
# 54/54 - 0s - loss: 0.4476 - accuracy: 0.7940 - val_loss: 0.5170 - val_accuracy: 0.7917 - 372ms/epoch - 7ms/step
# Epoch 88/100
# 54/54 - 0s - loss: 0.4457 - accuracy: 0.7986 - val_loss: 0.5198 - val_accuracy: 0.7500 - 306ms/epoch - 6ms/step
# Epoch 89/100
# 54/54 - 0s - loss: 0.4465 - accuracy: 0.7917 - val_loss: 0.5087 - val_accuracy: 0.7500 - 287ms/epoch - 5ms/step
# Epoch 90/100
# 54/54 - 0s - loss: 0.4443 - accuracy: 0.8056 - val_loss: 0.5059 - val_accuracy: 0.7708 - 290ms/epoch - 5ms/step
# Epoch 91/100
# 54/54 - 0s - loss: 0.4317 - accuracy: 0.7963 - val_loss: 0.5014 - val_accuracy: 0.8125 - 288ms/epoch - 5ms/step
# Epoch 92/100
# 54/54 - 0s - loss: 0.4362 - accuracy: 0.8009 - val_loss: 0.5063 - val_accuracy: 0.7708 - 305ms/epoch - 6ms/step
# Epoch 93/100
# 54/54 - 0s - loss: 0.4461 - accuracy: 0.8056 - val_loss: 0.5417 - val_accuracy: 0.7708 - 314ms/epoch - 6ms/step
# Epoch 94/100
# 54/54 - 0s - loss: 0.4346 - accuracy: 0.7847 - val_loss: 0.5052 - val_accuracy: 0.8125 - 291ms/epoch - 5ms/step
# Epoch 95/100
# 54/54 - 0s - loss: 0.4443 - accuracy: 0.7847 - val_loss: 0.5211 - val_accuracy: 0.7917 - 288ms/epoch - 5ms/step
# Epoch 96/100
# 54/54 - 0s - loss: 0.4518 - accuracy: 0.7917 - val_loss: 0.5132 - val_accuracy: 0.7708 - 301ms/epoch - 6ms/step
# Epoch 97/100
# 54/54 - 0s - loss: 0.4289 - accuracy: 0.7963 - val_loss: 0.5242 - val_accuracy: 0.7500 - 275ms/epoch - 5ms/step
# Epoch 98/100
# 54/54 - 0s - loss: 0.4372 - accuracy: 0.8056 - val_loss: 0.5149 - val_accuracy: 0.7500 - 271ms/epoch - 5ms/step
# Epoch 99/100
# 54/54 - 0s - loss: 0.4429 - accuracy: 0.7894 - val_loss: 0.5136 - val_accuracy: 0.8125 - 287ms/epoch - 5ms/step
# Epoch 100/100
# 54/54 - 0s - loss: 0.4207 - accuracy: 0.8079 - val_loss: 0.5136 - val_accuracy: 0.8125 - 295ms/epoch - 5ms/step

# %% [markdown]
# Evaluate the model

# %%
# Predict probabilities
y_pred_prob = model.predict(X_test).ravel()

# Convert to binary output
y_pred = (y_pred_prob >= 0.5).astype(int)

# Classification report
print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))

# Confusion Matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# Predict probabilities and convert to binary
y_pred_prob = model.predict(X_test).ravel()
y_pred = (y_pred_prob >= 0.5).astype(int)

# Generate confusion matrix
cm = confusion_matrix(y_test, y_pred)
labels = ['No Diabetes', 'Diabetes']

# Plot
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)

plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.tight_layout()
plt.show()


# Individual metrics
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall:", recall_score(y_test, y_pred))
print("F1 Score:", f1_score(y_test, y_pred))
# Out:
# 2/2 [==============================] - 0s 8ms/step
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.72      0.69        25
#            1       0.74      0.69      0.71        29
#
#     accuracy                           0.70        54
#    macro avg       0.70      0.70      0.70        54
# weighted avg       0.71      0.70      0.70        54
#
# 2/2 [==============================] - 0s 6ms/step
# Accuracy: 0.7037037037037037
# Precision: 0.7407407407407407
# Recall: 0.6896551724137931
# F1 Score: 0.7142857142857143

# %%
# Plot training & validation accuracy
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot training & validation loss
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# Predict probabilities for the test set
y_pred_prob = model.predict(X_test).ravel()  # Already flattened

# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)

# Calculate AUC score
auc_score = roc_auc_score(y_test, y_pred_prob)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC Curve (AUC = {auc_score:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')  # Diagonal line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()
# Out:
# 2/2 [==============================] - 0s 5ms/step
