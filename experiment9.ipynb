# %%
# %pip install tensorflow seaborn

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.impute import KNNImputer
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_curve, auc

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# Out:
# Requirement already satisfied: tensorflow in c:\users\ww\anaconda3\envs\iis\lib\site-packages (2.11.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: seaborn in c:\users\ww\anaconda3\envs\iis\lib\site-packages (0.12.2)
# Requirement already satisfied: tensorflow-intel==2.11.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.8.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (18.1.1)
# Requirement already satisfied: numpy>=1.20 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.21.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (24.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.19.6)
# Requirement already satisfied: setuptools in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (65.6.3)
# Requirement already satisfied: six>=1.12.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (4.7.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.62.2)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.2)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.31.0)
# Requirement already satisfied: pandas>=0.25 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from seaborn) (1.3.5)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from seaborn) (3.5.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.5.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from pandas>=0.25->seaborn) (2024.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.29.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.4.4)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.0)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (6.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.1.5)
# Requirement already satisfied: zipp>=0.5 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.15.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.2.2)

# %% [markdown]
# load dataset

# %%
# Load Pima Indian Diabetes dataset
df = pd.read_csv("F:/RUSL/4- 1/ICT 4302 - Intelligent Systems/miniProject1/diabetes.csv")

df.columns = df.columns.str.strip()  # Clean header spaces
for col in df.columns:
    if col != 'Outcome':
        df[col] = pd.to_numeric(df[col], errors='coerce')  # Convert non-numeric to NaN

numeric_df = df.select_dtypes(include=['number'])

df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# Data preprocessing

# %% [markdown]
# step 1 - Replace invalid zeros with NaN (handle missing values)

# %%
cols_with_missing = ["Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI"]

# Replace 0 with np.nan only for these features
df[cols_with_missing] = df[cols_with_missing].replace(0, np.nan)

# %%
# Remove rows with too many missing values
def drop_rows_with_many_missing(df, threshold_cols=4):
    return df[df[cols_with_missing].isnull().sum(axis=1) < threshold_cols]

df = drop_rows_with_many_missing(df)

# %%
# Define columns for different strategies
median_columns = ["Glucose", "BloodPressure"]
knn_columns = ["SkinThickness", "Insulin", "BMI"]

# %% [markdown]
# step 2 - fill missing values using the median of the same class

# %%
# Apply same-class median imputation
def impute_same_class_median(df, columns, class_col="Outcome"):
    for col in columns:
        df[col] = df.groupby(class_col)[col].transform(lambda x: x.fillna(x.median()))
    return df

df = impute_same_class_median(df, median_columns)

# %%
# Apply KNN Imputer for selected columns
def knn_impute(df, columns, n_neighbors=5):
    imputer = KNNImputer(n_neighbors=n_neighbors)
    df[columns] = imputer.fit_transform(df[columns])
    return df

df = knn_impute(df, knn_columns)

# %%
# Normalize features (optional but recommended)
from sklearn.preprocessing import MinMaxScaler


features = df.columns[:-1]  # Exclude Outcome
scaler = MinMaxScaler()
df[features] = scaler.fit_transform(df[features])

# %%
print("✅ Cleaned dataset ready for model:")
display(df.head())
# Out:
# ✅ Cleaned dataset ready for model:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     0.352941  0.670968       0.489796       0.304348  0.213221  0.314928
# 1     0.058824  0.264516       0.428571       0.239130  0.128125  0.171779
# 2     0.470588  0.896774       0.408163       0.106522  0.106010  0.104294
# 3     0.058824  0.290323       0.428571       0.173913  0.096154  0.202454
# 4     0.000000  0.600000       0.163265       0.304348  0.185096  0.509202
#
#    DiabetesPedigreeFunction       Age  Outcome
# 0                  0.234415  0.483333        1
# 1                  0.116567  0.166667        0
# 2                  0.253629  0.183333        1
# 3                  0.038002  0.000000        0
# 4                  0.943638  0.200000        1

# %%
# ----- AFTER preprocessing and missing value handling -----

# Balance the dataset
class_0 = df[df['Outcome'] == 0]
class_1 = df[df['Outcome'] == 1]

min_size = min(len(class_0), len(class_1))
class_0_sampled = class_0.sample(n=min_size, random_state=42)
class_1_sampled = class_1.sample(n=min_size, random_state=42)

balanced_df = pd.concat([class_0_sampled, class_1_sampled], axis=0)
balanced_df = balanced_df.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
X = balanced_df.drop("Outcome", axis=1)
y = balanced_df["Outcome"]

# %% [markdown]
# data split

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

# %% [markdown]
# build custom keras model

# %%
model = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    layers.Dropout(0.3),  # Dropout layer to prevent overfitting
    layers.Dense(16, activation='relu'),
    layers.Dense(1, activation='sigmoid')  # Binary output
])

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
#add extra hidden layer and change number of nodes in each layer

# %%
model = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    layers.Dropout(0.3),  # Dropout layer to prevent overfitting
    layers.Dense(16, activation='relu'),
    layers.Dense(1, activation='sigmoid')  # Binary output
])

model.compile(optimizer='RMSprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])
#add extra hidden layer and change number of nodes in each layer

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_12 (Dense)            (None, 64)                576
#
#  dropout_4 (Dropout)         (None, 64)                0
#
#  dense_13 (Dense)            (None, 16)                1040
#
#  dense_14 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 1,633
# Trainable params: 1,633
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Train the model

# %%
history = model.fit(X_train, y_train, epochs=100, batch_size=16, validation_split=0.1, verbose=2) #change validation0split from 0.2-> 0.1
# Out:
# Epoch 1/100
# 27/27 - 1s - loss: 0.6880 - accuracy: 0.5000 - val_loss: 0.6787 - val_accuracy: 0.5833 - 969ms/epoch - 36ms/step
# Epoch 2/100
# 27/27 - 0s - loss: 0.6742 - accuracy: 0.5532 - val_loss: 0.6689 - val_accuracy: 0.6042 - 216ms/epoch - 8ms/step
# Epoch 3/100
# 27/27 - 0s - loss: 0.6652 - accuracy: 0.5949 - val_loss: 0.6586 - val_accuracy: 0.6042 - 99ms/epoch - 4ms/step
# Epoch 4/100
# 27/27 - 0s - loss: 0.6594 - accuracy: 0.6157 - val_loss: 0.6499 - val_accuracy: 0.7292 - 102ms/epoch - 4ms/step
# Epoch 5/100
# 27/27 - 0s - loss: 0.6523 - accuracy: 0.6690 - val_loss: 0.6403 - val_accuracy: 0.6042 - 75ms/epoch - 3ms/step
# Epoch 6/100
# 27/27 - 0s - loss: 0.6464 - accuracy: 0.6690 - val_loss: 0.6312 - val_accuracy: 0.7292 - 85ms/epoch - 3ms/step
# Epoch 7/100
# 27/27 - 0s - loss: 0.6315 - accuracy: 0.6898 - val_loss: 0.6214 - val_accuracy: 0.7708 - 72ms/epoch - 3ms/step
# Epoch 8/100
# 27/27 - 0s - loss: 0.6266 - accuracy: 0.6875 - val_loss: 0.6120 - val_accuracy: 0.7917 - 66ms/epoch - 2ms/step
# Epoch 9/100
# 27/27 - 0s - loss: 0.6070 - accuracy: 0.7199 - val_loss: 0.6028 - val_accuracy: 0.7917 - 94ms/epoch - 3ms/step
# Epoch 10/100
# 27/27 - 0s - loss: 0.6046 - accuracy: 0.7130 - val_loss: 0.5920 - val_accuracy: 0.7917 - 107ms/epoch - 4ms/step
# Epoch 11/100
# 27/27 - 0s - loss: 0.5955 - accuracy: 0.7338 - val_loss: 0.5837 - val_accuracy: 0.7917 - 79ms/epoch - 3ms/step
# Epoch 12/100
# 27/27 - 0s - loss: 0.5790 - accuracy: 0.7662 - val_loss: 0.5743 - val_accuracy: 0.7500 - 83ms/epoch - 3ms/step
# Epoch 13/100
# 27/27 - 0s - loss: 0.5755 - accuracy: 0.7431 - val_loss: 0.5662 - val_accuracy: 0.7917 - 92ms/epoch - 3ms/step
# Epoch 14/100
# 27/27 - 0s - loss: 0.5699 - accuracy: 0.7199 - val_loss: 0.5584 - val_accuracy: 0.7917 - 84ms/epoch - 3ms/step
# Epoch 15/100
# 27/27 - 0s - loss: 0.5673 - accuracy: 0.7662 - val_loss: 0.5640 - val_accuracy: 0.7500 - 69ms/epoch - 3ms/step
# Epoch 16/100
# 27/27 - 0s - loss: 0.5632 - accuracy: 0.7384 - val_loss: 0.5527 - val_accuracy: 0.8125 - 80ms/epoch - 3ms/step
# Epoch 17/100
# 27/27 - 0s - loss: 0.5654 - accuracy: 0.7315 - val_loss: 0.5485 - val_accuracy: 0.8125 - 99ms/epoch - 4ms/step
# Epoch 18/100
# 27/27 - 0s - loss: 0.5563 - accuracy: 0.7130 - val_loss: 0.5506 - val_accuracy: 0.7917 - 81ms/epoch - 3ms/step
# Epoch 19/100
# 27/27 - 0s - loss: 0.5486 - accuracy: 0.7315 - val_loss: 0.5512 - val_accuracy: 0.7500 - 89ms/epoch - 3ms/step
# Epoch 20/100
# 27/27 - 0s - loss: 0.5543 - accuracy: 0.7384 - val_loss: 0.5433 - val_accuracy: 0.7708 - 69ms/epoch - 3ms/step
# Epoch 21/100
# 27/27 - 0s - loss: 0.5315 - accuracy: 0.7500 - val_loss: 0.5331 - val_accuracy: 0.8333 - 63ms/epoch - 2ms/step
# Epoch 22/100
# 27/27 - 0s - loss: 0.5497 - accuracy: 0.7338 - val_loss: 0.5344 - val_accuracy: 0.7500 - 65ms/epoch - 2ms/step
# Epoch 23/100
# 27/27 - 0s - loss: 0.5405 - accuracy: 0.7292 - val_loss: 0.5231 - val_accuracy: 0.7708 - 79ms/epoch - 3ms/step
# Epoch 24/100
# 27/27 - 0s - loss: 0.5344 - accuracy: 0.7477 - val_loss: 0.5407 - val_accuracy: 0.7708 - 83ms/epoch - 3ms/step
# Epoch 25/100
# 27/27 - 0s - loss: 0.5422 - accuracy: 0.7292 - val_loss: 0.5222 - val_accuracy: 0.8125 - 71ms/epoch - 3ms/step
# Epoch 26/100
# 27/27 - 0s - loss: 0.5242 - accuracy: 0.7431 - val_loss: 0.5253 - val_accuracy: 0.7917 - 65ms/epoch - 2ms/step
# Epoch 27/100
# 27/27 - 0s - loss: 0.5313 - accuracy: 0.7315 - val_loss: 0.5168 - val_accuracy: 0.8125 - 116ms/epoch - 4ms/step
# Epoch 28/100
# 27/27 - 0s - loss: 0.5268 - accuracy: 0.7500 - val_loss: 0.5169 - val_accuracy: 0.8125 - 68ms/epoch - 3ms/step
# Epoch 29/100
# 27/27 - 0s - loss: 0.5225 - accuracy: 0.7755 - val_loss: 0.5229 - val_accuracy: 0.7917 - 65ms/epoch - 2ms/step
# Epoch 30/100
# 27/27 - 0s - loss: 0.5245 - accuracy: 0.7338 - val_loss: 0.5160 - val_accuracy: 0.7917 - 94ms/epoch - 3ms/step
# Epoch 31/100
# 27/27 - 0s - loss: 0.5199 - accuracy: 0.7546 - val_loss: 0.5135 - val_accuracy: 0.7917 - 85ms/epoch - 3ms/step
# Epoch 32/100
# 27/27 - 0s - loss: 0.5083 - accuracy: 0.7616 - val_loss: 0.5068 - val_accuracy: 0.8333 - 79ms/epoch - 3ms/step
# Epoch 33/100
# 27/27 - 0s - loss: 0.5155 - accuracy: 0.7384 - val_loss: 0.4993 - val_accuracy: 0.7917 - 62ms/epoch - 2ms/step
# Epoch 34/100
# 27/27 - 0s - loss: 0.5181 - accuracy: 0.7662 - val_loss: 0.5025 - val_accuracy: 0.8542 - 60ms/epoch - 2ms/step
# Epoch 35/100
# 27/27 - 0s - loss: 0.5095 - accuracy: 0.7731 - val_loss: 0.4959 - val_accuracy: 0.7917 - 63ms/epoch - 2ms/step
# Epoch 36/100
# 27/27 - 0s - loss: 0.5176 - accuracy: 0.7384 - val_loss: 0.4924 - val_accuracy: 0.7917 - 64ms/epoch - 2ms/step
# Epoch 37/100
# 27/27 - 0s - loss: 0.5058 - accuracy: 0.7755 - val_loss: 0.4914 - val_accuracy: 0.7917 - 67ms/epoch - 2ms/step
# Epoch 38/100
# 27/27 - 0s - loss: 0.5073 - accuracy: 0.7662 - val_loss: 0.5159 - val_accuracy: 0.7500 - 68ms/epoch - 3ms/step
# Epoch 39/100
# 27/27 - 0s - loss: 0.5047 - accuracy: 0.7546 - val_loss: 0.5110 - val_accuracy: 0.7500 - 70ms/epoch - 3ms/step
# Epoch 40/100
# 27/27 - 0s - loss: 0.5023 - accuracy: 0.7616 - val_loss: 0.4918 - val_accuracy: 0.8125 - 74ms/epoch - 3ms/step
# Epoch 41/100
# 27/27 - 0s - loss: 0.5131 - accuracy: 0.7384 - val_loss: 0.4983 - val_accuracy: 0.7917 - 81ms/epoch - 3ms/step
# Epoch 42/100
# 27/27 - 0s - loss: 0.5069 - accuracy: 0.7523 - val_loss: 0.4920 - val_accuracy: 0.8333 - 117ms/epoch - 4ms/step
# Epoch 43/100
# 27/27 - 0s - loss: 0.5144 - accuracy: 0.7431 - val_loss: 0.4917 - val_accuracy: 0.8333 - 88ms/epoch - 3ms/step
# Epoch 44/100
# 27/27 - 0s - loss: 0.4951 - accuracy: 0.7616 - val_loss: 0.4868 - val_accuracy: 0.7917 - 75ms/epoch - 3ms/step
# Epoch 45/100
# 27/27 - 0s - loss: 0.5051 - accuracy: 0.7616 - val_loss: 0.4918 - val_accuracy: 0.7917 - 72ms/epoch - 3ms/step
# Epoch 46/100
# 27/27 - 0s - loss: 0.5016 - accuracy: 0.7662 - val_loss: 0.4824 - val_accuracy: 0.8542 - 74ms/epoch - 3ms/step
# Epoch 47/100
# 27/27 - 0s - loss: 0.4937 - accuracy: 0.7755 - val_loss: 0.4815 - val_accuracy: 0.8542 - 86ms/epoch - 3ms/step
# Epoch 48/100
# 27/27 - 0s - loss: 0.5120 - accuracy: 0.7431 - val_loss: 0.4844 - val_accuracy: 0.8125 - 81ms/epoch - 3ms/step
# Epoch 49/100
# 27/27 - 0s - loss: 0.4997 - accuracy: 0.7454 - val_loss: 0.4788 - val_accuracy: 0.8333 - 69ms/epoch - 3ms/step
# Epoch 50/100
# 27/27 - 0s - loss: 0.5062 - accuracy: 0.7569 - val_loss: 0.4848 - val_accuracy: 0.8125 - 73ms/epoch - 3ms/step
# Epoch 51/100
# 27/27 - 0s - loss: 0.5099 - accuracy: 0.7731 - val_loss: 0.4992 - val_accuracy: 0.7708 - 75ms/epoch - 3ms/step
# Epoch 52/100
# 27/27 - 0s - loss: 0.4951 - accuracy: 0.7731 - val_loss: 0.4835 - val_accuracy: 0.8125 - 69ms/epoch - 3ms/step
# Epoch 53/100
# 27/27 - 0s - loss: 0.5037 - accuracy: 0.7477 - val_loss: 0.4816 - val_accuracy: 0.8125 - 74ms/epoch - 3ms/step
# Epoch 54/100
# 27/27 - 0s - loss: 0.4954 - accuracy: 0.7593 - val_loss: 0.4731 - val_accuracy: 0.8125 - 103ms/epoch - 4ms/step
# Epoch 55/100
# 27/27 - 0s - loss: 0.4939 - accuracy: 0.7477 - val_loss: 0.4721 - val_accuracy: 0.8125 - 89ms/epoch - 3ms/step
# Epoch 56/100
# 27/27 - 0s - loss: 0.4843 - accuracy: 0.7662 - val_loss: 0.4674 - val_accuracy: 0.8125 - 78ms/epoch - 3ms/step
# Epoch 57/100
# 27/27 - 0s - loss: 0.4883 - accuracy: 0.7546 - val_loss: 0.4837 - val_accuracy: 0.7500 - 92ms/epoch - 3ms/step
# Epoch 58/100
# 27/27 - 0s - loss: 0.4784 - accuracy: 0.7685 - val_loss: 0.4698 - val_accuracy: 0.8333 - 91ms/epoch - 3ms/step
# Epoch 59/100
# 27/27 - 0s - loss: 0.4910 - accuracy: 0.7616 - val_loss: 0.4785 - val_accuracy: 0.7708 - 84ms/epoch - 3ms/step
# Epoch 60/100
# 27/27 - 0s - loss: 0.4942 - accuracy: 0.7639 - val_loss: 0.4685 - val_accuracy: 0.8125 - 88ms/epoch - 3ms/step
# Epoch 61/100
# 27/27 - 0s - loss: 0.4914 - accuracy: 0.7569 - val_loss: 0.4688 - val_accuracy: 0.8125 - 102ms/epoch - 4ms/step
# Epoch 62/100
# 27/27 - 0s - loss: 0.4887 - accuracy: 0.7731 - val_loss: 0.4905 - val_accuracy: 0.7500 - 79ms/epoch - 3ms/step
# Epoch 63/100
# 27/27 - 0s - loss: 0.4998 - accuracy: 0.7685 - val_loss: 0.4823 - val_accuracy: 0.7708 - 76ms/epoch - 3ms/step
# Epoch 64/100
# 27/27 - 0s - loss: 0.4832 - accuracy: 0.7546 - val_loss: 0.4688 - val_accuracy: 0.8333 - 79ms/epoch - 3ms/step
# Epoch 65/100
# 27/27 - 0s - loss: 0.4823 - accuracy: 0.7616 - val_loss: 0.4783 - val_accuracy: 0.7917 - 87ms/epoch - 3ms/step
# Epoch 66/100
# 27/27 - 0s - loss: 0.4714 - accuracy: 0.7639 - val_loss: 0.4709 - val_accuracy: 0.8125 - 95ms/epoch - 4ms/step
# Epoch 67/100
# 27/27 - 0s - loss: 0.4907 - accuracy: 0.7616 - val_loss: 0.4659 - val_accuracy: 0.8333 - 173ms/epoch - 6ms/step
# Epoch 68/100
# 27/27 - 0s - loss: 0.4894 - accuracy: 0.7685 - val_loss: 0.4640 - val_accuracy: 0.8125 - 87ms/epoch - 3ms/step
# Epoch 69/100
# 27/27 - 0s - loss: 0.5046 - accuracy: 0.7384 - val_loss: 0.4767 - val_accuracy: 0.7708 - 81ms/epoch - 3ms/step
# Epoch 70/100
# 27/27 - 0s - loss: 0.4868 - accuracy: 0.7569 - val_loss: 0.4704 - val_accuracy: 0.8125 - 113ms/epoch - 4ms/step
# Epoch 71/100
# 27/27 - 0s - loss: 0.4881 - accuracy: 0.7755 - val_loss: 0.4633 - val_accuracy: 0.8125 - 152ms/epoch - 6ms/step
# Epoch 72/100
# 27/27 - 0s - loss: 0.4871 - accuracy: 0.7616 - val_loss: 0.4669 - val_accuracy: 0.7708 - 73ms/epoch - 3ms/step
# Epoch 73/100
# 27/27 - 0s - loss: 0.4871 - accuracy: 0.7616 - val_loss: 0.4668 - val_accuracy: 0.8125 - 87ms/epoch - 3ms/step
# Epoch 74/100
# 27/27 - 0s - loss: 0.4822 - accuracy: 0.7523 - val_loss: 0.4702 - val_accuracy: 0.7708 - 76ms/epoch - 3ms/step
# Epoch 75/100
# 27/27 - 0s - loss: 0.4875 - accuracy: 0.7685 - val_loss: 0.4711 - val_accuracy: 0.7708 - 86ms/epoch - 3ms/step
# Epoch 76/100
# 27/27 - 0s - loss: 0.4912 - accuracy: 0.7708 - val_loss: 0.4696 - val_accuracy: 0.7708 - 71ms/epoch - 3ms/step
# Epoch 77/100
# 27/27 - 0s - loss: 0.4690 - accuracy: 0.7778 - val_loss: 0.4585 - val_accuracy: 0.8125 - 75ms/epoch - 3ms/step
# Epoch 78/100
# 27/27 - 0s - loss: 0.4894 - accuracy: 0.7569 - val_loss: 0.4801 - val_accuracy: 0.7708 - 73ms/epoch - 3ms/step
# Epoch 79/100
# 27/27 - 0s - loss: 0.4819 - accuracy: 0.7523 - val_loss: 0.4630 - val_accuracy: 0.8333 - 68ms/epoch - 3ms/step
# Epoch 80/100
# 27/27 - 0s - loss: 0.4900 - accuracy: 0.7824 - val_loss: 0.4732 - val_accuracy: 0.7708 - 64ms/epoch - 2ms/step
# Epoch 81/100
# 27/27 - 0s - loss: 0.4778 - accuracy: 0.7755 - val_loss: 0.4654 - val_accuracy: 0.7708 - 58ms/epoch - 2ms/step
# Epoch 82/100
# 27/27 - 0s - loss: 0.4687 - accuracy: 0.7847 - val_loss: 0.4660 - val_accuracy: 0.7708 - 65ms/epoch - 2ms/step
# Epoch 83/100
# 27/27 - 0s - loss: 0.4680 - accuracy: 0.7824 - val_loss: 0.4624 - val_accuracy: 0.7917 - 68ms/epoch - 3ms/step
# Epoch 84/100
# 27/27 - 0s - loss: 0.4765 - accuracy: 0.7778 - val_loss: 0.4584 - val_accuracy: 0.7917 - 88ms/epoch - 3ms/step
# Epoch 85/100
# 27/27 - 0s - loss: 0.4861 - accuracy: 0.7778 - val_loss: 0.4606 - val_accuracy: 0.7917 - 71ms/epoch - 3ms/step
# Epoch 86/100
# 27/27 - 0s - loss: 0.4782 - accuracy: 0.7708 - val_loss: 0.4555 - val_accuracy: 0.8125 - 83ms/epoch - 3ms/step
# Epoch 87/100
# 27/27 - 0s - loss: 0.4832 - accuracy: 0.7616 - val_loss: 0.4610 - val_accuracy: 0.7708 - 62ms/epoch - 2ms/step
# Epoch 88/100
# 27/27 - 0s - loss: 0.4804 - accuracy: 0.7847 - val_loss: 0.4555 - val_accuracy: 0.7917 - 62ms/epoch - 2ms/step
# Epoch 89/100
# 27/27 - 0s - loss: 0.4776 - accuracy: 0.7616 - val_loss: 0.4571 - val_accuracy: 0.7708 - 64ms/epoch - 2ms/step
# Epoch 90/100
# 27/27 - 0s - loss: 0.4640 - accuracy: 0.7986 - val_loss: 0.4529 - val_accuracy: 0.8125 - 63ms/epoch - 2ms/step
# Epoch 91/100
# 27/27 - 0s - loss: 0.4689 - accuracy: 0.7662 - val_loss: 0.4640 - val_accuracy: 0.7708 - 70ms/epoch - 3ms/step
# Epoch 92/100
# 27/27 - 0s - loss: 0.4832 - accuracy: 0.7778 - val_loss: 0.4560 - val_accuracy: 0.8125 - 66ms/epoch - 2ms/step
# Epoch 93/100
# 27/27 - 0s - loss: 0.4723 - accuracy: 0.7917 - val_loss: 0.4626 - val_accuracy: 0.7708 - 78ms/epoch - 3ms/step
# Epoch 94/100
# 27/27 - 0s - loss: 0.4708 - accuracy: 0.7824 - val_loss: 0.4752 - val_accuracy: 0.7708 - 75ms/epoch - 3ms/step
# Epoch 95/100
# 27/27 - 0s - loss: 0.4826 - accuracy: 0.7431 - val_loss: 0.4517 - val_accuracy: 0.8125 - 58ms/epoch - 2ms/step
# Epoch 96/100
# 27/27 - 0s - loss: 0.4900 - accuracy: 0.7662 - val_loss: 0.4572 - val_accuracy: 0.7917 - 61ms/epoch - 2ms/step
# Epoch 97/100
# 27/27 - 0s - loss: 0.4596 - accuracy: 0.7639 - val_loss: 0.4500 - val_accuracy: 0.7917 - 58ms/epoch - 2ms/step
# Epoch 98/100
# 27/27 - 0s - loss: 0.4854 - accuracy: 0.7731 - val_loss: 0.4635 - val_accuracy: 0.7708 - 63ms/epoch - 2ms/step
# Epoch 99/100
# 27/27 - 0s - loss: 0.4651 - accuracy: 0.7778 - val_loss: 0.4650 - val_accuracy: 0.7708 - 68ms/epoch - 3ms/step
# Epoch 100/100
# 27/27 - 0s - loss: 0.4885 - accuracy: 0.7731 - val_loss: 0.4558 - val_accuracy: 0.7708 - 73ms/epoch - 3ms/step

# %% [markdown]
# Evaluate the model

# %%
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, confusion_matrix, classification_report
)

# Predict probabilities
y_pred_prob = model.predict(X_test).ravel()

# Convert to binary output
y_pred = (y_pred_prob >= 0.5).astype(int)

# Classification report
print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))

# Confusion Matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# Predict probabilities and convert to binary
y_pred_prob = model.predict(X_test).ravel()
y_pred = (y_pred_prob >= 0.5).astype(int)

# Generate confusion matrix
cm = confusion_matrix(y_test, y_pred)
labels = ['No Diabetes', 'Diabetes']

# Plot
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)

plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.tight_layout()
plt.show()


# Individual metrics
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall:", recall_score(y_test, y_pred))
print("F1 Score:", f1_score(y_test, y_pred))
# Out:
# 2/2 [==============================] - 0s 2ms/step
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.70      0.67      0.68        24
#            1       0.74      0.77      0.75        30
#
#     accuracy                           0.72        54
#    macro avg       0.72      0.72      0.72        54
# weighted avg       0.72      0.72      0.72        54
#
# 2/2 [==============================] - 0s 2ms/step
# Accuracy: 0.7222222222222222
# Precision: 0.7419354838709677
# Recall: 0.7666666666666667
# F1 Score: 0.7540983606557377

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot training & validation loss
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
