# %%
# %pip install tensorflow seaborn

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.impute import KNNImputer
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_curve, auc

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# Out:
# Requirement already satisfied: tensorflow in c:\users\ww\anaconda3\envs\iis\lib\site-packages (2.11.0)
# Requirement already satisfied: seaborn in c:\users\ww\anaconda3\envs\iis\lib\site-packages (0.12.2)
# Requirement already satisfied: tensorflow-intel==2.11.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.8.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (18.1.1)
# Requirement already satisfied: numpy>=1.20 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.21.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (24.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.19.6)
# Requirement already satisfied: setuptools in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (65.6.3)
# Requirement already satisfied: six>=1.12.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (4.7.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.62.2)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.2)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.31.0)
# Requirement already satisfied: pandas>=0.25 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from seaborn) (1.3.5)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from seaborn) (3.5.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.5.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from pandas>=0.25->seaborn) (2024.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.29.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.4.4)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.0)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (6.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.1.5)
# Requirement already satisfied: zipp>=0.5 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.15.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# load dataset

# %%
# Load Pima Indian Diabetes dataset
df = pd.read_csv("F:/RUSL/4- 1/ICT 4302 - Intelligent Systems/miniProject1/diabetes.csv")

df.columns = df.columns.str.strip()  # Clean header spaces
for col in df.columns:
    if col != 'Outcome':
        df[col] = pd.to_numeric(df[col], errors='coerce')  # Convert non-numeric to NaN

numeric_df = df.select_dtypes(include=['number'])

df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# Data preprocessing

# %% [markdown]
# step 1 - Replace invalid zeros with NaN (handle missing values)

# %%
cols_with_missing = ["Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI"]

# Replace 0 with np.nan only for these features
df[cols_with_missing] = df[cols_with_missing].replace(0, np.nan)

# %%
# Remove rows with too many missing values
def drop_rows_with_many_missing(df, threshold_cols=4):
    return df[df[cols_with_missing].isnull().sum(axis=1) < threshold_cols]

df = drop_rows_with_many_missing(df)

# %%
# Define columns for different strategies
median_columns = ["Glucose", "BloodPressure"]
knn_columns = ["SkinThickness", "Insulin", "BMI"]

# %% [markdown]
# step 2 - fill missing values using the median of the same class

# %%
# Apply same-class median imputation
def impute_same_class_median(df, columns, class_col="Outcome"):
    for col in columns:
        df[col] = df.groupby(class_col)[col].transform(lambda x: x.fillna(x.median()))
    return df

df = impute_same_class_median(df, median_columns)

# %%
# Apply KNN Imputer for selected columns
def knn_impute(df, columns, n_neighbors=5):
    imputer = KNNImputer(n_neighbors=n_neighbors)
    df[columns] = imputer.fit_transform(df[columns])
    return df

df = knn_impute(df, knn_columns)

# %%
# Normalize features (optional but recommended)
from sklearn.preprocessing import MinMaxScaler


features = df.columns[:-1]  # Exclude Outcome
scaler = MinMaxScaler()
df[features] = scaler.fit_transform(df[features])

# %%
print("✅ Cleaned dataset ready for model:")
display(df.head())
# Out:
# ✅ Cleaned dataset ready for model:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     0.352941  0.670968       0.489796       0.304348  0.213221  0.314928
# 1     0.058824  0.264516       0.428571       0.239130  0.128125  0.171779
# 2     0.470588  0.896774       0.408163       0.106522  0.106010  0.104294
# 3     0.058824  0.290323       0.428571       0.173913  0.096154  0.202454
# 4     0.000000  0.600000       0.163265       0.304348  0.185096  0.509202
#
#    DiabetesPedigreeFunction       Age  Outcome
# 0                  0.234415  0.483333        1
# 1                  0.116567  0.166667        0
# 2                  0.253629  0.183333        1
# 3                  0.038002  0.000000        0
# 4                  0.943638  0.200000        1

# %%
# ----- AFTER preprocessing and missing value handling -----

# Balance the dataset
class_0 = df[df['Outcome'] == 0]
class_1 = df[df['Outcome'] == 1]

min_size = min(len(class_0), len(class_1))
class_0_sampled = class_0.sample(n=min_size, random_state=42)
class_1_sampled = class_1.sample(n=min_size, random_state=42)

balanced_df = pd.concat([class_0_sampled, class_1_sampled], axis=0)
balanced_df = balanced_df.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
X = balanced_df.drop("Outcome", axis=1)
y = balanced_df["Outcome"]

# %% [markdown]
# data split

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# build custom keras model

# %%
model = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    layers.Dropout(0.3),  # Dropout layer to prevent overfitting
    layers.Dense(16, activation='relu'),
    layers.Dense(1, activation='sigmoid')  # Binary output
])

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
#add extra hidden layer and change number of nodes in each layer

# %%
model = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    layers.Dropout(0.3),  # Dropout layer to prevent overfitting
    layers.Dense(16, activation='relu'),
    layers.Dense(1, activation='sigmoid')  # Binary output
])

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
#add extra hidden layer and change number of nodes in each layer

# %%
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_24 (Dense)            (None, 64)                576
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_25 (Dense)            (None, 16)                1040
#
#  dense_26 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 1,633
# Trainable params: 1,633
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Train the model

# %%
history = model.fit(X_train, y_train, epochs=100, batch_size=16, validation_split=0.1, verbose=2) #change validation0split from 0.2-> 0.1
# Out:
# Epoch 1/100
# 24/24 - 6s - loss: 0.6924 - accuracy: 0.4844 - val_loss: 0.6736 - val_accuracy: 0.6047 - 6s/epoch - 243ms/step
# Epoch 2/100
# 24/24 - 0s - loss: 0.6821 - accuracy: 0.5234 - val_loss: 0.6649 - val_accuracy: 0.6279 - 374ms/epoch - 16ms/step
# Epoch 3/100
# 24/24 - 0s - loss: 0.6782 - accuracy: 0.5391 - val_loss: 0.6500 - val_accuracy: 0.7209 - 289ms/epoch - 12ms/step
# Epoch 4/100
# 24/24 - 0s - loss: 0.6758 - accuracy: 0.5677 - val_loss: 0.6372 - val_accuracy: 0.8140 - 363ms/epoch - 15ms/step
# Epoch 5/100
# 24/24 - 0s - loss: 0.6673 - accuracy: 0.6510 - val_loss: 0.6235 - val_accuracy: 0.8372 - 356ms/epoch - 15ms/step
# Epoch 6/100
# 24/24 - 0s - loss: 0.6502 - accuracy: 0.6953 - val_loss: 0.6069 - val_accuracy: 0.8372 - 271ms/epoch - 11ms/step
# Epoch 7/100
# 24/24 - 0s - loss: 0.6428 - accuracy: 0.7005 - val_loss: 0.5927 - val_accuracy: 0.8605 - 234ms/epoch - 10ms/step
# Epoch 8/100
# 24/24 - 0s - loss: 0.6290 - accuracy: 0.6927 - val_loss: 0.5674 - val_accuracy: 0.8605 - 248ms/epoch - 10ms/step
# Epoch 9/100
# 24/24 - 0s - loss: 0.6052 - accuracy: 0.7292 - val_loss: 0.5410 - val_accuracy: 0.8372 - 321ms/epoch - 13ms/step
# Epoch 10/100
# 24/24 - 0s - loss: 0.5985 - accuracy: 0.7240 - val_loss: 0.5206 - val_accuracy: 0.8605 - 261ms/epoch - 11ms/step
# Epoch 11/100
# 24/24 - 0s - loss: 0.5704 - accuracy: 0.7500 - val_loss: 0.4900 - val_accuracy: 0.8605 - 311ms/epoch - 13ms/step
# Epoch 12/100
# 24/24 - 0s - loss: 0.5741 - accuracy: 0.7448 - val_loss: 0.5110 - val_accuracy: 0.7442 - 284ms/epoch - 12ms/step
# Epoch 13/100
# 24/24 - 0s - loss: 0.5561 - accuracy: 0.7552 - val_loss: 0.4559 - val_accuracy: 0.9070 - 311ms/epoch - 13ms/step
# Epoch 14/100
# 24/24 - 0s - loss: 0.5522 - accuracy: 0.7292 - val_loss: 0.4637 - val_accuracy: 0.8372 - 318ms/epoch - 13ms/step
# Epoch 15/100
# 24/24 - 0s - loss: 0.5426 - accuracy: 0.7240 - val_loss: 0.4493 - val_accuracy: 0.8605 - 339ms/epoch - 14ms/step
# Epoch 16/100
# 24/24 - 0s - loss: 0.5276 - accuracy: 0.7578 - val_loss: 0.4365 - val_accuracy: 0.8605 - 327ms/epoch - 14ms/step
# Epoch 17/100
# 24/24 - 0s - loss: 0.5294 - accuracy: 0.7240 - val_loss: 0.4370 - val_accuracy: 0.8605 - 419ms/epoch - 17ms/step
# Epoch 18/100
# 24/24 - 0s - loss: 0.5225 - accuracy: 0.7396 - val_loss: 0.4318 - val_accuracy: 0.8605 - 341ms/epoch - 14ms/step
# Epoch 19/100
# 24/24 - 0s - loss: 0.5273 - accuracy: 0.7474 - val_loss: 0.4266 - val_accuracy: 0.8605 - 339ms/epoch - 14ms/step
# Epoch 20/100
# 24/24 - 0s - loss: 0.5147 - accuracy: 0.7240 - val_loss: 0.4206 - val_accuracy: 0.8605 - 261ms/epoch - 11ms/step
# Epoch 21/100
# 24/24 - 0s - loss: 0.5241 - accuracy: 0.7266 - val_loss: 0.4387 - val_accuracy: 0.8140 - 359ms/epoch - 15ms/step
# Epoch 22/100
# 24/24 - 0s - loss: 0.5083 - accuracy: 0.7292 - val_loss: 0.4048 - val_accuracy: 0.8837 - 402ms/epoch - 17ms/step
# Epoch 23/100
# 24/24 - 0s - loss: 0.5007 - accuracy: 0.7552 - val_loss: 0.4225 - val_accuracy: 0.8140 - 406ms/epoch - 17ms/step
# Epoch 24/100
# 24/24 - 0s - loss: 0.5058 - accuracy: 0.7500 - val_loss: 0.4013 - val_accuracy: 0.8837 - 270ms/epoch - 11ms/step
# Epoch 25/100
# 24/24 - 0s - loss: 0.5032 - accuracy: 0.7500 - val_loss: 0.4414 - val_accuracy: 0.7674 - 253ms/epoch - 11ms/step
# Epoch 26/100
# 24/24 - 0s - loss: 0.4930 - accuracy: 0.7578 - val_loss: 0.4113 - val_accuracy: 0.8372 - 386ms/epoch - 16ms/step
# Epoch 27/100
# 24/24 - 0s - loss: 0.4985 - accuracy: 0.7630 - val_loss: 0.4038 - val_accuracy: 0.8605 - 332ms/epoch - 14ms/step
# Epoch 28/100
# 24/24 - 0s - loss: 0.4929 - accuracy: 0.7891 - val_loss: 0.4294 - val_accuracy: 0.7907 - 396ms/epoch - 16ms/step
# Epoch 29/100
# 24/24 - 0s - loss: 0.5107 - accuracy: 0.7474 - val_loss: 0.3911 - val_accuracy: 0.8837 - 314ms/epoch - 13ms/step
# Epoch 30/100
# 24/24 - 0s - loss: 0.4964 - accuracy: 0.7448 - val_loss: 0.4235 - val_accuracy: 0.7907 - 241ms/epoch - 10ms/step
# Epoch 31/100
# 24/24 - 0s - loss: 0.4971 - accuracy: 0.7578 - val_loss: 0.3969 - val_accuracy: 0.8605 - 307ms/epoch - 13ms/step
# Epoch 32/100
# 24/24 - 0s - loss: 0.4947 - accuracy: 0.7526 - val_loss: 0.4081 - val_accuracy: 0.8372 - 346ms/epoch - 14ms/step
# Epoch 33/100
# 24/24 - 0s - loss: 0.4981 - accuracy: 0.7604 - val_loss: 0.3962 - val_accuracy: 0.8605 - 266ms/epoch - 11ms/step
# Epoch 34/100
# 24/24 - 0s - loss: 0.4874 - accuracy: 0.7682 - val_loss: 0.4066 - val_accuracy: 0.8372 - 349ms/epoch - 15ms/step
# Epoch 35/100
# 24/24 - 0s - loss: 0.4923 - accuracy: 0.7630 - val_loss: 0.3956 - val_accuracy: 0.8372 - 344ms/epoch - 14ms/step
# Epoch 36/100
# 24/24 - 0s - loss: 0.4882 - accuracy: 0.7578 - val_loss: 0.3971 - val_accuracy: 0.8605 - 453ms/epoch - 19ms/step
# Epoch 37/100
# 24/24 - 1s - loss: 0.4999 - accuracy: 0.7396 - val_loss: 0.4074 - val_accuracy: 0.8140 - 570ms/epoch - 24ms/step
# Epoch 38/100
# 24/24 - 1s - loss: 0.4913 - accuracy: 0.7682 - val_loss: 0.3930 - val_accuracy: 0.8372 - 534ms/epoch - 22ms/step
# Epoch 39/100
# 24/24 - 1s - loss: 0.4877 - accuracy: 0.7604 - val_loss: 0.4129 - val_accuracy: 0.8140 - 552ms/epoch - 23ms/step
# Epoch 40/100
# 24/24 - 0s - loss: 0.4813 - accuracy: 0.7474 - val_loss: 0.3864 - val_accuracy: 0.8837 - 461ms/epoch - 19ms/step
# Epoch 41/100
# 24/24 - 0s - loss: 0.4959 - accuracy: 0.7526 - val_loss: 0.3991 - val_accuracy: 0.8372 - 463ms/epoch - 19ms/step
# Epoch 42/100
# 24/24 - 0s - loss: 0.4888 - accuracy: 0.7656 - val_loss: 0.3975 - val_accuracy: 0.8372 - 364ms/epoch - 15ms/step
# Epoch 43/100
# 24/24 - 0s - loss: 0.4699 - accuracy: 0.7656 - val_loss: 0.3968 - val_accuracy: 0.8372 - 340ms/epoch - 14ms/step
# Epoch 44/100
# 24/24 - 0s - loss: 0.4835 - accuracy: 0.7656 - val_loss: 0.3832 - val_accuracy: 0.8837 - 308ms/epoch - 13ms/step
# Epoch 45/100
# 24/24 - 0s - loss: 0.4696 - accuracy: 0.7734 - val_loss: 0.3813 - val_accuracy: 0.8837 - 376ms/epoch - 16ms/step
# Epoch 46/100
# 24/24 - 0s - loss: 0.4729 - accuracy: 0.7891 - val_loss: 0.3784 - val_accuracy: 0.8837 - 356ms/epoch - 15ms/step
# Epoch 47/100
# 24/24 - 1s - loss: 0.4679 - accuracy: 0.7656 - val_loss: 0.3872 - val_accuracy: 0.8605 - 504ms/epoch - 21ms/step
# Epoch 48/100
# 24/24 - 0s - loss: 0.4801 - accuracy: 0.7578 - val_loss: 0.3953 - val_accuracy: 0.8605 - 455ms/epoch - 19ms/step
# Epoch 49/100
# 24/24 - 0s - loss: 0.4699 - accuracy: 0.7760 - val_loss: 0.3949 - val_accuracy: 0.8372 - 404ms/epoch - 17ms/step
# Epoch 50/100
# 24/24 - 0s - loss: 0.4944 - accuracy: 0.7604 - val_loss: 0.3811 - val_accuracy: 0.8605 - 378ms/epoch - 16ms/step
# Epoch 51/100
# 24/24 - 0s - loss: 0.4694 - accuracy: 0.7865 - val_loss: 0.3891 - val_accuracy: 0.8605 - 314ms/epoch - 13ms/step
# Epoch 52/100
# 24/24 - 0s - loss: 0.4811 - accuracy: 0.7630 - val_loss: 0.3848 - val_accuracy: 0.8605 - 295ms/epoch - 12ms/step
# Epoch 53/100
# 24/24 - 0s - loss: 0.4706 - accuracy: 0.7786 - val_loss: 0.3873 - val_accuracy: 0.8837 - 238ms/epoch - 10ms/step
# Epoch 54/100
# 24/24 - 0s - loss: 0.4855 - accuracy: 0.7578 - val_loss: 0.3932 - val_accuracy: 0.8372 - 205ms/epoch - 9ms/step
# Epoch 55/100
# 24/24 - 0s - loss: 0.4758 - accuracy: 0.7734 - val_loss: 0.3934 - val_accuracy: 0.8372 - 231ms/epoch - 10ms/step
# Epoch 56/100
# 24/24 - 0s - loss: 0.4641 - accuracy: 0.7682 - val_loss: 0.3761 - val_accuracy: 0.8837 - 267ms/epoch - 11ms/step
# Epoch 57/100
# 24/24 - 0s - loss: 0.4620 - accuracy: 0.7812 - val_loss: 0.3847 - val_accuracy: 0.8605 - 243ms/epoch - 10ms/step
# Epoch 58/100
# 24/24 - 0s - loss: 0.4626 - accuracy: 0.7891 - val_loss: 0.3777 - val_accuracy: 0.8605 - 215ms/epoch - 9ms/step
# Epoch 59/100
# 24/24 - 0s - loss: 0.4632 - accuracy: 0.7656 - val_loss: 0.3844 - val_accuracy: 0.8605 - 180ms/epoch - 8ms/step
# Epoch 60/100
# 24/24 - 0s - loss: 0.4681 - accuracy: 0.7630 - val_loss: 0.3833 - val_accuracy: 0.8372 - 168ms/epoch - 7ms/step
# Epoch 61/100
# 24/24 - 0s - loss: 0.4811 - accuracy: 0.7682 - val_loss: 0.3815 - val_accuracy: 0.8605 - 168ms/epoch - 7ms/step
# Epoch 62/100
# 24/24 - 0s - loss: 0.4675 - accuracy: 0.7812 - val_loss: 0.3803 - val_accuracy: 0.8605 - 217ms/epoch - 9ms/step
# Epoch 63/100
# 24/24 - 0s - loss: 0.4675 - accuracy: 0.7734 - val_loss: 0.3833 - val_accuracy: 0.8605 - 225ms/epoch - 9ms/step
# Epoch 64/100
# 24/24 - 0s - loss: 0.4633 - accuracy: 0.7812 - val_loss: 0.3826 - val_accuracy: 0.8605 - 208ms/epoch - 9ms/step
# Epoch 65/100
# 24/24 - 0s - loss: 0.4574 - accuracy: 0.7839 - val_loss: 0.3739 - val_accuracy: 0.8372 - 240ms/epoch - 10ms/step
# Epoch 66/100
# 24/24 - 0s - loss: 0.4787 - accuracy: 0.7708 - val_loss: 0.3821 - val_accuracy: 0.8605 - 248ms/epoch - 10ms/step
# Epoch 67/100
# 24/24 - 0s - loss: 0.4491 - accuracy: 0.7812 - val_loss: 0.3732 - val_accuracy: 0.8372 - 220ms/epoch - 9ms/step
# Epoch 68/100
# 24/24 - 0s - loss: 0.4769 - accuracy: 0.7630 - val_loss: 0.3737 - val_accuracy: 0.8372 - 200ms/epoch - 8ms/step
# Epoch 69/100
# 24/24 - 0s - loss: 0.4585 - accuracy: 0.7839 - val_loss: 0.3695 - val_accuracy: 0.8605 - 172ms/epoch - 7ms/step
# Epoch 70/100
# 24/24 - 0s - loss: 0.4537 - accuracy: 0.7969 - val_loss: 0.3870 - val_accuracy: 0.8372 - 162ms/epoch - 7ms/step
# Epoch 71/100
# 24/24 - 0s - loss: 0.4553 - accuracy: 0.7682 - val_loss: 0.3749 - val_accuracy: 0.8605 - 206ms/epoch - 9ms/step
# Epoch 72/100
# 24/24 - 0s - loss: 0.4673 - accuracy: 0.7760 - val_loss: 0.3680 - val_accuracy: 0.8372 - 188ms/epoch - 8ms/step
# Epoch 73/100
# 24/24 - 0s - loss: 0.4673 - accuracy: 0.7839 - val_loss: 0.3776 - val_accuracy: 0.8605 - 166ms/epoch - 7ms/step
# Epoch 74/100
# 24/24 - 0s - loss: 0.4612 - accuracy: 0.7708 - val_loss: 0.3807 - val_accuracy: 0.8605 - 143ms/epoch - 6ms/step
# Epoch 75/100
# 24/24 - 0s - loss: 0.4563 - accuracy: 0.7708 - val_loss: 0.3722 - val_accuracy: 0.8372 - 149ms/epoch - 6ms/step
# Epoch 76/100
# 24/24 - 0s - loss: 0.4634 - accuracy: 0.7865 - val_loss: 0.3706 - val_accuracy: 0.8372 - 149ms/epoch - 6ms/step
# Epoch 77/100
# 24/24 - 0s - loss: 0.4583 - accuracy: 0.7812 - val_loss: 0.3777 - val_accuracy: 0.8372 - 156ms/epoch - 7ms/step
# Epoch 78/100
# 24/24 - 0s - loss: 0.4545 - accuracy: 0.7891 - val_loss: 0.3699 - val_accuracy: 0.8140 - 134ms/epoch - 6ms/step
# Epoch 79/100
# 24/24 - 0s - loss: 0.4650 - accuracy: 0.7656 - val_loss: 0.3809 - val_accuracy: 0.8605 - 130ms/epoch - 5ms/step
# Epoch 80/100
# 24/24 - 0s - loss: 0.4506 - accuracy: 0.7812 - val_loss: 0.3755 - val_accuracy: 0.8605 - 133ms/epoch - 6ms/step
# Epoch 81/100
# 24/24 - 0s - loss: 0.4397 - accuracy: 0.7969 - val_loss: 0.3708 - val_accuracy: 0.8372 - 139ms/epoch - 6ms/step
# Epoch 82/100
# 24/24 - 0s - loss: 0.4492 - accuracy: 0.7786 - val_loss: 0.3723 - val_accuracy: 0.8372 - 143ms/epoch - 6ms/step
# Epoch 83/100
# 24/24 - 0s - loss: 0.4545 - accuracy: 0.7786 - val_loss: 0.3727 - val_accuracy: 0.8372 - 138ms/epoch - 6ms/step
# Epoch 84/100
# 24/24 - 0s - loss: 0.4608 - accuracy: 0.7839 - val_loss: 0.3718 - val_accuracy: 0.8605 - 135ms/epoch - 6ms/step
# Epoch 85/100
# 24/24 - 0s - loss: 0.4459 - accuracy: 0.7865 - val_loss: 0.3708 - val_accuracy: 0.8372 - 135ms/epoch - 6ms/step
# Epoch 86/100
# 24/24 - 0s - loss: 0.4528 - accuracy: 0.7708 - val_loss: 0.3796 - val_accuracy: 0.8605 - 133ms/epoch - 6ms/step
# Epoch 87/100
# 24/24 - 0s - loss: 0.4474 - accuracy: 0.7734 - val_loss: 0.3693 - val_accuracy: 0.8140 - 132ms/epoch - 6ms/step
# Epoch 88/100
# 24/24 - 0s - loss: 0.4324 - accuracy: 0.7839 - val_loss: 0.3759 - val_accuracy: 0.8605 - 130ms/epoch - 5ms/step
# Epoch 89/100
# 24/24 - 0s - loss: 0.4379 - accuracy: 0.7786 - val_loss: 0.3732 - val_accuracy: 0.8605 - 130ms/epoch - 5ms/step
# Epoch 90/100
# 24/24 - 0s - loss: 0.4528 - accuracy: 0.7760 - val_loss: 0.3673 - val_accuracy: 0.8372 - 139ms/epoch - 6ms/step
# Epoch 91/100
# 24/24 - 0s - loss: 0.4560 - accuracy: 0.7839 - val_loss: 0.3733 - val_accuracy: 0.8605 - 135ms/epoch - 6ms/step
# Epoch 92/100
# 24/24 - 0s - loss: 0.4677 - accuracy: 0.7734 - val_loss: 0.3627 - val_accuracy: 0.8372 - 131ms/epoch - 5ms/step
# Epoch 93/100
# 24/24 - 0s - loss: 0.4467 - accuracy: 0.7812 - val_loss: 0.3695 - val_accuracy: 0.8372 - 126ms/epoch - 5ms/step
# Epoch 94/100
# 24/24 - 0s - loss: 0.4408 - accuracy: 0.7812 - val_loss: 0.3654 - val_accuracy: 0.8372 - 227ms/epoch - 9ms/step
# Epoch 95/100
# 24/24 - 0s - loss: 0.4393 - accuracy: 0.7786 - val_loss: 0.3629 - val_accuracy: 0.8372 - 216ms/epoch - 9ms/step
# Epoch 96/100
# 24/24 - 0s - loss: 0.4384 - accuracy: 0.7839 - val_loss: 0.3582 - val_accuracy: 0.8372 - 250ms/epoch - 10ms/step
# Epoch 97/100
# 24/24 - 0s - loss: 0.4477 - accuracy: 0.7656 - val_loss: 0.3742 - val_accuracy: 0.8605 - 376ms/epoch - 16ms/step
# Epoch 98/100
# 24/24 - 0s - loss: 0.4464 - accuracy: 0.7995 - val_loss: 0.3692 - val_accuracy: 0.8372 - 262ms/epoch - 11ms/step
# Epoch 99/100
# 24/24 - 0s - loss: 0.4600 - accuracy: 0.7734 - val_loss: 0.3607 - val_accuracy: 0.8372 - 278ms/epoch - 12ms/step
# Epoch 100/100
# 24/24 - 0s - loss: 0.4434 - accuracy: 0.7969 - val_loss: 0.3619 - val_accuracy: 0.8372 - 264ms/epoch - 11ms/step

# %% [markdown]
# Evaluate the model

# %%
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, confusion_matrix, classification_report
)

# Predict probabilities
y_pred_prob = model.predict(X_test).ravel()

# Convert to binary output
y_pred = (y_pred_prob >= 0.5).astype(int)

# Classification report
print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))

# Confusion Matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# Predict probabilities and convert to binary
y_pred_prob = model.predict(X_test).ravel()
y_pred = (y_pred_prob >= 0.5).astype(int)

# Generate confusion matrix
cm = confusion_matrix(y_test, y_pred)
labels = ['No Diabetes', 'Diabetes']

# Plot
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)

plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.tight_layout()
plt.show()


# Individual metrics
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall:", recall_score(y_test, y_pred))
print("F1 Score:", f1_score(y_test, y_pred))
# Out:
# 4/4 [==============================] - 0s 4ms/step
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.73      0.64      0.69        56
#            1       0.66      0.75      0.70        51
#
#     accuracy                           0.69       107
#    macro avg       0.69      0.69      0.69       107
# weighted avg       0.70      0.69      0.69       107
#
# 4/4 [==============================] - 0s 4ms/step
# Accuracy: 0.6915887850467289
# Precision: 0.6551724137931034
# Recall: 0.7450980392156863
# F1 Score: 0.6972477064220184

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot training & validation loss
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
