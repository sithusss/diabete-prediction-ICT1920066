# %%
# %pip install tensorflow seaborn


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.impute import KNNImputer
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_curve, auc

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# Out:
# [notice] A new release of pip available: 22.2.2 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: tensorflow in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (2.10.1)
# Requirement already satisfied: seaborn in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (0.13.2)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (4.11.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (1.64.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (0.31.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (2.10.1)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: setuptools in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (69.5.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: numpy>=1.20 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (3.19.6)
# Requirement already satisfied: packaging in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (23.2)
# Requirement already satisfied: keras<2.11,>=2.10.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from seaborn) (3.9.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pillow>=8 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (3.6)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.32.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.29.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (3.0.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.4.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (5.3.3)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (2.0.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2024.8.30)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (3.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (0.13.0)
# Requirement already satisfied: joblib<2,>=1.1.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from imbalanced-learn) (1.4.2)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from imbalanced-learn) (0.1.3)
# Requirement already satisfied: numpy<3,>=1.24.3 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from imbalanced-learn) (1.26.4)
# Requirement already satisfied: scikit-learn<2,>=1.3.2 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from imbalanced-learn) (1.5.0)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from imbalanced-learn) (3.5.0)
# Requirement already satisfied: scipy<2,>=1.10.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from imbalanced-learn) (1.13.1)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# load dataset

# %%
# Load Pima Indian Diabetes dataset
df = pd.read_csv("F:/RUSL/4- 1/ICT 4302 - Intelligent Systems/miniProject1/diabetes.csv")

df.columns = df.columns.str.strip()  # Clean header spaces
for col in df.columns:
    if col != 'Outcome':
        df[col] = pd.to_numeric(df[col], errors='coerce')  # Convert non-numeric to NaN

numeric_df = df.select_dtypes(include=['number'])

df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# Data preprocessing

# %% [markdown]
# step 1 - Replace invalid zeros with NaN (handle missing values)

# %%
cols_with_missing = ["Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI"]

# Replace 0 with np.nan only for these features
df[cols_with_missing] = df[cols_with_missing].replace(0, np.nan)

# %%
# Remove rows with too many missing values
def drop_rows_with_many_missing(df, threshold_cols=4):
    return df[df[cols_with_missing].isnull().sum(axis=1) < threshold_cols]

df = drop_rows_with_many_missing(df)

# %%
# Define columns for different strategies
median_columns = ["Glucose", "BloodPressure"]
knn_columns = ["SkinThickness", "Insulin", "BMI"]

# %% [markdown]
# step 2 - fill missing values using the median of the same class

# %%
# Apply same-class median imputation
def impute_same_class_median(df, columns, class_col="Outcome"):
    for col in columns:
        df[col] = df.groupby(class_col)[col].transform(lambda x: x.fillna(x.median()))
    return df

df = impute_same_class_median(df, median_columns)

# %%
# Apply KNN Imputer for selected columns
def knn_impute(df, columns, n_neighbors=5):
    imputer = KNNImputer(n_neighbors=n_neighbors)
    df[columns] = imputer.fit_transform(df[columns])
    return df

df = knn_impute(df, knn_columns)

# %%
# Normalize features (optional but recommended)
from sklearn.preprocessing import MinMaxScaler


features = df.columns[:-1]  # Exclude Outcome
scaler = MinMaxScaler()
df[features] = scaler.fit_transform(df[features])

# %%
print("✅ Cleaned dataset ready for model:")
display(df.head())
# Out:
# ✅ Cleaned dataset ready for model:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     0.352941  0.670968       0.489796       0.304348  0.213221  0.314928
# 1     0.058824  0.264516       0.428571       0.239130  0.128125  0.171779
# 2     0.470588  0.896774       0.408163       0.106522  0.106010  0.104294
# 3     0.058824  0.290323       0.428571       0.173913  0.096154  0.202454
# 4     0.000000  0.600000       0.163265       0.304348  0.185096  0.509202
#
#    DiabetesPedigreeFunction       Age  Outcome
# 0                  0.234415  0.483333        1
# 1                  0.116567  0.166667        0
# 2                  0.253629  0.183333        1
# 3                  0.038002  0.000000        0
# 4                  0.943638  0.200000        1

# %%
# Step 1: Split features and labels
X = df.drop("Outcome", axis=1)
y = df["Outcome"]

# Step 2: Apply SMOTE
from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state=42)
X_resampled, y_resampled = sm.fit_resample(X, y)

# %% [markdown]
# data split

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.1)

# %% [markdown]
# build custom keras model

# %%
model = keras.Sequential([
    layers.Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    layers.Dropout(0.1),
    layers.Dense(64, activation='relu'),
    layers.Dense(32, activation='relu'),
    layers.Dense(16, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='RMSprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])
#add extra hidden layer and change number of nodes in each layer

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_23 (Dense)            (None, 128)               1152
#
#  dropout_7 (Dropout)         (None, 128)               0
#
#  dense_24 (Dense)            (None, 64)                8256
#
#  dropout_8 (Dropout)         (None, 64)                0
#
#  dense_25 (Dense)            (None, 32)                2080
#
#  dense_26 (Dense)            (None, 16)                528
#
#  dense_27 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 12,033
# Trainable params: 12,033
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Train the model

# %%
history = model.fit(X_train, y_train, epochs=100, batch_size=16, validation_split=0.2, verbose=2) #change validation split from 0.2-> 0.1
# Out:
# Epoch 1/100
# 45/45 - 2s - loss: 0.6735 - accuracy: 0.5809 - val_loss: 0.6318 - val_accuracy: 0.7753 - 2s/epoch - 51ms/step
# Epoch 2/100
# 45/45 - 1s - loss: 0.6170 - accuracy: 0.7145 - val_loss: 0.5468 - val_accuracy: 0.7697 - 755ms/epoch - 17ms/step
# Epoch 3/100
# 45/45 - 1s - loss: 0.5858 - accuracy: 0.7159 - val_loss: 0.5036 - val_accuracy: 0.7753 - 718ms/epoch - 16ms/step
# Epoch 4/100
# 45/45 - 1s - loss: 0.5562 - accuracy: 0.7243 - val_loss: 0.4850 - val_accuracy: 0.7640 - 771ms/epoch - 17ms/step
# Epoch 5/100
# 45/45 - 1s - loss: 0.5370 - accuracy: 0.7370 - val_loss: 0.4562 - val_accuracy: 0.7921 - 683ms/epoch - 15ms/step
# Epoch 6/100
# 45/45 - 1s - loss: 0.5111 - accuracy: 0.7511 - val_loss: 0.4636 - val_accuracy: 0.7472 - 667ms/epoch - 15ms/step
# Epoch 7/100
# 45/45 - 1s - loss: 0.5290 - accuracy: 0.7370 - val_loss: 0.4445 - val_accuracy: 0.7978 - 703ms/epoch - 16ms/step
# Epoch 8/100
# 45/45 - 1s - loss: 0.5014 - accuracy: 0.7651 - val_loss: 0.4788 - val_accuracy: 0.7528 - 718ms/epoch - 16ms/step
# Epoch 9/100
# 45/45 - 1s - loss: 0.5027 - accuracy: 0.7581 - val_loss: 0.4224 - val_accuracy: 0.8202 - 839ms/epoch - 19ms/step
# Epoch 10/100
# 45/45 - 1s - loss: 0.5018 - accuracy: 0.7468 - val_loss: 0.4377 - val_accuracy: 0.7978 - 784ms/epoch - 17ms/step
# Epoch 11/100
# 45/45 - 1s - loss: 0.4992 - accuracy: 0.7525 - val_loss: 0.4238 - val_accuracy: 0.8034 - 656ms/epoch - 15ms/step
# Epoch 12/100
# 45/45 - 1s - loss: 0.4875 - accuracy: 0.7511 - val_loss: 0.4340 - val_accuracy: 0.8146 - 649ms/epoch - 14ms/step
# Epoch 13/100
# 45/45 - 1s - loss: 0.4842 - accuracy: 0.7820 - val_loss: 0.4202 - val_accuracy: 0.8315 - 624ms/epoch - 14ms/step
# Epoch 14/100
# 45/45 - 1s - loss: 0.4737 - accuracy: 0.7918 - val_loss: 0.4311 - val_accuracy: 0.8146 - 611ms/epoch - 14ms/step
# Epoch 15/100
# 45/45 - 1s - loss: 0.4852 - accuracy: 0.7750 - val_loss: 0.4141 - val_accuracy: 0.8090 - 703ms/epoch - 16ms/step
# Epoch 16/100
# 45/45 - 1s - loss: 0.4714 - accuracy: 0.7834 - val_loss: 0.4114 - val_accuracy: 0.8146 - 598ms/epoch - 13ms/step
# Epoch 17/100
# 45/45 - 1s - loss: 0.4748 - accuracy: 0.7693 - val_loss: 0.4017 - val_accuracy: 0.8090 - 610ms/epoch - 14ms/step
# Epoch 18/100
# 45/45 - 1s - loss: 0.4696 - accuracy: 0.7904 - val_loss: 0.4120 - val_accuracy: 0.8146 - 630ms/epoch - 14ms/step
# Epoch 19/100
# 45/45 - 1s - loss: 0.4689 - accuracy: 0.7722 - val_loss: 0.4073 - val_accuracy: 0.8258 - 635ms/epoch - 14ms/step
# Epoch 20/100
# 45/45 - 1s - loss: 0.4610 - accuracy: 0.7975 - val_loss: 0.4041 - val_accuracy: 0.8202 - 608ms/epoch - 14ms/step
# Epoch 21/100
# 45/45 - 1s - loss: 0.4719 - accuracy: 0.7834 - val_loss: 0.4029 - val_accuracy: 0.8371 - 635ms/epoch - 14ms/step
# Epoch 22/100
# 45/45 - 1s - loss: 0.4656 - accuracy: 0.7876 - val_loss: 0.4110 - val_accuracy: 0.8202 - 612ms/epoch - 14ms/step
# Epoch 23/100
# 45/45 - 1s - loss: 0.4722 - accuracy: 0.7764 - val_loss: 0.4028 - val_accuracy: 0.8202 - 551ms/epoch - 12ms/step
# Epoch 24/100
# 45/45 - 1s - loss: 0.4547 - accuracy: 0.8003 - val_loss: 0.4315 - val_accuracy: 0.8146 - 581ms/epoch - 13ms/step
# Epoch 25/100
# 45/45 - 1s - loss: 0.4584 - accuracy: 0.7806 - val_loss: 0.4087 - val_accuracy: 0.8202 - 545ms/epoch - 12ms/step
# Epoch 26/100
# 45/45 - 1s - loss: 0.4400 - accuracy: 0.7918 - val_loss: 0.3907 - val_accuracy: 0.8202 - 584ms/epoch - 13ms/step
# Epoch 27/100
# 45/45 - 1s - loss: 0.4686 - accuracy: 0.7806 - val_loss: 0.3937 - val_accuracy: 0.8371 - 564ms/epoch - 13ms/step
# Epoch 28/100
# 45/45 - 1s - loss: 0.4572 - accuracy: 0.7862 - val_loss: 0.4196 - val_accuracy: 0.8090 - 674ms/epoch - 15ms/step
# Epoch 29/100
# 45/45 - 1s - loss: 0.4643 - accuracy: 0.7918 - val_loss: 0.4041 - val_accuracy: 0.8315 - 720ms/epoch - 16ms/step
# Epoch 30/100
# 45/45 - 1s - loss: 0.4492 - accuracy: 0.8031 - val_loss: 0.4142 - val_accuracy: 0.8427 - 759ms/epoch - 17ms/step
# Epoch 31/100
# 45/45 - 1s - loss: 0.4548 - accuracy: 0.7947 - val_loss: 0.3906 - val_accuracy: 0.8315 - 683ms/epoch - 15ms/step
# Epoch 32/100
# 45/45 - 1s - loss: 0.4484 - accuracy: 0.7932 - val_loss: 0.4130 - val_accuracy: 0.8146 - 702ms/epoch - 16ms/step
# Epoch 33/100
# 45/45 - 1s - loss: 0.4503 - accuracy: 0.7989 - val_loss: 0.3998 - val_accuracy: 0.8258 - 698ms/epoch - 16ms/step
# Epoch 34/100
# 45/45 - 1s - loss: 0.4390 - accuracy: 0.8031 - val_loss: 0.3916 - val_accuracy: 0.8427 - 712ms/epoch - 16ms/step
# Epoch 35/100
# 45/45 - 1s - loss: 0.4439 - accuracy: 0.7989 - val_loss: 0.3840 - val_accuracy: 0.8427 - 679ms/epoch - 15ms/step
# Epoch 36/100
# 45/45 - 1s - loss: 0.4410 - accuracy: 0.7947 - val_loss: 0.3942 - val_accuracy: 0.8539 - 675ms/epoch - 15ms/step
# Epoch 37/100
# 45/45 - 1s - loss: 0.4469 - accuracy: 0.7947 - val_loss: 0.4135 - val_accuracy: 0.8202 - 749ms/epoch - 17ms/step
# Epoch 38/100
# 45/45 - 1s - loss: 0.4415 - accuracy: 0.7947 - val_loss: 0.3940 - val_accuracy: 0.8427 - 864ms/epoch - 19ms/step
# Epoch 39/100
# 45/45 - 1s - loss: 0.4402 - accuracy: 0.7918 - val_loss: 0.3777 - val_accuracy: 0.8483 - 961ms/epoch - 21ms/step
# Epoch 40/100
# 45/45 - 1s - loss: 0.4408 - accuracy: 0.7961 - val_loss: 0.3884 - val_accuracy: 0.8483 - 656ms/epoch - 15ms/step
# Epoch 41/100
# 45/45 - 1s - loss: 0.4410 - accuracy: 0.8003 - val_loss: 0.3945 - val_accuracy: 0.8427 - 577ms/epoch - 13ms/step
# Epoch 42/100
# 45/45 - 1s - loss: 0.4453 - accuracy: 0.7876 - val_loss: 0.3923 - val_accuracy: 0.8483 - 708ms/epoch - 16ms/step
# Epoch 43/100
# 45/45 - 1s - loss: 0.4355 - accuracy: 0.7989 - val_loss: 0.3869 - val_accuracy: 0.8258 - 847ms/epoch - 19ms/step
# Epoch 44/100
# 45/45 - 1s - loss: 0.4304 - accuracy: 0.8003 - val_loss: 0.3842 - val_accuracy: 0.8315 - 801ms/epoch - 18ms/step
# Epoch 45/100
# 45/45 - 1s - loss: 0.4289 - accuracy: 0.7947 - val_loss: 0.4521 - val_accuracy: 0.7640 - 646ms/epoch - 14ms/step
# Epoch 46/100
# 45/45 - 1s - loss: 0.4371 - accuracy: 0.7848 - val_loss: 0.3768 - val_accuracy: 0.8483 - 585ms/epoch - 13ms/step
# Epoch 47/100
# 45/45 - 1s - loss: 0.4285 - accuracy: 0.7947 - val_loss: 0.3970 - val_accuracy: 0.8427 - 565ms/epoch - 13ms/step
# Epoch 48/100
# 45/45 - 1s - loss: 0.4254 - accuracy: 0.8143 - val_loss: 0.4582 - val_accuracy: 0.7865 - 556ms/epoch - 12ms/step
# Epoch 49/100
# 45/45 - 1s - loss: 0.4287 - accuracy: 0.8003 - val_loss: 0.3862 - val_accuracy: 0.8202 - 582ms/epoch - 13ms/step
# Epoch 50/100
# 45/45 - 1s - loss: 0.4314 - accuracy: 0.8031 - val_loss: 0.4183 - val_accuracy: 0.8202 - 557ms/epoch - 12ms/step
# Epoch 51/100
# 45/45 - 1s - loss: 0.4330 - accuracy: 0.8059 - val_loss: 0.3780 - val_accuracy: 0.8427 - 563ms/epoch - 13ms/step
# Epoch 52/100
# 45/45 - 1s - loss: 0.4191 - accuracy: 0.8059 - val_loss: 0.3785 - val_accuracy: 0.8427 - 558ms/epoch - 12ms/step
# Epoch 53/100
# 45/45 - 1s - loss: 0.4302 - accuracy: 0.8017 - val_loss: 0.3807 - val_accuracy: 0.8427 - 559ms/epoch - 12ms/step
# Epoch 54/100
# 45/45 - 1s - loss: 0.4237 - accuracy: 0.8031 - val_loss: 0.3854 - val_accuracy: 0.8539 - 629ms/epoch - 14ms/step
# Epoch 55/100
# 45/45 - 1s - loss: 0.4258 - accuracy: 0.8101 - val_loss: 0.4013 - val_accuracy: 0.8258 - 528ms/epoch - 12ms/step
# Epoch 56/100
# 45/45 - 1s - loss: 0.4170 - accuracy: 0.8031 - val_loss: 0.3902 - val_accuracy: 0.8371 - 567ms/epoch - 13ms/step
# Epoch 57/100
# 45/45 - 1s - loss: 0.4383 - accuracy: 0.7947 - val_loss: 0.4061 - val_accuracy: 0.8258 - 551ms/epoch - 12ms/step
# Epoch 58/100
# 45/45 - 1s - loss: 0.4180 - accuracy: 0.8158 - val_loss: 0.3744 - val_accuracy: 0.8371 - 676ms/epoch - 15ms/step
# Epoch 59/100
# 45/45 - 1s - loss: 0.4119 - accuracy: 0.8200 - val_loss: 0.3833 - val_accuracy: 0.8315 - 612ms/epoch - 14ms/step
# Epoch 60/100
# 45/45 - 1s - loss: 0.4123 - accuracy: 0.8270 - val_loss: 0.5315 - val_accuracy: 0.7753 - 687ms/epoch - 15ms/step
# Epoch 61/100
# 45/45 - 1s - loss: 0.4133 - accuracy: 0.8186 - val_loss: 0.4179 - val_accuracy: 0.8202 - 827ms/epoch - 18ms/step
# Epoch 62/100
# 45/45 - 1s - loss: 0.4264 - accuracy: 0.8158 - val_loss: 0.3789 - val_accuracy: 0.8371 - 699ms/epoch - 16ms/step
# Epoch 63/100
# 45/45 - 1s - loss: 0.4075 - accuracy: 0.8200 - val_loss: 0.3927 - val_accuracy: 0.8483 - 916ms/epoch - 20ms/step
# Epoch 64/100
# 45/45 - 1s - loss: 0.4196 - accuracy: 0.8115 - val_loss: 0.3853 - val_accuracy: 0.8258 - 885ms/epoch - 20ms/step
# Epoch 65/100
# 45/45 - 1s - loss: 0.4181 - accuracy: 0.8087 - val_loss: 0.3890 - val_accuracy: 0.8483 - 700ms/epoch - 16ms/step
# Epoch 66/100
# 45/45 - 1s - loss: 0.4086 - accuracy: 0.8087 - val_loss: 0.3755 - val_accuracy: 0.8315 - 707ms/epoch - 16ms/step
# Epoch 67/100
# 45/45 - 1s - loss: 0.4116 - accuracy: 0.8059 - val_loss: 0.3859 - val_accuracy: 0.8371 - 719ms/epoch - 16ms/step
# Epoch 68/100
# 45/45 - 1s - loss: 0.4104 - accuracy: 0.8087 - val_loss: 0.3790 - val_accuracy: 0.8539 - 667ms/epoch - 15ms/step
# Epoch 69/100
# 45/45 - 1s - loss: 0.3999 - accuracy: 0.8298 - val_loss: 0.3755 - val_accuracy: 0.8483 - 725ms/epoch - 16ms/step
# Epoch 70/100
# 45/45 - 1s - loss: 0.4194 - accuracy: 0.8129 - val_loss: 0.3776 - val_accuracy: 0.8483 - 630ms/epoch - 14ms/step
# Epoch 71/100
# 45/45 - 1s - loss: 0.3954 - accuracy: 0.8340 - val_loss: 0.3778 - val_accuracy: 0.8539 - 663ms/epoch - 15ms/step
# Epoch 72/100
# 45/45 - 1s - loss: 0.4134 - accuracy: 0.8284 - val_loss: 0.3746 - val_accuracy: 0.8539 - 637ms/epoch - 14ms/step
# Epoch 73/100
# 45/45 - 1s - loss: 0.4137 - accuracy: 0.8031 - val_loss: 0.3745 - val_accuracy: 0.8258 - 632ms/epoch - 14ms/step
# Epoch 74/100
# 45/45 - 1s - loss: 0.4082 - accuracy: 0.8143 - val_loss: 0.4350 - val_accuracy: 0.7865 - 647ms/epoch - 14ms/step
# Epoch 75/100
# 45/45 - 1s - loss: 0.4042 - accuracy: 0.8172 - val_loss: 0.3801 - val_accuracy: 0.8427 - 695ms/epoch - 15ms/step
# Epoch 76/100
# 45/45 - 1s - loss: 0.3920 - accuracy: 0.8284 - val_loss: 0.3763 - val_accuracy: 0.8427 - 639ms/epoch - 14ms/step
# Epoch 77/100
# 45/45 - 1s - loss: 0.3954 - accuracy: 0.8284 - val_loss: 0.4042 - val_accuracy: 0.8202 - 636ms/epoch - 14ms/step
# Epoch 78/100
# 45/45 - 1s - loss: 0.4108 - accuracy: 0.8158 - val_loss: 0.4256 - val_accuracy: 0.7865 - 591ms/epoch - 13ms/step
# Epoch 79/100
# 45/45 - 1s - loss: 0.3969 - accuracy: 0.8228 - val_loss: 0.4968 - val_accuracy: 0.7865 - 593ms/epoch - 13ms/step
# Epoch 80/100
# 45/45 - 1s - loss: 0.4072 - accuracy: 0.8186 - val_loss: 0.3821 - val_accuracy: 0.8371 - 631ms/epoch - 14ms/step
# Epoch 81/100
# 45/45 - 1s - loss: 0.3929 - accuracy: 0.8326 - val_loss: 0.3881 - val_accuracy: 0.8315 - 737ms/epoch - 16ms/step
# Epoch 82/100
# 45/45 - 1s - loss: 0.3928 - accuracy: 0.8129 - val_loss: 0.3772 - val_accuracy: 0.8427 - 633ms/epoch - 14ms/step
# Epoch 83/100
# 45/45 - 1s - loss: 0.4014 - accuracy: 0.8242 - val_loss: 0.3699 - val_accuracy: 0.8371 - 593ms/epoch - 13ms/step
# Epoch 84/100
# 45/45 - 1s - loss: 0.4042 - accuracy: 0.8101 - val_loss: 0.3767 - val_accuracy: 0.8371 - 663ms/epoch - 15ms/step
# Epoch 85/100
# 45/45 - 1s - loss: 0.3851 - accuracy: 0.8242 - val_loss: 0.3764 - val_accuracy: 0.8315 - 621ms/epoch - 14ms/step
# Epoch 86/100
# 45/45 - 1s - loss: 0.3867 - accuracy: 0.8481 - val_loss: 0.3845 - val_accuracy: 0.8371 - 582ms/epoch - 13ms/step
# Epoch 87/100
# 45/45 - 1s - loss: 0.3856 - accuracy: 0.8383 - val_loss: 0.3810 - val_accuracy: 0.8315 - 563ms/epoch - 13ms/step
# Epoch 88/100
# 45/45 - 1s - loss: 0.3728 - accuracy: 0.8523 - val_loss: 0.3832 - val_accuracy: 0.8427 - 575ms/epoch - 13ms/step
# Epoch 89/100
# 45/45 - 1s - loss: 0.3921 - accuracy: 0.8256 - val_loss: 0.3768 - val_accuracy: 0.8258 - 565ms/epoch - 13ms/step
# Epoch 90/100
# 45/45 - 1s - loss: 0.3747 - accuracy: 0.8312 - val_loss: 0.4417 - val_accuracy: 0.7753 - 567ms/epoch - 13ms/step
# Epoch 91/100
# 45/45 - 1s - loss: 0.3902 - accuracy: 0.8383 - val_loss: 0.3776 - val_accuracy: 0.8315 - 573ms/epoch - 13ms/step
# Epoch 92/100
# 45/45 - 1s - loss: 0.3820 - accuracy: 0.8284 - val_loss: 0.3872 - val_accuracy: 0.8258 - 593ms/epoch - 13ms/step
# Epoch 93/100
# 45/45 - 1s - loss: 0.3777 - accuracy: 0.8425 - val_loss: 0.3940 - val_accuracy: 0.8371 - 572ms/epoch - 13ms/step
# Epoch 94/100
# 45/45 - 1s - loss: 0.3841 - accuracy: 0.8354 - val_loss: 0.3766 - val_accuracy: 0.8202 - 585ms/epoch - 13ms/step
# Epoch 95/100
# 45/45 - 1s - loss: 0.3742 - accuracy: 0.8439 - val_loss: 0.3784 - val_accuracy: 0.8258 - 552ms/epoch - 12ms/step
# Epoch 96/100
# 45/45 - 1s - loss: 0.3748 - accuracy: 0.8368 - val_loss: 0.3970 - val_accuracy: 0.8315 - 594ms/epoch - 13ms/step
# Epoch 97/100
# 45/45 - 1s - loss: 0.3797 - accuracy: 0.8340 - val_loss: 0.3815 - val_accuracy: 0.8315 - 560ms/epoch - 12ms/step
# Epoch 98/100
# 45/45 - 1s - loss: 0.3700 - accuracy: 0.8495 - val_loss: 0.3768 - val_accuracy: 0.8258 - 564ms/epoch - 13ms/step
# Epoch 99/100
# 45/45 - 1s - loss: 0.3854 - accuracy: 0.8256 - val_loss: 0.3745 - val_accuracy: 0.8258 - 570ms/epoch - 13ms/step
# Epoch 100/100
# 45/45 - 1s - loss: 0.3681 - accuracy: 0.8354 - val_loss: 0.3857 - val_accuracy: 0.8202 - 566ms/epoch - 13ms/step

# %% [markdown]
# Evaluate the model

# %%
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, confusion_matrix, classification_report
)

# Predict probabilities
y_pred_prob = model.predict(X_test).ravel()

# Convert to binary output
y_pred = (y_pred_prob >= 0.5).astype(int)

# Classification report
print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))

# Confusion Matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# Predict probabilities and convert to binary
y_pred_prob = model.predict(X_test).ravel()
y_pred = (y_pred_prob >= 0.5).astype(int)

# Generate confusion matrix
cm = confusion_matrix(y_test, y_pred)
labels = ['No Diabetes', 'Diabetes']

# Plot
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)

plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.tight_layout()
plt.show()


# Individual metrics
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall:", recall_score(y_test, y_pred))
print("F1 Score:", f1_score(y_test, y_pred))
# Out:
# 4/4 [==============================] - 0s 4ms/step
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.80      0.71      0.75        49
#            1       0.75      0.82      0.78        50
#
#     accuracy                           0.77        99
#    macro avg       0.77      0.77      0.77        99
# weighted avg       0.77      0.77      0.77        99
#
# 4/4 [==============================] - 0s 4ms/step
# Accuracy: 0.7676767676767676
# Precision: 0.7454545454545455
# Recall: 0.82
# F1 Score: 0.780952380952381

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot training & validation loss
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# Predict probabilities for the test set
y_pred_prob = model.predict(X_test).ravel()  # Already flattened

# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)

# Calculate AUC score
auc_score = roc_auc_score(y_test, y_pred_prob)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC Curve (AUC = {auc_score:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')  # Diagonal line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()
# Out:
# 4/4 [==============================] - 0s 4ms/step
