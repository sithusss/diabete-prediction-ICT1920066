# %%
# %pip install tensorflow seaborn


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.impute import KNNImputer
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_curve, auc

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# Out:
# [notice] A new release of pip available: 22.2.2 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: tensorflow in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (2.10.1)
# Requirement already satisfied: seaborn in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (0.13.2)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (1.64.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (0.31.0)
# Requirement already satisfied: packaging in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (23.2)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (2.10.1)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (4.11.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: numpy>=1.20 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: setuptools in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (69.5.1)
# Requirement already satisfied: keras<2.11,>=2.10.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (3.19.6)
# Requirement already satisfied: pandas>=1.2 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from seaborn) (3.9.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: pillow>=8 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (3.6)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.32.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.6.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.29.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (3.0.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (5.3.3)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.4.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2024.8.30)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2.2.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (3.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (0.13.0)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from imbalanced-learn) (0.1.3)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from imbalanced-learn) (3.5.0)
# Requirement already satisfied: scikit-learn<2,>=1.3.2 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from imbalanced-learn) (1.5.0)
# Requirement already satisfied: scipy<2,>=1.10.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from imbalanced-learn) (1.13.1)
# Requirement already satisfied: joblib<2,>=1.1.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from imbalanced-learn) (1.4.2)
# Requirement already satisfied: numpy<3,>=1.24.3 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from imbalanced-learn) (1.26.4)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# load dataset

# %%
# Load Pima Indian Diabetes dataset
df = pd.read_csv("F:/RUSL/4- 1/ICT 4302 - Intelligent Systems/miniProject1/diabetes.csv")

df.columns = df.columns.str.strip()  # Clean header spaces
for col in df.columns:
    if col != 'Outcome':
        df[col] = pd.to_numeric(df[col], errors='coerce')  # Convert non-numeric to NaN

numeric_df = df.select_dtypes(include=['number'])

df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# Data preprocessing

# %% [markdown]
# step 1 - Replace invalid zeros with NaN (handle missing values)

# %%
cols_with_missing = ["Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI"]

# Replace 0 with np.nan only for these features
df[cols_with_missing] = df[cols_with_missing].replace(0, np.nan)

# %%
# Remove rows with too many missing values
def drop_rows_with_many_missing(df, threshold_cols=4):
    return df[df[cols_with_missing].isnull().sum(axis=1) < threshold_cols]

df = drop_rows_with_many_missing(df)

# %%
# Define columns for different strategies
median_columns = ["Glucose", "BloodPressure"]
knn_columns = ["SkinThickness", "Insulin", "BMI"]

# %% [markdown]
# step 2 - fill missing values using the median of the same class

# %%
# Apply same-class median imputation
def impute_same_class_median(df, columns, class_col="Outcome"):
    for col in columns:
        df[col] = df.groupby(class_col)[col].transform(lambda x: x.fillna(x.median()))
    return df

df = impute_same_class_median(df, median_columns)

# %%
# Apply KNN Imputer for selected columns
def knn_impute(df, columns, n_neighbors=5):
    imputer = KNNImputer(n_neighbors=n_neighbors)
    df[columns] = imputer.fit_transform(df[columns])
    return df

df = knn_impute(df, knn_columns)

# %%
# Normalize features (optional but recommended)
from sklearn.preprocessing import MinMaxScaler


features = df.columns[:-1]  # Exclude Outcome
scaler = MinMaxScaler()
df[features] = scaler.fit_transform(df[features])

# %%
print("✅ Cleaned dataset ready for model:")
display(df.head())
# Out:
# ✅ Cleaned dataset ready for model:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     0.352941  0.670968       0.489796       0.304348  0.213221  0.314928
# 1     0.058824  0.264516       0.428571       0.239130  0.128125  0.171779
# 2     0.470588  0.896774       0.408163       0.106522  0.106010  0.104294
# 3     0.058824  0.290323       0.428571       0.173913  0.096154  0.202454
# 4     0.000000  0.600000       0.163265       0.304348  0.185096  0.509202
#
#    DiabetesPedigreeFunction       Age  Outcome
# 0                  0.234415  0.483333        1
# 1                  0.116567  0.166667        0
# 2                  0.253629  0.183333        1
# 3                  0.038002  0.000000        0
# 4                  0.943638  0.200000        1

# %%
# Step 1: Split features and labels
X = df.drop("Outcome", axis=1)
y = df["Outcome"]

# Step 2: Apply SMOTE
from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state=42)
X_resampled, y_resampled = sm.fit_resample(X, y)

# %% [markdown]
# data split

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.1)

# %% [markdown]
# build custom keras model

# %%
model = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    layers.Dropout(0.2),
    layers.Dense(16, activation='relu'),
    layers.Dropout(0.1),
    layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='Adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
#add extra hidden layer and change number of nodes in each layer

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                576
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 16)                1040
#
#  dropout_1 (Dropout)         (None, 16)                0
#
#  dense_2 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 1,633
# Trainable params: 1,633
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Train the model

# %%
history = model.fit(X_train, y_train, epochs=100, batch_size=16, validation_split=0.2, verbose=2) #change validation split from 0.2-> 0.1
# Out:
# Epoch 1/100
# 45/45 - 14s - loss: 0.6789 - accuracy: 0.5288 - val_loss: 0.6689 - val_accuracy: 0.5393 - 14s/epoch - 305ms/step
# Epoch 2/100
# 45/45 - 1s - loss: 0.6545 - accuracy: 0.6076 - val_loss: 0.6508 - val_accuracy: 0.6517 - 1s/epoch - 32ms/step
# Epoch 3/100
# 45/45 - 1s - loss: 0.6262 - accuracy: 0.7075 - val_loss: 0.6284 - val_accuracy: 0.7135 - 955ms/epoch - 21ms/step
# Epoch 4/100
# 45/45 - 1s - loss: 0.6099 - accuracy: 0.7215 - val_loss: 0.6044 - val_accuracy: 0.6910 - 710ms/epoch - 16ms/step
# Epoch 5/100
# 45/45 - 1s - loss: 0.5895 - accuracy: 0.7328 - val_loss: 0.5784 - val_accuracy: 0.7247 - 604ms/epoch - 13ms/step
# Epoch 6/100
# 45/45 - 1s - loss: 0.5707 - accuracy: 0.7314 - val_loss: 0.5622 - val_accuracy: 0.7303 - 638ms/epoch - 14ms/step
# Epoch 7/100
# 45/45 - 1s - loss: 0.5495 - accuracy: 0.7539 - val_loss: 0.5496 - val_accuracy: 0.7472 - 716ms/epoch - 16ms/step
# Epoch 8/100
# 45/45 - 1s - loss: 0.5287 - accuracy: 0.7595 - val_loss: 0.5335 - val_accuracy: 0.7360 - 980ms/epoch - 22ms/step
# Epoch 9/100
# 45/45 - 1s - loss: 0.5218 - accuracy: 0.7539 - val_loss: 0.5238 - val_accuracy: 0.7360 - 909ms/epoch - 20ms/step
# Epoch 10/100
# 45/45 - 1s - loss: 0.5163 - accuracy: 0.7609 - val_loss: 0.5213 - val_accuracy: 0.7528 - 881ms/epoch - 20ms/step
# Epoch 11/100
# 45/45 - 1s - loss: 0.5197 - accuracy: 0.7370 - val_loss: 0.5236 - val_accuracy: 0.7416 - 834ms/epoch - 19ms/step
# Epoch 12/100
# 45/45 - 1s - loss: 0.5053 - accuracy: 0.7567 - val_loss: 0.5186 - val_accuracy: 0.7303 - 779ms/epoch - 17ms/step
# Epoch 13/100
# 45/45 - 1s - loss: 0.5101 - accuracy: 0.7482 - val_loss: 0.5057 - val_accuracy: 0.7697 - 730ms/epoch - 16ms/step
# Epoch 14/100
# 45/45 - 1s - loss: 0.5042 - accuracy: 0.7665 - val_loss: 0.5039 - val_accuracy: 0.7528 - 667ms/epoch - 15ms/step
# Epoch 15/100
# 45/45 - 1s - loss: 0.4909 - accuracy: 0.7736 - val_loss: 0.4979 - val_accuracy: 0.7640 - 595ms/epoch - 13ms/step
# Epoch 16/100
# 45/45 - 1s - loss: 0.4913 - accuracy: 0.7651 - val_loss: 0.4976 - val_accuracy: 0.7584 - 543ms/epoch - 12ms/step
# Epoch 17/100
# 45/45 - 1s - loss: 0.4892 - accuracy: 0.7609 - val_loss: 0.5145 - val_accuracy: 0.7360 - 516ms/epoch - 11ms/step
# Epoch 18/100
# 45/45 - 1s - loss: 0.4770 - accuracy: 0.7722 - val_loss: 0.4968 - val_accuracy: 0.7584 - 526ms/epoch - 12ms/step
# Epoch 19/100
# 45/45 - 1s - loss: 0.4865 - accuracy: 0.7651 - val_loss: 0.4914 - val_accuracy: 0.7753 - 772ms/epoch - 17ms/step
# Epoch 20/100
# 45/45 - 1s - loss: 0.4681 - accuracy: 0.7792 - val_loss: 0.4820 - val_accuracy: 0.7865 - 995ms/epoch - 22ms/step
# Epoch 21/100
# 45/45 - 1s - loss: 0.4729 - accuracy: 0.7778 - val_loss: 0.5038 - val_accuracy: 0.7472 - 1s/epoch - 24ms/step
# Epoch 22/100
# 45/45 - 1s - loss: 0.4783 - accuracy: 0.7722 - val_loss: 0.4804 - val_accuracy: 0.7865 - 926ms/epoch - 21ms/step
# Epoch 23/100
# 45/45 - 1s - loss: 0.4714 - accuracy: 0.7609 - val_loss: 0.4795 - val_accuracy: 0.7921 - 1s/epoch - 23ms/step
# Epoch 24/100
# 45/45 - 1s - loss: 0.4681 - accuracy: 0.7904 - val_loss: 0.4879 - val_accuracy: 0.7640 - 770ms/epoch - 17ms/step
# Epoch 25/100
# 45/45 - 1s - loss: 0.4690 - accuracy: 0.7665 - val_loss: 0.4874 - val_accuracy: 0.7640 - 859ms/epoch - 19ms/step
# Epoch 26/100
# 45/45 - 1s - loss: 0.4579 - accuracy: 0.7778 - val_loss: 0.4778 - val_accuracy: 0.7865 - 952ms/epoch - 21ms/step
# Epoch 27/100
# 45/45 - 1s - loss: 0.4717 - accuracy: 0.7792 - val_loss: 0.4736 - val_accuracy: 0.7865 - 873ms/epoch - 19ms/step
# Epoch 28/100
# 45/45 - 1s - loss: 0.4624 - accuracy: 0.7904 - val_loss: 0.4712 - val_accuracy: 0.7978 - 1s/epoch - 25ms/step
# Epoch 29/100
# 45/45 - 2s - loss: 0.4617 - accuracy: 0.7820 - val_loss: 0.4747 - val_accuracy: 0.7865 - 2s/epoch - 37ms/step
# Epoch 30/100
# 45/45 - 1s - loss: 0.4605 - accuracy: 0.7862 - val_loss: 0.4754 - val_accuracy: 0.7809 - 1s/epoch - 24ms/step
# Epoch 31/100
# 45/45 - 1s - loss: 0.4680 - accuracy: 0.7609 - val_loss: 0.4728 - val_accuracy: 0.7921 - 1s/epoch - 30ms/step
# Epoch 32/100
# 45/45 - 2s - loss: 0.4635 - accuracy: 0.7750 - val_loss: 0.4858 - val_accuracy: 0.7697 - 2s/epoch - 43ms/step
# Epoch 33/100
# 45/45 - 3s - loss: 0.4533 - accuracy: 0.7750 - val_loss: 0.4687 - val_accuracy: 0.7978 - 3s/epoch - 57ms/step
# Epoch 34/100
# 45/45 - 4s - loss: 0.4699 - accuracy: 0.7750 - val_loss: 0.4691 - val_accuracy: 0.8202 - 4s/epoch - 92ms/step
# Epoch 35/100
# 45/45 - 2s - loss: 0.4554 - accuracy: 0.7848 - val_loss: 0.4685 - val_accuracy: 0.7978 - 2s/epoch - 54ms/step
# Epoch 36/100
# 45/45 - 2s - loss: 0.4711 - accuracy: 0.7834 - val_loss: 0.4659 - val_accuracy: 0.7921 - 2s/epoch - 38ms/step
# Epoch 37/100
# 45/45 - 3s - loss: 0.4577 - accuracy: 0.7764 - val_loss: 0.4747 - val_accuracy: 0.7697 - 3s/epoch - 57ms/step
# Epoch 38/100
# 45/45 - 4s - loss: 0.4496 - accuracy: 0.7792 - val_loss: 0.4662 - val_accuracy: 0.7809 - 4s/epoch - 92ms/step
# Epoch 39/100
# 45/45 - 2s - loss: 0.4539 - accuracy: 0.7778 - val_loss: 0.4670 - val_accuracy: 0.7978 - 2s/epoch - 42ms/step
# Epoch 40/100
# 45/45 - 2s - loss: 0.4542 - accuracy: 0.7848 - val_loss: 0.4688 - val_accuracy: 0.7865 - 2s/epoch - 42ms/step
# Epoch 41/100
# 45/45 - 3s - loss: 0.4536 - accuracy: 0.7904 - val_loss: 0.4766 - val_accuracy: 0.7753 - 3s/epoch - 57ms/step
# Epoch 42/100
# 45/45 - 2s - loss: 0.4542 - accuracy: 0.7890 - val_loss: 0.4694 - val_accuracy: 0.7921 - 2s/epoch - 50ms/step
# Epoch 43/100
# 45/45 - 3s - loss: 0.4489 - accuracy: 0.7792 - val_loss: 0.4780 - val_accuracy: 0.7865 - 3s/epoch - 59ms/step
# Epoch 44/100
# 45/45 - 2s - loss: 0.4497 - accuracy: 0.7792 - val_loss: 0.4599 - val_accuracy: 0.8202 - 2s/epoch - 42ms/step
# Epoch 45/100
# 45/45 - 2s - loss: 0.4510 - accuracy: 0.7848 - val_loss: 0.4602 - val_accuracy: 0.7921 - 2s/epoch - 39ms/step
# Epoch 46/100
# 45/45 - 4s - loss: 0.4498 - accuracy: 0.7876 - val_loss: 0.4623 - val_accuracy: 0.7921 - 4s/epoch - 80ms/step
# Epoch 47/100
# 45/45 - 3s - loss: 0.4505 - accuracy: 0.7904 - val_loss: 0.4662 - val_accuracy: 0.7921 - 3s/epoch - 61ms/step
# Epoch 48/100
# 45/45 - 2s - loss: 0.4492 - accuracy: 0.7932 - val_loss: 0.4631 - val_accuracy: 0.7978 - 2s/epoch - 53ms/step
# Epoch 49/100
# 45/45 - 2s - loss: 0.4340 - accuracy: 0.7989 - val_loss: 0.4595 - val_accuracy: 0.7753 - 2s/epoch - 43ms/step
# Epoch 50/100
# 45/45 - 2s - loss: 0.4456 - accuracy: 0.7806 - val_loss: 0.4537 - val_accuracy: 0.8090 - 2s/epoch - 45ms/step
# Epoch 51/100
# 45/45 - 2s - loss: 0.4610 - accuracy: 0.7764 - val_loss: 0.4560 - val_accuracy: 0.8146 - 2s/epoch - 54ms/step
# Epoch 52/100
# 45/45 - 2s - loss: 0.4475 - accuracy: 0.7862 - val_loss: 0.4609 - val_accuracy: 0.7865 - 2s/epoch - 45ms/step
# Epoch 53/100
# 45/45 - 2s - loss: 0.4488 - accuracy: 0.8017 - val_loss: 0.4666 - val_accuracy: 0.7865 - 2s/epoch - 37ms/step
# Epoch 54/100
# 45/45 - 1s - loss: 0.4366 - accuracy: 0.7876 - val_loss: 0.4547 - val_accuracy: 0.8090 - 1s/epoch - 32ms/step
# Epoch 55/100
# 45/45 - 2s - loss: 0.4327 - accuracy: 0.8087 - val_loss: 0.4518 - val_accuracy: 0.8034 - 2s/epoch - 41ms/step
# Epoch 56/100
# 45/45 - 2s - loss: 0.4514 - accuracy: 0.7820 - val_loss: 0.4525 - val_accuracy: 0.7978 - 2s/epoch - 44ms/step
# Epoch 57/100
# 45/45 - 2s - loss: 0.4449 - accuracy: 0.7947 - val_loss: 0.4616 - val_accuracy: 0.8090 - 2s/epoch - 36ms/step
# Epoch 58/100
# 45/45 - 1s - loss: 0.4499 - accuracy: 0.7876 - val_loss: 0.4631 - val_accuracy: 0.8034 - 1s/epoch - 30ms/step
# Epoch 59/100
# 45/45 - 1s - loss: 0.4322 - accuracy: 0.8115 - val_loss: 0.4504 - val_accuracy: 0.7978 - 1s/epoch - 24ms/step
# Epoch 60/100
# 45/45 - 1s - loss: 0.4408 - accuracy: 0.8017 - val_loss: 0.4733 - val_accuracy: 0.7921 - 940ms/epoch - 21ms/step
# Epoch 61/100
# 45/45 - 1s - loss: 0.4315 - accuracy: 0.7848 - val_loss: 0.4551 - val_accuracy: 0.7865 - 1s/epoch - 24ms/step
# Epoch 62/100
# 45/45 - 1s - loss: 0.4274 - accuracy: 0.7961 - val_loss: 0.4487 - val_accuracy: 0.7921 - 1s/epoch - 24ms/step
# Epoch 63/100
# 45/45 - 1s - loss: 0.4325 - accuracy: 0.8059 - val_loss: 0.4481 - val_accuracy: 0.7978 - 1s/epoch - 24ms/step
# Epoch 64/100
# 45/45 - 1s - loss: 0.4316 - accuracy: 0.7989 - val_loss: 0.4559 - val_accuracy: 0.8034 - 903ms/epoch - 20ms/step
# Epoch 65/100
# 45/45 - 1s - loss: 0.4250 - accuracy: 0.8045 - val_loss: 0.4507 - val_accuracy: 0.7921 - 822ms/epoch - 18ms/step
# Epoch 66/100
# 45/45 - 1s - loss: 0.4292 - accuracy: 0.8031 - val_loss: 0.4606 - val_accuracy: 0.7753 - 847ms/epoch - 19ms/step
# Epoch 67/100
# 45/45 - 1s - loss: 0.4294 - accuracy: 0.7989 - val_loss: 0.4484 - val_accuracy: 0.8034 - 768ms/epoch - 17ms/step
# Epoch 68/100
# 45/45 - 1s - loss: 0.4368 - accuracy: 0.7947 - val_loss: 0.4483 - val_accuracy: 0.8034 - 860ms/epoch - 19ms/step
# Epoch 69/100
# 45/45 - 1s - loss: 0.4254 - accuracy: 0.7961 - val_loss: 0.4487 - val_accuracy: 0.7978 - 801ms/epoch - 18ms/step
# Epoch 70/100
# 45/45 - 1s - loss: 0.4266 - accuracy: 0.8087 - val_loss: 0.4584 - val_accuracy: 0.7865 - 693ms/epoch - 15ms/step
# Epoch 71/100
# 45/45 - 1s - loss: 0.4348 - accuracy: 0.7918 - val_loss: 0.4528 - val_accuracy: 0.7921 - 646ms/epoch - 14ms/step
# Epoch 72/100
# 45/45 - 1s - loss: 0.4330 - accuracy: 0.8059 - val_loss: 0.4436 - val_accuracy: 0.7978 - 617ms/epoch - 14ms/step
# Epoch 73/100
# 45/45 - 1s - loss: 0.4216 - accuracy: 0.8143 - val_loss: 0.4529 - val_accuracy: 0.8034 - 595ms/epoch - 13ms/step
# Epoch 74/100
# 45/45 - 1s - loss: 0.4283 - accuracy: 0.8172 - val_loss: 0.4408 - val_accuracy: 0.7921 - 627ms/epoch - 14ms/step
# Epoch 75/100
# 45/45 - 1s - loss: 0.4186 - accuracy: 0.8031 - val_loss: 0.4422 - val_accuracy: 0.8034 - 658ms/epoch - 15ms/step
# Epoch 76/100
# 45/45 - 1s - loss: 0.4276 - accuracy: 0.8059 - val_loss: 0.4629 - val_accuracy: 0.7753 - 643ms/epoch - 14ms/step
# Epoch 77/100
# 45/45 - 1s - loss: 0.4141 - accuracy: 0.8031 - val_loss: 0.4605 - val_accuracy: 0.7865 - 554ms/epoch - 12ms/step
# Epoch 78/100
# 45/45 - 0s - loss: 0.4136 - accuracy: 0.8059 - val_loss: 0.4544 - val_accuracy: 0.7865 - 499ms/epoch - 11ms/step
# Epoch 79/100
# 45/45 - 1s - loss: 0.4310 - accuracy: 0.7890 - val_loss: 0.4501 - val_accuracy: 0.7921 - 508ms/epoch - 11ms/step
# Epoch 80/100
# 45/45 - 1s - loss: 0.4212 - accuracy: 0.8115 - val_loss: 0.4522 - val_accuracy: 0.7921 - 502ms/epoch - 11ms/step
# Epoch 81/100
# 45/45 - 0s - loss: 0.4296 - accuracy: 0.8045 - val_loss: 0.4427 - val_accuracy: 0.7921 - 483ms/epoch - 11ms/step
# Epoch 82/100
# 45/45 - 1s - loss: 0.4220 - accuracy: 0.8143 - val_loss: 0.4484 - val_accuracy: 0.7921 - 502ms/epoch - 11ms/step
# Epoch 83/100
# 45/45 - 0s - loss: 0.4158 - accuracy: 0.8045 - val_loss: 0.4507 - val_accuracy: 0.7978 - 494ms/epoch - 11ms/step
# Epoch 84/100
# 45/45 - 0s - loss: 0.4146 - accuracy: 0.8059 - val_loss: 0.4478 - val_accuracy: 0.7865 - 491ms/epoch - 11ms/step
# Epoch 85/100
# 45/45 - 0s - loss: 0.4208 - accuracy: 0.8129 - val_loss: 0.4599 - val_accuracy: 0.7809 - 486ms/epoch - 11ms/step
# Epoch 86/100
# 45/45 - 0s - loss: 0.4185 - accuracy: 0.8143 - val_loss: 0.4609 - val_accuracy: 0.7921 - 487ms/epoch - 11ms/step
# Epoch 87/100
# 45/45 - 1s - loss: 0.4183 - accuracy: 0.8059 - val_loss: 0.4461 - val_accuracy: 0.7978 - 505ms/epoch - 11ms/step
# Epoch 88/100
# 45/45 - 0s - loss: 0.4226 - accuracy: 0.7975 - val_loss: 0.4465 - val_accuracy: 0.7865 - 485ms/epoch - 11ms/step
# Epoch 89/100
# 45/45 - 0s - loss: 0.4095 - accuracy: 0.8073 - val_loss: 0.4510 - val_accuracy: 0.7921 - 476ms/epoch - 11ms/step
# Epoch 90/100
# 45/45 - 0s - loss: 0.4176 - accuracy: 0.8143 - val_loss: 0.4463 - val_accuracy: 0.7921 - 493ms/epoch - 11ms/step
# Epoch 91/100
# 45/45 - 0s - loss: 0.4217 - accuracy: 0.7989 - val_loss: 0.4692 - val_accuracy: 0.7921 - 482ms/epoch - 11ms/step
# Epoch 92/100
# 45/45 - 0s - loss: 0.4127 - accuracy: 0.8186 - val_loss: 0.4452 - val_accuracy: 0.8090 - 471ms/epoch - 10ms/step
# Epoch 93/100
# 45/45 - 1s - loss: 0.4251 - accuracy: 0.8017 - val_loss: 0.4429 - val_accuracy: 0.7978 - 516ms/epoch - 11ms/step
# Epoch 94/100
# 45/45 - 1s - loss: 0.4164 - accuracy: 0.8115 - val_loss: 0.4524 - val_accuracy: 0.7865 - 519ms/epoch - 12ms/step
# Epoch 95/100
# 45/45 - 0s - loss: 0.4077 - accuracy: 0.8101 - val_loss: 0.4427 - val_accuracy: 0.8146 - 497ms/epoch - 11ms/step
# Epoch 96/100
# 45/45 - 0s - loss: 0.4215 - accuracy: 0.8045 - val_loss: 0.4410 - val_accuracy: 0.8090 - 492ms/epoch - 11ms/step
# Epoch 97/100
# 45/45 - 1s - loss: 0.4236 - accuracy: 0.8087 - val_loss: 0.4430 - val_accuracy: 0.7978 - 503ms/epoch - 11ms/step
# Epoch 98/100
# 45/45 - 0s - loss: 0.4077 - accuracy: 0.8115 - val_loss: 0.4417 - val_accuracy: 0.8034 - 495ms/epoch - 11ms/step
# Epoch 99/100
# 45/45 - 1s - loss: 0.4178 - accuracy: 0.8158 - val_loss: 0.4569 - val_accuracy: 0.7865 - 503ms/epoch - 11ms/step
# Epoch 100/100
# 45/45 - 0s - loss: 0.4170 - accuracy: 0.8073 - val_loss: 0.4405 - val_accuracy: 0.8090 - 495ms/epoch - 11ms/step

# %% [markdown]
# Evaluate the model

# %%
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, confusion_matrix, classification_report
)

# Predict probabilities
y_pred_prob = model.predict(X_test).ravel()

# Convert to binary output
y_pred = (y_pred_prob >= 0.5).astype(int)

# Classification report
print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))

# Confusion Matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# Predict probabilities and convert to binary
y_pred_prob = model.predict(X_test).ravel()
y_pred = (y_pred_prob >= 0.5).astype(int)

# Generate confusion matrix
cm = confusion_matrix(y_test, y_pred)
labels = ['No Diabetes', 'Diabetes']

# Plot
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)

plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.tight_layout()
plt.show()


# Individual metrics
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall:", recall_score(y_test, y_pred))
print("F1 Score:", f1_score(y_test, y_pred))
# Out:
# 4/4 [==============================] - 0s 6ms/step
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.74      0.78        50
#            1       0.76      0.84      0.80        49
#
#     accuracy                           0.79        99
#    macro avg       0.79      0.79      0.79        99
# weighted avg       0.79      0.79      0.79        99
#
# 4/4 [==============================] - 0s 5ms/step
# Accuracy: 0.7878787878787878
# Precision: 0.7592592592592593
# Recall: 0.8367346938775511
# F1 Score: 0.7961165048543689

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot training & validation loss
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# Predict probabilities for the test set
y_pred_prob = model.predict(X_test).ravel()  # Already flattened

# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)

# Calculate AUC score
auc_score = roc_auc_score(y_test, y_pred_prob)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC Curve (AUC = {auc_score:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')  # Diagonal line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()
# Out:
# 4/4 [==============================] - 0s 6ms/step
