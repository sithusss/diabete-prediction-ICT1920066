# %%
# %pip install tensorflow seaborn

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.impute import KNNImputer
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_curve, auc

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# Out:
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: tensorflow in c:\users\ww\anaconda3\envs\iis\lib\site-packages (2.11.0)
# Requirement already satisfied: seaborn in c:\users\ww\anaconda3\envs\iis\lib\site-packages (0.12.2)
# Requirement already satisfied: tensorflow-intel==2.11.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.8.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (18.1.1)
# Requirement already satisfied: numpy>=1.20 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.21.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (24.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.19.6)
# Requirement already satisfied: setuptools in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (65.6.3)
# Requirement already satisfied: six>=1.12.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (4.7.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.62.2)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.2)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.31.0)
# Requirement already satisfied: pandas>=0.25 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from seaborn) (1.3.5)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from seaborn) (3.5.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.5.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from pandas>=0.25->seaborn) (2024.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.29.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.4.4)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.0)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (6.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.1.5)
# Requirement already satisfied: zipp>=0.5 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.15.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.2.2)

# %% [markdown]
# load dataset

# %%
# Load Pima Indian Diabetes dataset
df = pd.read_csv("F:/RUSL/4- 1/ICT 4302 - Intelligent Systems/miniProject1/diabetes.csv")

df.columns = df.columns.str.strip()  # Clean header spaces
for col in df.columns:
    if col != 'Outcome':
        df[col] = pd.to_numeric(df[col], errors='coerce')  # Convert non-numeric to NaN

numeric_df = df.select_dtypes(include=['number'])

df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# Data preprocessing

# %% [markdown]
# step 1 - Replace invalid zeros with NaN (handle missing values)

# %%
cols_with_missing = ["Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI"]

# Replace 0 with np.nan only for these features
df[cols_with_missing] = df[cols_with_missing].replace(0, np.nan)

# %%
# Remove rows with too many missing values
def drop_rows_with_many_missing(df, threshold_cols=4):
    return df[df[cols_with_missing].isnull().sum(axis=1) < threshold_cols]

df = drop_rows_with_many_missing(df)

# %%
# Define columns for different strategies
median_columns = ["Glucose", "BloodPressure"]
knn_columns = ["SkinThickness", "Insulin", "BMI"]

# %% [markdown]
# step 2 - fill missing values using the median of the same class

# %%
# Apply same-class median imputation
def impute_same_class_median(df, columns, class_col="Outcome"):
    for col in columns:
        df[col] = df.groupby(class_col)[col].transform(lambda x: x.fillna(x.median()))
    return df

df = impute_same_class_median(df, median_columns)

# %%
# Apply KNN Imputer for selected columns
def knn_impute(df, columns, n_neighbors=5):
    imputer = KNNImputer(n_neighbors=n_neighbors)
    df[columns] = imputer.fit_transform(df[columns])
    return df

df = knn_impute(df, knn_columns)

# %%
# Normalize features (optional but recommended)
from sklearn.preprocessing import MinMaxScaler


features = df.columns[:-1]  # Exclude Outcome
scaler = MinMaxScaler()
df[features] = scaler.fit_transform(df[features])

# %%
print("✅ Cleaned dataset ready for model:")
display(df.head())
# Out:
# ✅ Cleaned dataset ready for model:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     0.352941  0.670968       0.489796       0.304348  0.213221  0.314928
# 1     0.058824  0.264516       0.428571       0.239130  0.128125  0.171779
# 2     0.470588  0.896774       0.408163       0.106522  0.106010  0.104294
# 3     0.058824  0.290323       0.428571       0.173913  0.096154  0.202454
# 4     0.000000  0.600000       0.163265       0.304348  0.185096  0.509202
#
#    DiabetesPedigreeFunction       Age  Outcome
# 0                  0.234415  0.483333        1
# 1                  0.116567  0.166667        0
# 2                  0.253629  0.183333        1
# 3                  0.038002  0.000000        0
# 4                  0.943638  0.200000        1

# %%
# ----- AFTER preprocessing and missing value handling -----

# Balance the dataset
class_0 = df[df['Outcome'] == 0]
class_1 = df[df['Outcome'] == 1]

min_size = min(len(class_0), len(class_1))
class_0_sampled = class_0.sample(n=min_size, random_state=42)
class_1_sampled = class_1.sample(n=min_size, random_state=42)

balanced_df = pd.concat([class_0_sampled, class_1_sampled], axis=0)
balanced_df = balanced_df.sample(frac=1, random_state=42).reset_index(drop=True)

# %%
X = balanced_df.drop("Outcome", axis=1)
y = balanced_df["Outcome"]

# %% [markdown]
# data split

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# build custom keras model

# %%
model = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    layers.Dropout(0.3),  # Dropout layer to prevent overfitting
    layers.Dense(16, activation='relu'),
    layers.Dense(1, activation='sigmoid')  # Binary output
])

model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
#add extra hidden layer and change number of nodes in each layer

# %%
model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_18 (Dense)            (None, 64)                576
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_19 (Dense)            (None, 16)                1040
#
#  dense_20 (Dense)            (None, 1)                 17
#
# =================================================================
# Total params: 1,633
# Trainable params: 1,633
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Train the model

# %%
history = model.fit(X_train, y_train, epochs=120, batch_size=16, validation_split=0.1, verbose=2) #change validation0split from 0.2-> 0.1
# Out:
# Epoch 1/120
# 24/24 - 2s - loss: 0.6961 - accuracy: 0.4974 - val_loss: 0.6912 - val_accuracy: 0.5116 - 2s/epoch - 75ms/step
# Epoch 2/120
# 24/24 - 0s - loss: 0.6864 - accuracy: 0.5365 - val_loss: 0.6848 - val_accuracy: 0.6047 - 154ms/epoch - 6ms/step
# Epoch 3/120
# 24/24 - 0s - loss: 0.6763 - accuracy: 0.5625 - val_loss: 0.6756 - val_accuracy: 0.6047 - 148ms/epoch - 6ms/step
# Epoch 4/120
# 24/24 - 0s - loss: 0.6707 - accuracy: 0.6042 - val_loss: 0.6683 - val_accuracy: 0.6047 - 142ms/epoch - 6ms/step
# Epoch 5/120
# 24/24 - 0s - loss: 0.6632 - accuracy: 0.6615 - val_loss: 0.6583 - val_accuracy: 0.6744 - 153ms/epoch - 6ms/step
# Epoch 6/120
# 24/24 - 0s - loss: 0.6562 - accuracy: 0.6745 - val_loss: 0.6478 - val_accuracy: 0.6744 - 155ms/epoch - 6ms/step
# Epoch 7/120
# 24/24 - 0s - loss: 0.6330 - accuracy: 0.6875 - val_loss: 0.6384 - val_accuracy: 0.6744 - 140ms/epoch - 6ms/step
# Epoch 8/120
# 24/24 - 0s - loss: 0.6311 - accuracy: 0.6849 - val_loss: 0.6272 - val_accuracy: 0.6977 - 151ms/epoch - 6ms/step
# Epoch 9/120
# 24/24 - 0s - loss: 0.6177 - accuracy: 0.6901 - val_loss: 0.6124 - val_accuracy: 0.6744 - 132ms/epoch - 6ms/step
# Epoch 10/120
# 24/24 - 0s - loss: 0.6054 - accuracy: 0.6979 - val_loss: 0.6012 - val_accuracy: 0.6977 - 128ms/epoch - 5ms/step
# Epoch 11/120
# 24/24 - 0s - loss: 0.5960 - accuracy: 0.7188 - val_loss: 0.5878 - val_accuracy: 0.6744 - 134ms/epoch - 6ms/step
# Epoch 12/120
# 24/24 - 0s - loss: 0.5861 - accuracy: 0.7161 - val_loss: 0.5813 - val_accuracy: 0.6977 - 156ms/epoch - 6ms/step
# Epoch 13/120
# 24/24 - 0s - loss: 0.5748 - accuracy: 0.7161 - val_loss: 0.5695 - val_accuracy: 0.6744 - 133ms/epoch - 6ms/step
# Epoch 14/120
# 24/24 - 0s - loss: 0.5457 - accuracy: 0.7474 - val_loss: 0.5597 - val_accuracy: 0.6744 - 160ms/epoch - 7ms/step
# Epoch 15/120
# 24/24 - 0s - loss: 0.5797 - accuracy: 0.7135 - val_loss: 0.5491 - val_accuracy: 0.7209 - 172ms/epoch - 7ms/step
# Epoch 16/120
# 24/24 - 0s - loss: 0.5419 - accuracy: 0.7266 - val_loss: 0.5457 - val_accuracy: 0.6977 - 142ms/epoch - 6ms/step
# Epoch 17/120
# 24/24 - 0s - loss: 0.5505 - accuracy: 0.7292 - val_loss: 0.5431 - val_accuracy: 0.6977 - 130ms/epoch - 5ms/step
# Epoch 18/120
# 24/24 - 0s - loss: 0.5463 - accuracy: 0.7266 - val_loss: 0.5336 - val_accuracy: 0.7209 - 125ms/epoch - 5ms/step
# Epoch 19/120
# 24/24 - 0s - loss: 0.5381 - accuracy: 0.7318 - val_loss: 0.5319 - val_accuracy: 0.6977 - 117ms/epoch - 5ms/step
# Epoch 20/120
# 24/24 - 0s - loss: 0.5594 - accuracy: 0.7135 - val_loss: 0.5277 - val_accuracy: 0.6744 - 112ms/epoch - 5ms/step
# Epoch 21/120
# 24/24 - 0s - loss: 0.5280 - accuracy: 0.7474 - val_loss: 0.5251 - val_accuracy: 0.6977 - 107ms/epoch - 4ms/step
# Epoch 22/120
# 24/24 - 0s - loss: 0.5181 - accuracy: 0.7578 - val_loss: 0.5187 - val_accuracy: 0.6744 - 148ms/epoch - 6ms/step
# Epoch 23/120
# 24/24 - 0s - loss: 0.5259 - accuracy: 0.7604 - val_loss: 0.5183 - val_accuracy: 0.6744 - 126ms/epoch - 5ms/step
# Epoch 24/120
# 24/24 - 0s - loss: 0.5156 - accuracy: 0.7344 - val_loss: 0.5223 - val_accuracy: 0.6977 - 115ms/epoch - 5ms/step
# Epoch 25/120
# 24/24 - 0s - loss: 0.5359 - accuracy: 0.7396 - val_loss: 0.5145 - val_accuracy: 0.6744 - 120ms/epoch - 5ms/step
# Epoch 26/120
# 24/24 - 0s - loss: 0.5276 - accuracy: 0.7422 - val_loss: 0.5127 - val_accuracy: 0.6744 - 123ms/epoch - 5ms/step
# Epoch 27/120
# 24/24 - 0s - loss: 0.5228 - accuracy: 0.7422 - val_loss: 0.5101 - val_accuracy: 0.6977 - 110ms/epoch - 5ms/step
# Epoch 28/120
# 24/24 - 0s - loss: 0.5167 - accuracy: 0.7500 - val_loss: 0.5119 - val_accuracy: 0.6744 - 110ms/epoch - 5ms/step
# Epoch 29/120
# 24/24 - 0s - loss: 0.5079 - accuracy: 0.7526 - val_loss: 0.5105 - val_accuracy: 0.6744 - 109ms/epoch - 5ms/step
# Epoch 30/120
# 24/24 - 0s - loss: 0.5057 - accuracy: 0.7734 - val_loss: 0.5088 - val_accuracy: 0.6744 - 119ms/epoch - 5ms/step
# Epoch 31/120
# 24/24 - 0s - loss: 0.5163 - accuracy: 0.7552 - val_loss: 0.5116 - val_accuracy: 0.6744 - 136ms/epoch - 6ms/step
# Epoch 32/120
# 24/24 - 0s - loss: 0.5235 - accuracy: 0.7292 - val_loss: 0.5085 - val_accuracy: 0.6977 - 140ms/epoch - 6ms/step
# Epoch 33/120
# 24/24 - 0s - loss: 0.5191 - accuracy: 0.7552 - val_loss: 0.5058 - val_accuracy: 0.6977 - 240ms/epoch - 10ms/step
# Epoch 34/120
# 24/24 - 0s - loss: 0.5150 - accuracy: 0.7474 - val_loss: 0.5010 - val_accuracy: 0.6744 - 133ms/epoch - 6ms/step
# Epoch 35/120
# 24/24 - 0s - loss: 0.4889 - accuracy: 0.7786 - val_loss: 0.5010 - val_accuracy: 0.6744 - 145ms/epoch - 6ms/step
# Epoch 36/120
# 24/24 - 0s - loss: 0.5004 - accuracy: 0.7682 - val_loss: 0.5017 - val_accuracy: 0.6977 - 164ms/epoch - 7ms/step
# Epoch 37/120
# 24/24 - 0s - loss: 0.4987 - accuracy: 0.7630 - val_loss: 0.5066 - val_accuracy: 0.6744 - 129ms/epoch - 5ms/step
# Epoch 38/120
# 24/24 - 0s - loss: 0.5070 - accuracy: 0.7500 - val_loss: 0.5020 - val_accuracy: 0.6977 - 115ms/epoch - 5ms/step
# Epoch 39/120
# 24/24 - 0s - loss: 0.5008 - accuracy: 0.7708 - val_loss: 0.5026 - val_accuracy: 0.6977 - 109ms/epoch - 5ms/step
# Epoch 40/120
# 24/24 - 0s - loss: 0.5064 - accuracy: 0.7422 - val_loss: 0.4986 - val_accuracy: 0.6977 - 126ms/epoch - 5ms/step
# Epoch 41/120
# 24/24 - 0s - loss: 0.4909 - accuracy: 0.7656 - val_loss: 0.4971 - val_accuracy: 0.6977 - 121ms/epoch - 5ms/step
# Epoch 42/120
# 24/24 - 0s - loss: 0.5085 - accuracy: 0.7682 - val_loss: 0.5032 - val_accuracy: 0.6744 - 123ms/epoch - 5ms/step
# Epoch 43/120
# 24/24 - 0s - loss: 0.4947 - accuracy: 0.7682 - val_loss: 0.5039 - val_accuracy: 0.6977 - 125ms/epoch - 5ms/step
# Epoch 44/120
# 24/24 - 0s - loss: 0.4861 - accuracy: 0.7839 - val_loss: 0.5070 - val_accuracy: 0.6977 - 133ms/epoch - 6ms/step
# Epoch 45/120
# 24/24 - 0s - loss: 0.5117 - accuracy: 0.7396 - val_loss: 0.5035 - val_accuracy: 0.6977 - 129ms/epoch - 5ms/step
# Epoch 46/120
# 24/24 - 0s - loss: 0.4949 - accuracy: 0.7630 - val_loss: 0.4973 - val_accuracy: 0.7209 - 131ms/epoch - 5ms/step
# Epoch 47/120
# 24/24 - 0s - loss: 0.4903 - accuracy: 0.7396 - val_loss: 0.4984 - val_accuracy: 0.6977 - 130ms/epoch - 5ms/step
# Epoch 48/120
# 24/24 - 0s - loss: 0.4889 - accuracy: 0.7630 - val_loss: 0.4917 - val_accuracy: 0.7209 - 123ms/epoch - 5ms/step
# Epoch 49/120
# 24/24 - 0s - loss: 0.4763 - accuracy: 0.7786 - val_loss: 0.4969 - val_accuracy: 0.7209 - 134ms/epoch - 6ms/step
# Epoch 50/120
# 24/24 - 0s - loss: 0.4768 - accuracy: 0.7656 - val_loss: 0.4958 - val_accuracy: 0.7209 - 129ms/epoch - 5ms/step
# Epoch 51/120
# 24/24 - 0s - loss: 0.4954 - accuracy: 0.7734 - val_loss: 0.4986 - val_accuracy: 0.7209 - 140ms/epoch - 6ms/step
# Epoch 52/120
# 24/24 - 0s - loss: 0.4955 - accuracy: 0.7760 - val_loss: 0.4965 - val_accuracy: 0.7209 - 135ms/epoch - 6ms/step
# Epoch 53/120
# 24/24 - 0s - loss: 0.4842 - accuracy: 0.7812 - val_loss: 0.5004 - val_accuracy: 0.7209 - 128ms/epoch - 5ms/step
# Epoch 54/120
# 24/24 - 0s - loss: 0.4789 - accuracy: 0.7630 - val_loss: 0.4976 - val_accuracy: 0.7209 - 120ms/epoch - 5ms/step
# Epoch 55/120
# 24/24 - 0s - loss: 0.4746 - accuracy: 0.7760 - val_loss: 0.4947 - val_accuracy: 0.6977 - 132ms/epoch - 5ms/step
# Epoch 56/120
# 24/24 - 0s - loss: 0.4790 - accuracy: 0.7734 - val_loss: 0.4919 - val_accuracy: 0.6977 - 161ms/epoch - 7ms/step
# Epoch 57/120
# 24/24 - 0s - loss: 0.4910 - accuracy: 0.7552 - val_loss: 0.4899 - val_accuracy: 0.6977 - 131ms/epoch - 5ms/step
# Epoch 58/120
# 24/24 - 0s - loss: 0.4781 - accuracy: 0.7552 - val_loss: 0.4934 - val_accuracy: 0.6977 - 148ms/epoch - 6ms/step
# Epoch 59/120
# 24/24 - 0s - loss: 0.4916 - accuracy: 0.7760 - val_loss: 0.4916 - val_accuracy: 0.6977 - 138ms/epoch - 6ms/step
# Epoch 60/120
# 24/24 - 0s - loss: 0.4755 - accuracy: 0.7682 - val_loss: 0.4936 - val_accuracy: 0.6977 - 119ms/epoch - 5ms/step
# Epoch 61/120
# 24/24 - 0s - loss: 0.4810 - accuracy: 0.7682 - val_loss: 0.4973 - val_accuracy: 0.7209 - 116ms/epoch - 5ms/step
# Epoch 62/120
# 24/24 - 0s - loss: 0.4833 - accuracy: 0.7708 - val_loss: 0.4908 - val_accuracy: 0.7209 - 116ms/epoch - 5ms/step
# Epoch 63/120
# 24/24 - 0s - loss: 0.4798 - accuracy: 0.7682 - val_loss: 0.4873 - val_accuracy: 0.7209 - 110ms/epoch - 5ms/step
# Epoch 64/120
# 24/24 - 0s - loss: 0.4660 - accuracy: 0.7708 - val_loss: 0.4818 - val_accuracy: 0.6977 - 113ms/epoch - 5ms/step
# Epoch 65/120
# 24/24 - 0s - loss: 0.4665 - accuracy: 0.7786 - val_loss: 0.4879 - val_accuracy: 0.7209 - 108ms/epoch - 4ms/step
# Epoch 66/120
# 24/24 - 0s - loss: 0.4698 - accuracy: 0.7812 - val_loss: 0.4842 - val_accuracy: 0.7209 - 186ms/epoch - 8ms/step
# Epoch 67/120
# 24/24 - 0s - loss: 0.4805 - accuracy: 0.7604 - val_loss: 0.4904 - val_accuracy: 0.6977 - 123ms/epoch - 5ms/step
# Epoch 68/120
# 24/24 - 0s - loss: 0.4707 - accuracy: 0.7760 - val_loss: 0.4843 - val_accuracy: 0.6977 - 132ms/epoch - 5ms/step
# Epoch 69/120
# 24/24 - 0s - loss: 0.4780 - accuracy: 0.7578 - val_loss: 0.4739 - val_accuracy: 0.7209 - 130ms/epoch - 5ms/step
# Epoch 70/120
# 24/24 - 0s - loss: 0.4842 - accuracy: 0.7734 - val_loss: 0.4767 - val_accuracy: 0.7209 - 121ms/epoch - 5ms/step
# Epoch 71/120
# 24/24 - 0s - loss: 0.4807 - accuracy: 0.7682 - val_loss: 0.4803 - val_accuracy: 0.7209 - 133ms/epoch - 6ms/step
# Epoch 72/120
# 24/24 - 0s - loss: 0.4770 - accuracy: 0.7786 - val_loss: 0.4839 - val_accuracy: 0.6977 - 125ms/epoch - 5ms/step
# Epoch 73/120
# 24/24 - 0s - loss: 0.4572 - accuracy: 0.7995 - val_loss: 0.4846 - val_accuracy: 0.7209 - 127ms/epoch - 5ms/step
# Epoch 74/120
# 24/24 - 0s - loss: 0.4614 - accuracy: 0.7969 - val_loss: 0.4790 - val_accuracy: 0.6977 - 127ms/epoch - 5ms/step
# Epoch 75/120
# 24/24 - 0s - loss: 0.4683 - accuracy: 0.7734 - val_loss: 0.4831 - val_accuracy: 0.7209 - 136ms/epoch - 6ms/step
# Epoch 76/120
# 24/24 - 0s - loss: 0.4726 - accuracy: 0.7786 - val_loss: 0.4822 - val_accuracy: 0.7209 - 132ms/epoch - 5ms/step
# Epoch 77/120
# 24/24 - 0s - loss: 0.4731 - accuracy: 0.7812 - val_loss: 0.4826 - val_accuracy: 0.7209 - 156ms/epoch - 6ms/step
# Epoch 78/120
# 24/24 - 0s - loss: 0.4644 - accuracy: 0.7839 - val_loss: 0.4771 - val_accuracy: 0.7209 - 126ms/epoch - 5ms/step
# Epoch 79/120
# 24/24 - 0s - loss: 0.4743 - accuracy: 0.7734 - val_loss: 0.4705 - val_accuracy: 0.7209 - 118ms/epoch - 5ms/step
# Epoch 80/120
# 24/24 - 0s - loss: 0.4735 - accuracy: 0.7865 - val_loss: 0.4632 - val_accuracy: 0.7209 - 131ms/epoch - 5ms/step
# Epoch 81/120
# 24/24 - 0s - loss: 0.4686 - accuracy: 0.7812 - val_loss: 0.4704 - val_accuracy: 0.6977 - 133ms/epoch - 6ms/step
# Epoch 82/120
# 24/24 - 0s - loss: 0.4646 - accuracy: 0.7839 - val_loss: 0.4729 - val_accuracy: 0.6977 - 120ms/epoch - 5ms/step
# Epoch 83/120
# 24/24 - 0s - loss: 0.4783 - accuracy: 0.7578 - val_loss: 0.4690 - val_accuracy: 0.6977 - 158ms/epoch - 7ms/step
# Epoch 84/120
# 24/24 - 0s - loss: 0.4703 - accuracy: 0.7734 - val_loss: 0.4789 - val_accuracy: 0.7209 - 162ms/epoch - 7ms/step
# Epoch 85/120
# 24/24 - 0s - loss: 0.4724 - accuracy: 0.7708 - val_loss: 0.4701 - val_accuracy: 0.7209 - 144ms/epoch - 6ms/step
# Epoch 86/120
# 24/24 - 0s - loss: 0.4604 - accuracy: 0.7891 - val_loss: 0.4745 - val_accuracy: 0.7209 - 120ms/epoch - 5ms/step
# Epoch 87/120
# 24/24 - 0s - loss: 0.4728 - accuracy: 0.7760 - val_loss: 0.4758 - val_accuracy: 0.7209 - 112ms/epoch - 5ms/step
# Epoch 88/120
# 24/24 - 0s - loss: 0.4654 - accuracy: 0.7839 - val_loss: 0.4810 - val_accuracy: 0.7209 - 108ms/epoch - 5ms/step
# Epoch 89/120
# 24/24 - 0s - loss: 0.4710 - accuracy: 0.7734 - val_loss: 0.4774 - val_accuracy: 0.7209 - 105ms/epoch - 4ms/step
# Epoch 90/120
# 24/24 - 0s - loss: 0.4621 - accuracy: 0.7865 - val_loss: 0.4775 - val_accuracy: 0.7209 - 102ms/epoch - 4ms/step
# Epoch 91/120
# 24/24 - 0s - loss: 0.4525 - accuracy: 0.7865 - val_loss: 0.4725 - val_accuracy: 0.7209 - 103ms/epoch - 4ms/step
# Epoch 92/120
# 24/24 - 0s - loss: 0.4546 - accuracy: 0.7969 - val_loss: 0.4728 - val_accuracy: 0.7209 - 99ms/epoch - 4ms/step
# Epoch 93/120
# 24/24 - 0s - loss: 0.4457 - accuracy: 0.7943 - val_loss: 0.4771 - val_accuracy: 0.7209 - 103ms/epoch - 4ms/step
# Epoch 94/120
# 24/24 - 0s - loss: 0.4677 - accuracy: 0.7760 - val_loss: 0.4773 - val_accuracy: 0.7209 - 100ms/epoch - 4ms/step
# Epoch 95/120
# 24/24 - 0s - loss: 0.4727 - accuracy: 0.7839 - val_loss: 0.4785 - val_accuracy: 0.7209 - 170ms/epoch - 7ms/step
# Epoch 96/120
# 24/24 - 0s - loss: 0.4673 - accuracy: 0.7943 - val_loss: 0.4777 - val_accuracy: 0.7209 - 104ms/epoch - 4ms/step
# Epoch 97/120
# 24/24 - 0s - loss: 0.4631 - accuracy: 0.7839 - val_loss: 0.4754 - val_accuracy: 0.7209 - 101ms/epoch - 4ms/step
# Epoch 98/120
# 24/24 - 0s - loss: 0.4503 - accuracy: 0.7839 - val_loss: 0.4740 - val_accuracy: 0.7209 - 101ms/epoch - 4ms/step
# Epoch 99/120
# 24/24 - 0s - loss: 0.4515 - accuracy: 0.7891 - val_loss: 0.4680 - val_accuracy: 0.7209 - 121ms/epoch - 5ms/step
# Epoch 100/120
# 24/24 - 0s - loss: 0.4444 - accuracy: 0.8021 - val_loss: 0.4676 - val_accuracy: 0.6977 - 102ms/epoch - 4ms/step
# Epoch 101/120
# 24/24 - 0s - loss: 0.4477 - accuracy: 0.7812 - val_loss: 0.4688 - val_accuracy: 0.7209 - 99ms/epoch - 4ms/step
# Epoch 102/120
# 24/24 - 0s - loss: 0.4620 - accuracy: 0.7682 - val_loss: 0.4629 - val_accuracy: 0.7209 - 101ms/epoch - 4ms/step
# Epoch 103/120
# 24/24 - 0s - loss: 0.4581 - accuracy: 0.7917 - val_loss: 0.4632 - val_accuracy: 0.7209 - 113ms/epoch - 5ms/step
# Epoch 104/120
# 24/24 - 0s - loss: 0.4533 - accuracy: 0.7578 - val_loss: 0.4705 - val_accuracy: 0.7209 - 113ms/epoch - 5ms/step
# Epoch 105/120
# 24/24 - 0s - loss: 0.4452 - accuracy: 0.7917 - val_loss: 0.4689 - val_accuracy: 0.7209 - 108ms/epoch - 4ms/step
# Epoch 106/120
# 24/24 - 0s - loss: 0.4429 - accuracy: 0.7891 - val_loss: 0.4683 - val_accuracy: 0.7209 - 102ms/epoch - 4ms/step
# Epoch 107/120
# 24/24 - 0s - loss: 0.4595 - accuracy: 0.7839 - val_loss: 0.4681 - val_accuracy: 0.7209 - 106ms/epoch - 4ms/step
# Epoch 108/120
# 24/24 - 0s - loss: 0.4526 - accuracy: 0.7839 - val_loss: 0.4700 - val_accuracy: 0.7209 - 103ms/epoch - 4ms/step
# Epoch 109/120
# 24/24 - 0s - loss: 0.4540 - accuracy: 0.7786 - val_loss: 0.4679 - val_accuracy: 0.7209 - 104ms/epoch - 4ms/step
# Epoch 110/120
# 24/24 - 0s - loss: 0.4391 - accuracy: 0.8021 - val_loss: 0.4654 - val_accuracy: 0.7209 - 99ms/epoch - 4ms/step
# Epoch 111/120
# 24/24 - 0s - loss: 0.4494 - accuracy: 0.7865 - val_loss: 0.4720 - val_accuracy: 0.7209 - 99ms/epoch - 4ms/step
# Epoch 112/120
# 24/24 - 0s - loss: 0.4599 - accuracy: 0.7760 - val_loss: 0.4647 - val_accuracy: 0.7209 - 101ms/epoch - 4ms/step
# Epoch 113/120
# 24/24 - 0s - loss: 0.4588 - accuracy: 0.7891 - val_loss: 0.4630 - val_accuracy: 0.7209 - 98ms/epoch - 4ms/step
# Epoch 114/120
# 24/24 - 0s - loss: 0.4424 - accuracy: 0.7839 - val_loss: 0.4629 - val_accuracy: 0.7209 - 93ms/epoch - 4ms/step
# Epoch 115/120
# 24/24 - 0s - loss: 0.4411 - accuracy: 0.7786 - val_loss: 0.4623 - val_accuracy: 0.7442 - 97ms/epoch - 4ms/step
# Epoch 116/120
# 24/24 - 0s - loss: 0.4455 - accuracy: 0.7891 - val_loss: 0.4593 - val_accuracy: 0.7209 - 97ms/epoch - 4ms/step
# Epoch 117/120
# 24/24 - 0s - loss: 0.4387 - accuracy: 0.7917 - val_loss: 0.4584 - val_accuracy: 0.7209 - 98ms/epoch - 4ms/step
# Epoch 118/120
# 24/24 - 0s - loss: 0.4551 - accuracy: 0.7682 - val_loss: 0.4607 - val_accuracy: 0.7209 - 100ms/epoch - 4ms/step
# Epoch 119/120
# 24/24 - 0s - loss: 0.4432 - accuracy: 0.8125 - val_loss: 0.4662 - val_accuracy: 0.7209 - 99ms/epoch - 4ms/step
# Epoch 120/120
# 24/24 - 0s - loss: 0.4365 - accuracy: 0.7969 - val_loss: 0.4601 - val_accuracy: 0.7209 - 97ms/epoch - 4ms/step

# %% [markdown]
# Evaluate the model

# %%
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, confusion_matrix, classification_report
)

# Predict probabilities
y_pred_prob = model.predict(X_test).ravel()

# Convert to binary output
y_pred = (y_pred_prob >= 0.5).astype(int)

# Classification report
print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))

# Confusion Matrix
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))

# Individual metrics
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall:", recall_score(y_test, y_pred))
print("F1 Score:", f1_score(y_test, y_pred))
# Out:
# 4/4 [==============================] - 0s 3ms/step
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.67      0.71      0.69        49
#            1       0.75      0.71      0.73        58
#
#     accuracy                           0.71       107
#    macro avg       0.71      0.71      0.71       107
# weighted avg       0.71      0.71      0.71       107
#
# Confusion Matrix:
# [[35 14]
#  [17 41]]
# Accuracy: 0.7102803738317757
# Precision: 0.7454545454545455
# Recall: 0.7068965517241379
# F1 Score: 0.7256637168141592

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot training & validation loss
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
