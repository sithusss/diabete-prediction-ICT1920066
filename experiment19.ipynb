# %%
# %pip install tensorflow seaborn


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.impute import KNNImputer
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_curve, auc

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# Out:
# [notice] A new release of pip available: 22.2.2 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: tensorflow in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (2.10.1)
# Requirement already satisfied: seaborn in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (0.13.2)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (2.10.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (4.11.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (1.64.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: setuptools in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (69.5.1)
# Requirement already satisfied: numpy>=1.20 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (1.26.4)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (3.19.6)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (0.31.0)
# Requirement already satisfied: packaging in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (23.2)
# Requirement already satisfied: keras<2.11,>=2.10.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from seaborn) (3.9.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.43.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: pillow>=8 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (10.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.53.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.1.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (3.0.3)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (3.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.29.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (2.32.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (1.8.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow) (0.6.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.4.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (2.0.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2.2.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.11,>=2.10->tensorflow) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow) (2.1.3)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow) (0.6.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow) (3.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (0.13.0)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from imbalanced-learn) (3.5.0)
# Requirement already satisfied: scipy<2,>=1.10.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from imbalanced-learn) (1.13.1)
# Requirement already satisfied: numpy<3,>=1.24.3 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from imbalanced-learn) (1.26.4)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from imbalanced-learn) (0.1.3)
# Requirement already satisfied: joblib<2,>=1.1.1 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from imbalanced-learn) (1.4.2)
# Requirement already satisfied: scikit-learn<2,>=1.3.2 in c:\users\ww\anaconda3\envs\mediapip\lib\site-packages (from imbalanced-learn) (1.5.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.2.2 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# load dataset

# %%
# Load Pima Indian Diabetes dataset
df = pd.read_csv("F:/RUSL/4- 1/ICT 4302 - Intelligent Systems/miniProject1/diabetes.csv")

df.columns = df.columns.str.strip()  # Clean header spaces
for col in df.columns:
    if col != 'Outcome':
        df[col] = pd.to_numeric(df[col], errors='coerce')  # Convert non-numeric to NaN

numeric_df = df.select_dtypes(include=['number'])

df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# Data preprocessing

# %% [markdown]
# step 1 - Replace invalid zeros with NaN (handle missing values)

# %%
cols_with_missing = ["Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI"]

# Replace 0 with np.nan only for these features
df[cols_with_missing] = df[cols_with_missing].replace(0, np.nan)

# %%
# Remove rows with too many missing values
def drop_rows_with_many_missing(df, threshold_cols=4):
    return df[df[cols_with_missing].isnull().sum(axis=1) < threshold_cols]

df = drop_rows_with_many_missing(df)

# %%
# Define columns for different strategies
median_columns = ["Glucose", "BloodPressure"]
knn_columns = ["SkinThickness", "Insulin", "BMI"]

# %% [markdown]
# step 2 - fill missing values using the median of the same class

# %%
# Apply same-class median imputation
def impute_same_class_median(df, columns, class_col="Outcome"):
    for col in columns:
        df[col] = df.groupby(class_col)[col].transform(lambda x: x.fillna(x.median()))
    return df

df = impute_same_class_median(df, median_columns)

# %%
# Apply KNN Imputer for selected columns
def knn_impute(df, columns, n_neighbors=5):
    imputer = KNNImputer(n_neighbors=n_neighbors)
    df[columns] = imputer.fit_transform(df[columns])
    return df

df = knn_impute(df, knn_columns)

# %%
# Normalize features (optional but recommended)
from sklearn.preprocessing import MinMaxScaler


features = df.columns[:-1]  # Exclude Outcome
scaler = MinMaxScaler()
df[features] = scaler.fit_transform(df[features])

# %%
print("✅ Cleaned dataset ready for model:")
display(df.head())
# Out:
# ✅ Cleaned dataset ready for model:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     0.352941  0.670968       0.489796       0.304348  0.213221  0.314928
# 1     0.058824  0.264516       0.428571       0.239130  0.128125  0.171779
# 2     0.470588  0.896774       0.408163       0.106522  0.106010  0.104294
# 3     0.058824  0.290323       0.428571       0.173913  0.096154  0.202454
# 4     0.000000  0.600000       0.163265       0.304348  0.185096  0.509202
#
#    DiabetesPedigreeFunction       Age  Outcome
# 0                  0.234415  0.483333        1
# 1                  0.116567  0.166667        0
# 2                  0.253629  0.183333        1
# 3                  0.038002  0.000000        0
# 4                  0.943638  0.200000        1

# %%
# Step 1: Split features and labels
X = df.drop("Outcome", axis=1)
y = df["Outcome"]

# Step 2: Apply SMOTE
from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state=42)
X_resampled, y_resampled = sm.fit_resample(X, y)

# %% [markdown]
# data split

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.1)

# %% [markdown]
# build custom keras model

# %%
model = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    layers.Dropout(0.2),
    layers.Dense(32, activation='relu'),
    layers.Dense(16, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='RMSprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])
#add extra hidden layer and change number of nodes in each layer

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 64)                576
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 32)                2080
#
#  dense_6 (Dense)             (None, 16)                528
#
#  dense_7 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 3,201
# Trainable params: 3,201
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Train the model

# %%
from tensorflow.keras.callbacks import EarlyStopping

early_stop = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = model.fit(X_train, y_train, epochs=100, batch_size=16, validation_split=0.2, verbose=2) #change validation split from 0.2-> 0.1
# Out:
# Epoch 1/100
# 45/45 - 4s - loss: 0.6872 - accuracy: 0.4965 - val_loss: 0.6742 - val_accuracy: 0.5393 - 4s/epoch - 97ms/step
# Epoch 2/100
# 45/45 - 1s - loss: 0.6666 - accuracy: 0.5724 - val_loss: 0.6517 - val_accuracy: 0.6348 - 561ms/epoch - 12ms/step
# Epoch 3/100
# 45/45 - 1s - loss: 0.6405 - accuracy: 0.6695 - val_loss: 0.6232 - val_accuracy: 0.7079 - 552ms/epoch - 12ms/step
# Epoch 4/100
# 45/45 - 1s - loss: 0.6098 - accuracy: 0.7173 - val_loss: 0.5963 - val_accuracy: 0.7303 - 562ms/epoch - 12ms/step
# Epoch 5/100
# 45/45 - 1s - loss: 0.5795 - accuracy: 0.7553 - val_loss: 0.5622 - val_accuracy: 0.7303 - 543ms/epoch - 12ms/step
# Epoch 6/100
# 45/45 - 0s - loss: 0.5531 - accuracy: 0.7370 - val_loss: 0.5464 - val_accuracy: 0.7303 - 468ms/epoch - 10ms/step
# Epoch 7/100
# 45/45 - 1s - loss: 0.5265 - accuracy: 0.7651 - val_loss: 0.5227 - val_accuracy: 0.7303 - 557ms/epoch - 12ms/step
# Epoch 8/100
# 45/45 - 1s - loss: 0.5298 - accuracy: 0.7426 - val_loss: 0.5168 - val_accuracy: 0.7528 - 667ms/epoch - 15ms/step
# Epoch 9/100
# 45/45 - 1s - loss: 0.5135 - accuracy: 0.7637 - val_loss: 0.5033 - val_accuracy: 0.7472 - 705ms/epoch - 16ms/step
# Epoch 10/100
# 45/45 - 1s - loss: 0.5010 - accuracy: 0.7764 - val_loss: 0.4971 - val_accuracy: 0.7360 - 735ms/epoch - 16ms/step
# Epoch 11/100
# 45/45 - 1s - loss: 0.5063 - accuracy: 0.7539 - val_loss: 0.4926 - val_accuracy: 0.7753 - 527ms/epoch - 12ms/step
# Epoch 12/100
# 45/45 - 0s - loss: 0.4940 - accuracy: 0.7482 - val_loss: 0.4865 - val_accuracy: 0.7472 - 473ms/epoch - 11ms/step
# Epoch 13/100
# 45/45 - 0s - loss: 0.4931 - accuracy: 0.7707 - val_loss: 0.4820 - val_accuracy: 0.7528 - 465ms/epoch - 10ms/step
# Epoch 14/100
# 45/45 - 1s - loss: 0.4944 - accuracy: 0.7496 - val_loss: 0.4844 - val_accuracy: 0.7753 - 683ms/epoch - 15ms/step
# Epoch 15/100
# 45/45 - 1s - loss: 0.4920 - accuracy: 0.7609 - val_loss: 0.4831 - val_accuracy: 0.7416 - 720ms/epoch - 16ms/step
# Epoch 16/100
# 45/45 - 0s - loss: 0.4675 - accuracy: 0.7722 - val_loss: 0.5094 - val_accuracy: 0.7921 - 480ms/epoch - 11ms/step
# Epoch 17/100
# 45/45 - 0s - loss: 0.4863 - accuracy: 0.7609 - val_loss: 0.4758 - val_accuracy: 0.7697 - 500ms/epoch - 11ms/step
# Epoch 18/100
# 45/45 - 1s - loss: 0.4718 - accuracy: 0.7736 - val_loss: 0.4738 - val_accuracy: 0.7416 - 538ms/epoch - 12ms/step
# Epoch 19/100
# 45/45 - 0s - loss: 0.4736 - accuracy: 0.7764 - val_loss: 0.4851 - val_accuracy: 0.7753 - 454ms/epoch - 10ms/step
# Epoch 20/100
# 45/45 - 0s - loss: 0.4796 - accuracy: 0.7750 - val_loss: 0.4841 - val_accuracy: 0.7697 - 457ms/epoch - 10ms/step
# Epoch 21/100
# 45/45 - 1s - loss: 0.4694 - accuracy: 0.7623 - val_loss: 0.4781 - val_accuracy: 0.7865 - 563ms/epoch - 13ms/step
# Epoch 22/100
# 45/45 - 1s - loss: 0.4763 - accuracy: 0.7651 - val_loss: 0.4802 - val_accuracy: 0.7921 - 569ms/epoch - 13ms/step
# Epoch 23/100
# 45/45 - 1s - loss: 0.4747 - accuracy: 0.7806 - val_loss: 0.4718 - val_accuracy: 0.7360 - 679ms/epoch - 15ms/step
# Epoch 24/100
# 45/45 - 1s - loss: 0.4780 - accuracy: 0.7778 - val_loss: 0.4661 - val_accuracy: 0.7472 - 679ms/epoch - 15ms/step
# Epoch 25/100
# 45/45 - 1s - loss: 0.4641 - accuracy: 0.7890 - val_loss: 0.4630 - val_accuracy: 0.7809 - 661ms/epoch - 15ms/step
# Epoch 26/100
# 45/45 - 1s - loss: 0.4736 - accuracy: 0.7778 - val_loss: 0.4731 - val_accuracy: 0.7360 - 645ms/epoch - 14ms/step
# Epoch 27/100
# 45/45 - 1s - loss: 0.4661 - accuracy: 0.7778 - val_loss: 0.4768 - val_accuracy: 0.8090 - 665ms/epoch - 15ms/step
# Epoch 28/100
# 45/45 - 1s - loss: 0.4575 - accuracy: 0.7834 - val_loss: 0.5019 - val_accuracy: 0.7753 - 633ms/epoch - 14ms/step
# Epoch 29/100
# 45/45 - 1s - loss: 0.4572 - accuracy: 0.7918 - val_loss: 0.4644 - val_accuracy: 0.7472 - 644ms/epoch - 14ms/step
# Epoch 30/100
# 45/45 - 1s - loss: 0.4609 - accuracy: 0.7778 - val_loss: 0.4617 - val_accuracy: 0.7472 - 605ms/epoch - 13ms/step
# Epoch 31/100
# 45/45 - 1s - loss: 0.4577 - accuracy: 0.7947 - val_loss: 0.4605 - val_accuracy: 0.7640 - 636ms/epoch - 14ms/step
# Epoch 32/100
# 45/45 - 1s - loss: 0.4583 - accuracy: 0.7750 - val_loss: 0.4568 - val_accuracy: 0.7697 - 625ms/epoch - 14ms/step
# Epoch 33/100
# 45/45 - 1s - loss: 0.4506 - accuracy: 0.8003 - val_loss: 0.4583 - val_accuracy: 0.7697 - 617ms/epoch - 14ms/step
# Epoch 34/100
# 45/45 - 1s - loss: 0.4566 - accuracy: 0.7862 - val_loss: 0.4645 - val_accuracy: 0.7921 - 670ms/epoch - 15ms/step
# Epoch 35/100
# 45/45 - 1s - loss: 0.4550 - accuracy: 0.7890 - val_loss: 0.4585 - val_accuracy: 0.7528 - 695ms/epoch - 15ms/step
# Epoch 36/100
# 45/45 - 1s - loss: 0.4529 - accuracy: 0.7834 - val_loss: 0.4613 - val_accuracy: 0.7921 - 665ms/epoch - 15ms/step
# Epoch 37/100
# 45/45 - 1s - loss: 0.4504 - accuracy: 0.7890 - val_loss: 0.4537 - val_accuracy: 0.7753 - 654ms/epoch - 15ms/step
# Epoch 38/100
# 45/45 - 1s - loss: 0.4515 - accuracy: 0.7820 - val_loss: 0.4565 - val_accuracy: 0.7584 - 728ms/epoch - 16ms/step
# Epoch 39/100
# 45/45 - 1s - loss: 0.4388 - accuracy: 0.7975 - val_loss: 0.4801 - val_accuracy: 0.7303 - 714ms/epoch - 16ms/step
# Epoch 40/100
# 45/45 - 1s - loss: 0.4451 - accuracy: 0.7904 - val_loss: 0.4540 - val_accuracy: 0.7865 - 723ms/epoch - 16ms/step
# Epoch 41/100
# 45/45 - 1s - loss: 0.4562 - accuracy: 0.7764 - val_loss: 0.4536 - val_accuracy: 0.7640 - 748ms/epoch - 17ms/step
# Epoch 42/100
# 45/45 - 1s - loss: 0.4389 - accuracy: 0.7989 - val_loss: 0.4520 - val_accuracy: 0.7865 - 687ms/epoch - 15ms/step
# Epoch 43/100
# 45/45 - 1s - loss: 0.4566 - accuracy: 0.7961 - val_loss: 0.4639 - val_accuracy: 0.8146 - 686ms/epoch - 15ms/step
# Epoch 44/100
# 45/45 - 1s - loss: 0.4436 - accuracy: 0.7904 - val_loss: 0.4463 - val_accuracy: 0.7921 - 632ms/epoch - 14ms/step
# Epoch 45/100
# 45/45 - 1s - loss: 0.4409 - accuracy: 0.8003 - val_loss: 0.4452 - val_accuracy: 0.7809 - 713ms/epoch - 16ms/step
# Epoch 46/100
# 45/45 - 1s - loss: 0.4402 - accuracy: 0.7961 - val_loss: 0.4530 - val_accuracy: 0.8315 - 708ms/epoch - 16ms/step
# Epoch 47/100
# 45/45 - 1s - loss: 0.4489 - accuracy: 0.7764 - val_loss: 0.4491 - val_accuracy: 0.7640 - 680ms/epoch - 15ms/step
# Epoch 48/100
# 45/45 - 1s - loss: 0.4466 - accuracy: 0.7932 - val_loss: 0.4503 - val_accuracy: 0.7584 - 677ms/epoch - 15ms/step
# Epoch 49/100
# 45/45 - 1s - loss: 0.4461 - accuracy: 0.7961 - val_loss: 0.4456 - val_accuracy: 0.8258 - 704ms/epoch - 16ms/step
# Epoch 50/100
# 45/45 - 1s - loss: 0.4469 - accuracy: 0.7848 - val_loss: 0.4479 - val_accuracy: 0.8146 - 684ms/epoch - 15ms/step
# Epoch 51/100
# 45/45 - 1s - loss: 0.4502 - accuracy: 0.7975 - val_loss: 0.4431 - val_accuracy: 0.8202 - 658ms/epoch - 15ms/step
# Epoch 52/100
# 45/45 - 1s - loss: 0.4410 - accuracy: 0.7947 - val_loss: 0.4502 - val_accuracy: 0.8090 - 617ms/epoch - 14ms/step
# Epoch 53/100
# 45/45 - 1s - loss: 0.4414 - accuracy: 0.8003 - val_loss: 0.4426 - val_accuracy: 0.7921 - 611ms/epoch - 14ms/step
# Epoch 54/100
# 45/45 - 1s - loss: 0.4226 - accuracy: 0.8017 - val_loss: 0.4480 - val_accuracy: 0.7809 - 611ms/epoch - 14ms/step
# Epoch 55/100
# 45/45 - 1s - loss: 0.4335 - accuracy: 0.7989 - val_loss: 0.4497 - val_accuracy: 0.7697 - 664ms/epoch - 15ms/step
# Epoch 56/100
# 45/45 - 1s - loss: 0.4358 - accuracy: 0.7989 - val_loss: 0.4435 - val_accuracy: 0.7809 - 681ms/epoch - 15ms/step
# Epoch 57/100
# 45/45 - 1s - loss: 0.4414 - accuracy: 0.7961 - val_loss: 0.4975 - val_accuracy: 0.7865 - 672ms/epoch - 15ms/step
# Epoch 58/100
# 45/45 - 1s - loss: 0.4247 - accuracy: 0.8101 - val_loss: 0.4503 - val_accuracy: 0.7697 - 649ms/epoch - 14ms/step
# Epoch 59/100
# 45/45 - 1s - loss: 0.4391 - accuracy: 0.7707 - val_loss: 0.4552 - val_accuracy: 0.8258 - 647ms/epoch - 14ms/step
# Epoch 60/100
# 45/45 - 1s - loss: 0.4274 - accuracy: 0.8129 - val_loss: 0.4519 - val_accuracy: 0.7584 - 723ms/epoch - 16ms/step
# Epoch 61/100
# 45/45 - 1s - loss: 0.4329 - accuracy: 0.8073 - val_loss: 0.4389 - val_accuracy: 0.7809 - 654ms/epoch - 15ms/step
# Epoch 62/100
# 45/45 - 1s - loss: 0.4396 - accuracy: 0.8003 - val_loss: 0.4480 - val_accuracy: 0.7753 - 677ms/epoch - 15ms/step
# Epoch 63/100
# 45/45 - 1s - loss: 0.4330 - accuracy: 0.8017 - val_loss: 0.4437 - val_accuracy: 0.7978 - 673ms/epoch - 15ms/step
# Epoch 64/100
# 45/45 - 1s - loss: 0.4207 - accuracy: 0.8003 - val_loss: 0.4413 - val_accuracy: 0.7865 - 680ms/epoch - 15ms/step
# Epoch 65/100
# 45/45 - 1s - loss: 0.4225 - accuracy: 0.7989 - val_loss: 0.4513 - val_accuracy: 0.8090 - 723ms/epoch - 16ms/step
# Epoch 66/100
# 45/45 - 1s - loss: 0.4260 - accuracy: 0.7975 - val_loss: 0.4648 - val_accuracy: 0.8090 - 739ms/epoch - 16ms/step
# Epoch 67/100
# 45/45 - 1s - loss: 0.4240 - accuracy: 0.7890 - val_loss: 0.4403 - val_accuracy: 0.7753 - 717ms/epoch - 16ms/step
# Epoch 68/100
# 45/45 - 1s - loss: 0.4305 - accuracy: 0.8031 - val_loss: 0.4457 - val_accuracy: 0.7528 - 701ms/epoch - 16ms/step
# Epoch 69/100
# 45/45 - 1s - loss: 0.4336 - accuracy: 0.7975 - val_loss: 0.4448 - val_accuracy: 0.8090 - 670ms/epoch - 15ms/step
# Epoch 70/100
# 45/45 - 1s - loss: 0.4315 - accuracy: 0.8129 - val_loss: 0.4682 - val_accuracy: 0.8090 - 708ms/epoch - 16ms/step
# Epoch 71/100
# 45/45 - 1s - loss: 0.4316 - accuracy: 0.7975 - val_loss: 0.4357 - val_accuracy: 0.7921 - 716ms/epoch - 16ms/step
# Epoch 72/100
# 45/45 - 1s - loss: 0.4144 - accuracy: 0.8242 - val_loss: 0.5002 - val_accuracy: 0.7697 - 637ms/epoch - 14ms/step
# Epoch 73/100
# 45/45 - 1s - loss: 0.4366 - accuracy: 0.7932 - val_loss: 0.4363 - val_accuracy: 0.8034 - 694ms/epoch - 15ms/step
# Epoch 74/100
# 45/45 - 1s - loss: 0.4208 - accuracy: 0.8087 - val_loss: 0.4575 - val_accuracy: 0.7528 - 695ms/epoch - 15ms/step
# Epoch 75/100
# 45/45 - 1s - loss: 0.4250 - accuracy: 0.8087 - val_loss: 0.4649 - val_accuracy: 0.7416 - 667ms/epoch - 15ms/step
# Epoch 76/100
# 45/45 - 1s - loss: 0.4193 - accuracy: 0.8073 - val_loss: 0.4388 - val_accuracy: 0.7921 - 692ms/epoch - 15ms/step
# Epoch 77/100
# 45/45 - 1s - loss: 0.4174 - accuracy: 0.8087 - val_loss: 0.4365 - val_accuracy: 0.7921 - 741ms/epoch - 16ms/step
# Epoch 78/100
# 45/45 - 1s - loss: 0.4266 - accuracy: 0.7918 - val_loss: 0.4339 - val_accuracy: 0.8090 - 685ms/epoch - 15ms/step
# Epoch 79/100
# 45/45 - 1s - loss: 0.4094 - accuracy: 0.7989 - val_loss: 0.4414 - val_accuracy: 0.7753 - 849ms/epoch - 19ms/step
# Epoch 80/100
# 45/45 - 1s - loss: 0.4188 - accuracy: 0.8059 - val_loss: 0.4360 - val_accuracy: 0.8034 - 706ms/epoch - 16ms/step
# Epoch 81/100
# 45/45 - 1s - loss: 0.4120 - accuracy: 0.8003 - val_loss: 0.4445 - val_accuracy: 0.8146 - 672ms/epoch - 15ms/step
# Epoch 82/100
# 45/45 - 1s - loss: 0.4111 - accuracy: 0.8101 - val_loss: 0.4561 - val_accuracy: 0.7865 - 655ms/epoch - 15ms/step
# Epoch 83/100
# 45/45 - 1s - loss: 0.4294 - accuracy: 0.8017 - val_loss: 0.4460 - val_accuracy: 0.8034 - 701ms/epoch - 16ms/step
# Epoch 84/100
# 45/45 - 1s - loss: 0.4140 - accuracy: 0.8045 - val_loss: 0.4500 - val_accuracy: 0.7978 - 763ms/epoch - 17ms/step
# Epoch 85/100
# 45/45 - 1s - loss: 0.4115 - accuracy: 0.8242 - val_loss: 0.4524 - val_accuracy: 0.8202 - 780ms/epoch - 17ms/step
# Epoch 86/100
# 45/45 - 1s - loss: 0.4095 - accuracy: 0.7975 - val_loss: 0.4586 - val_accuracy: 0.7978 - 801ms/epoch - 18ms/step
# Epoch 87/100
# 45/45 - 1s - loss: 0.4149 - accuracy: 0.8143 - val_loss: 0.4481 - val_accuracy: 0.7865 - 784ms/epoch - 17ms/step
# Epoch 88/100
# 45/45 - 1s - loss: 0.4107 - accuracy: 0.8228 - val_loss: 0.4386 - val_accuracy: 0.8202 - 849ms/epoch - 19ms/step
# Epoch 89/100
# 45/45 - 1s - loss: 0.4006 - accuracy: 0.8256 - val_loss: 0.4399 - val_accuracy: 0.7921 - 916ms/epoch - 20ms/step
# Epoch 90/100
# 45/45 - 1s - loss: 0.4005 - accuracy: 0.8158 - val_loss: 0.4430 - val_accuracy: 0.8034 - 907ms/epoch - 20ms/step
# Epoch 91/100
# 45/45 - 1s - loss: 0.4151 - accuracy: 0.8031 - val_loss: 0.4462 - val_accuracy: 0.7865 - 868ms/epoch - 19ms/step
# Epoch 92/100
# 45/45 - 1s - loss: 0.4112 - accuracy: 0.8115 - val_loss: 0.4647 - val_accuracy: 0.7640 - 896ms/epoch - 20ms/step
# Epoch 93/100
# 45/45 - 1s - loss: 0.4160 - accuracy: 0.7961 - val_loss: 0.4491 - val_accuracy: 0.7921 - 1s/epoch - 28ms/step
# Epoch 94/100
# 45/45 - 1s - loss: 0.4124 - accuracy: 0.8073 - val_loss: 0.4495 - val_accuracy: 0.8034 - 931ms/epoch - 21ms/step
# Epoch 95/100
# 45/45 - 1s - loss: 0.4143 - accuracy: 0.8045 - val_loss: 0.4470 - val_accuracy: 0.7921 - 695ms/epoch - 15ms/step
# Epoch 96/100
# 45/45 - 1s - loss: 0.4169 - accuracy: 0.8003 - val_loss: 0.4506 - val_accuracy: 0.7978 - 618ms/epoch - 14ms/step
# Epoch 97/100
# 45/45 - 1s - loss: 0.4060 - accuracy: 0.8129 - val_loss: 0.4565 - val_accuracy: 0.8090 - 628ms/epoch - 14ms/step
# Epoch 98/100
# 45/45 - 1s - loss: 0.4035 - accuracy: 0.8214 - val_loss: 0.4536 - val_accuracy: 0.8146 - 602ms/epoch - 13ms/step
# Epoch 99/100
# 45/45 - 1s - loss: 0.3959 - accuracy: 0.8172 - val_loss: 0.4474 - val_accuracy: 0.8034 - 714ms/epoch - 16ms/step
# Epoch 100/100
# 45/45 - 1s - loss: 0.4105 - accuracy: 0.8017 - val_loss: 0.4469 - val_accuracy: 0.8202 - 948ms/epoch - 21ms/step

# %% [markdown]
# Evaluate the model

# %%
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, confusion_matrix, classification_report
)

# Predict probabilities
y_pred_prob = model.predict(X_test).ravel()

# Convert to binary output
y_pred = (y_pred_prob >= 0.5).astype(int)

# Classification report
print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))

# Confusion Matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# Generate confusion matrix
cm = confusion_matrix(y_test, y_pred)
labels = ['No Diabetes', 'Diabetes']

# Plot
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)

plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.tight_layout()
plt.show()


# Individual metrics
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall:", recall_score(y_test, y_pred))
print("F1 Score:", f1_score(y_test, y_pred))
# Out:
# 4/4 [==============================] - 0s 8ms/step
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.78      0.80        45
#            1       0.82      0.87      0.85        54
#
#     accuracy                           0.83        99
#    macro avg       0.83      0.82      0.83        99
# weighted avg       0.83      0.83      0.83        99
# Accuracy: 0.8282828282828283
# Precision: 0.8245614035087719
# Recall: 0.8703703703703703
# F1 Score: 0.8468468468468469

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot training & validation loss
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# Predict probabilities for the test set
y_pred_prob = model.predict(X_test).ravel()  # Already flattened

# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)

# Calculate AUC score
auc_score = roc_auc_score(y_test, y_pred_prob)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC Curve (AUC = {auc_score:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')  # Diagonal line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()
# Out:
# 4/4 [==============================] - 0s 7ms/step
