# %%
# %pip install tensorflow seaborn
# %pip install imbalanced-learn


import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.impute import KNNImputer
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, roc_curve, auc

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
# Out:
# Requirement already satisfied: tensorflow in c:\users\ww\anaconda3\envs\iis\lib\site-packages (2.11.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: seaborn in c:\users\ww\anaconda3\envs\iis\lib\site-packages (0.12.2)
# Requirement already satisfied: tensorflow-intel==2.11.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow) (2.11.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.8.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (18.1.1)
# Requirement already satisfied: numpy>=1.20 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.21.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (24.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (3.19.6)
# Requirement already satisfied: setuptools in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (65.6.3)
# Requirement already satisfied: six>=1.12.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.3.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (4.7.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (1.62.2)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.2)
# Requirement already satisfied: tensorflow-estimator<2.12,>=2.11.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: keras<2.12,>=2.11.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (2.11.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorflow-intel==2.11.0->tensorflow) (0.31.0)
# Requirement already satisfied: pandas>=0.25 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from seaborn) (1.3.5)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from seaborn) (3.5.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.5.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2017.3 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from pandas>=0.25->seaborn) (2024.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.11.0->tensorflow) (0.38.4)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.29.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.4.4)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.2.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.0)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (6.7.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2022.12.7)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (2.1.5)
# Requirement already satisfied: zipp>=0.5 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.15.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\ww\anaconda3\envs\iis\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow-intel==2.11.0->tensorflow) (3.2.2)

# %% [markdown]
# load dataset

# %%
# Load Pima Indian Diabetes dataset
df = pd.read_csv("F:/RUSL/4- 1/ICT 4302 - Intelligent Systems/miniProject1/diabetes.csv")

df.columns = df.columns.str.strip()  # Clean header spaces
for col in df.columns:
    if col != 'Outcome':
        df[col] = pd.to_numeric(df[col], errors='coerce')  # Convert non-numeric to NaN

numeric_df = df.select_dtypes(include=['number'])

df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# Data preprocessing

# %% [markdown]
# step 1 - Replace invalid zeros with NaN (handle missing values)

# %%
cols_with_missing = ["Glucose", "BloodPressure", "SkinThickness", "Insulin", "BMI"]

# Replace 0 with np.nan only for these features
df[cols_with_missing] = df[cols_with_missing].replace(0, np.nan)

# %%
# Remove rows with too many missing values
def drop_rows_with_many_missing(df, threshold_cols=4):
    return df[df[cols_with_missing].isnull().sum(axis=1) < threshold_cols]

df = drop_rows_with_many_missing(df)

# %%
# Define columns for different strategies
median_columns = ["Glucose", "BloodPressure"]
knn_columns = ["SkinThickness", "Insulin", "BMI"]

# %% [markdown]
# step 2 - fill missing values using the median of the same class

# %%
# Apply same-class median imputation
def impute_same_class_median(df, columns, class_col="Outcome"):
    for col in columns:
        df[col] = df.groupby(class_col)[col].transform(lambda x: x.fillna(x.median()))
    return df

df = impute_same_class_median(df, median_columns)

# %%
# Apply KNN Imputer for selected columns
def knn_impute(df, columns, n_neighbors=5):
    imputer = KNNImputer(n_neighbors=n_neighbors)
    df[columns] = imputer.fit_transform(df[columns])
    return df

df = knn_impute(df, knn_columns)

# %%
# Normalize features (optional but recommended)
from sklearn.preprocessing import MinMaxScaler


features = df.columns[:-1]  # Exclude Outcome
scaler = MinMaxScaler()
df[features] = scaler.fit_transform(df[features])

# %%
print("✅ Cleaned dataset ready for model:")
display(df.head())
# Out:
# ✅ Cleaned dataset ready for model:
#    Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin       BMI  \
# 0     0.352941  0.670968       0.489796       0.304348  0.213221  0.314928
# 1     0.058824  0.264516       0.428571       0.239130  0.128125  0.171779
# 2     0.470588  0.896774       0.408163       0.106522  0.106010  0.104294
# 3     0.058824  0.290323       0.428571       0.173913  0.096154  0.202454
# 4     0.000000  0.600000       0.163265       0.304348  0.185096  0.509202
#
#    DiabetesPedigreeFunction       Age  Outcome
# 0                  0.234415  0.483333        1
# 1                  0.116567  0.166667        0
# 2                  0.253629  0.183333        1
# 3                  0.038002  0.000000        0
# 4                  0.943638  0.200000        1

# %%
from imblearn.over_sampling import SMOTE

# Create a SMOTE object
sm = SMOTE(random_state=42)

# Apply SMOTE to your features (X) and labels (y)
X_resampled, y_resampled = sm.fit_resample(X, y)

# %%
X = X_resampled.drop("Outcome", axis=1)
y = y_resampled["Outcome"]

# %% [markdown]
# data split

# %%
# Train-test split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1)

# %% [markdown]
# build custom keras model

# %%
model = keras.Sequential([
    layers.Dense(64, activation='relu', input_shape=(X_train.shape[1],)),
    layers.Dropout(0.3),  # Dropout layer to prevent overfitting
    layers.Dense(32, activation='relu'),
    layers.Dropout(0.2),  # Dropout layer to prevent overfitting
    layers.Dense(16, activation='relu'),
    layers.Dense(8, activation='relu'),
    layers.Dense(1, activation='sigmoid')  # Binary output
])

model.compile(optimizer='RMSprop',
              loss='binary_crossentropy',
              metrics=['accuracy'])
#add extra hidden layer and change number of nodes in each layer

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 64)                576
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 16)                1040
#
#  dense_2 (Dense)             (None, 1)                 17
#
# =================================================================
# Total params: 1,633
# Trainable params: 1,633
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Train the model

# %%
history = model.fit(X_train, y_train, epochs=100, batch_size=16, validation_split=0.1, verbose=2) #change validation0split from 0.2-> 0.1
# Out:
# Epoch 1/100
# 27/27 - 2s - loss: 0.6840 - accuracy: 0.5486 - val_loss: 0.6882 - val_accuracy: 0.4583 - 2s/epoch - 65ms/step
# Epoch 2/100
# 27/27 - 0s - loss: 0.6725 - accuracy: 0.5903 - val_loss: 0.6748 - val_accuracy: 0.5833 - 108ms/epoch - 4ms/step
# Epoch 3/100
# 27/27 - 0s - loss: 0.6606 - accuracy: 0.6736 - val_loss: 0.6597 - val_accuracy: 0.7083 - 110ms/epoch - 4ms/step
# Epoch 4/100
# 27/27 - 0s - loss: 0.6535 - accuracy: 0.6481 - val_loss: 0.6470 - val_accuracy: 0.7083 - 128ms/epoch - 5ms/step
# Epoch 5/100
# 27/27 - 0s - loss: 0.6332 - accuracy: 0.6829 - val_loss: 0.6283 - val_accuracy: 0.7083 - 120ms/epoch - 4ms/step
# Epoch 6/100
# 27/27 - 0s - loss: 0.6260 - accuracy: 0.6852 - val_loss: 0.6183 - val_accuracy: 0.7292 - 135ms/epoch - 5ms/step
# Epoch 7/100
# 27/27 - 0s - loss: 0.6027 - accuracy: 0.7454 - val_loss: 0.6030 - val_accuracy: 0.6875 - 153ms/epoch - 6ms/step
# Epoch 8/100
# 27/27 - 0s - loss: 0.6077 - accuracy: 0.7130 - val_loss: 0.5965 - val_accuracy: 0.6875 - 143ms/epoch - 5ms/step
# Epoch 9/100
# 27/27 - 0s - loss: 0.5902 - accuracy: 0.6991 - val_loss: 0.5901 - val_accuracy: 0.7083 - 94ms/epoch - 3ms/step
# Epoch 10/100
# 27/27 - 0s - loss: 0.5893 - accuracy: 0.7222 - val_loss: 0.5791 - val_accuracy: 0.7292 - 99ms/epoch - 4ms/step
# Epoch 11/100
# 27/27 - 0s - loss: 0.5783 - accuracy: 0.6968 - val_loss: 0.5736 - val_accuracy: 0.7083 - 113ms/epoch - 4ms/step
# Epoch 12/100
# 27/27 - 0s - loss: 0.5698 - accuracy: 0.7176 - val_loss: 0.5685 - val_accuracy: 0.7292 - 110ms/epoch - 4ms/step
# Epoch 13/100
# 27/27 - 0s - loss: 0.5672 - accuracy: 0.7106 - val_loss: 0.5633 - val_accuracy: 0.7083 - 133ms/epoch - 5ms/step
# Epoch 14/100
# 27/27 - 0s - loss: 0.5575 - accuracy: 0.7384 - val_loss: 0.5592 - val_accuracy: 0.7292 - 129ms/epoch - 5ms/step
# Epoch 15/100
# 27/27 - 0s - loss: 0.5361 - accuracy: 0.7361 - val_loss: 0.5572 - val_accuracy: 0.7083 - 112ms/epoch - 4ms/step
# Epoch 16/100
# 27/27 - 0s - loss: 0.5447 - accuracy: 0.7338 - val_loss: 0.5530 - val_accuracy: 0.7292 - 124ms/epoch - 5ms/step
# Epoch 17/100
# 27/27 - 0s - loss: 0.5477 - accuracy: 0.7153 - val_loss: 0.5489 - val_accuracy: 0.7292 - 104ms/epoch - 4ms/step
# Epoch 18/100
# 27/27 - 0s - loss: 0.5410 - accuracy: 0.7477 - val_loss: 0.5463 - val_accuracy: 0.7292 - 87ms/epoch - 3ms/step
# Epoch 19/100
# 27/27 - 0s - loss: 0.5310 - accuracy: 0.7384 - val_loss: 0.5459 - val_accuracy: 0.7083 - 94ms/epoch - 3ms/step
# Epoch 20/100
# 27/27 - 0s - loss: 0.5408 - accuracy: 0.7361 - val_loss: 0.5445 - val_accuracy: 0.7500 - 113ms/epoch - 4ms/step
# Epoch 21/100
# 27/27 - 0s - loss: 0.5341 - accuracy: 0.7338 - val_loss: 0.5438 - val_accuracy: 0.7083 - 135ms/epoch - 5ms/step
# Epoch 22/100
# 27/27 - 0s - loss: 0.5093 - accuracy: 0.7523 - val_loss: 0.5426 - val_accuracy: 0.7708 - 100ms/epoch - 4ms/step
# Epoch 23/100
# 27/27 - 0s - loss: 0.5239 - accuracy: 0.7593 - val_loss: 0.5419 - val_accuracy: 0.7708 - 110ms/epoch - 4ms/step
# Epoch 24/100
# 27/27 - 0s - loss: 0.5101 - accuracy: 0.7593 - val_loss: 0.5371 - val_accuracy: 0.7708 - 107ms/epoch - 4ms/step
# Epoch 25/100
# 27/27 - 0s - loss: 0.5249 - accuracy: 0.7199 - val_loss: 0.5348 - val_accuracy: 0.7083 - 89ms/epoch - 3ms/step
# Epoch 26/100
# 27/27 - 0s - loss: 0.5055 - accuracy: 0.7407 - val_loss: 0.5319 - val_accuracy: 0.7083 - 76ms/epoch - 3ms/step
# Epoch 27/100
# 27/27 - 0s - loss: 0.5130 - accuracy: 0.7477 - val_loss: 0.5329 - val_accuracy: 0.7083 - 105ms/epoch - 4ms/step
# Epoch 28/100
# 27/27 - 0s - loss: 0.5096 - accuracy: 0.7685 - val_loss: 0.5336 - val_accuracy: 0.7500 - 108ms/epoch - 4ms/step
# Epoch 29/100
# 27/27 - 0s - loss: 0.5236 - accuracy: 0.7245 - val_loss: 0.5327 - val_accuracy: 0.7083 - 134ms/epoch - 5ms/step
# Epoch 30/100
# 27/27 - 0s - loss: 0.5147 - accuracy: 0.7361 - val_loss: 0.5346 - val_accuracy: 0.7083 - 135ms/epoch - 5ms/step
# Epoch 31/100
# 27/27 - 0s - loss: 0.5036 - accuracy: 0.7593 - val_loss: 0.5384 - val_accuracy: 0.7292 - 119ms/epoch - 4ms/step
# Epoch 32/100
# 27/27 - 0s - loss: 0.5189 - accuracy: 0.7477 - val_loss: 0.5337 - val_accuracy: 0.7500 - 117ms/epoch - 4ms/step
# Epoch 33/100
# 27/27 - 0s - loss: 0.5082 - accuracy: 0.7523 - val_loss: 0.5302 - val_accuracy: 0.7292 - 99ms/epoch - 4ms/step
# Epoch 34/100
# 27/27 - 0s - loss: 0.5044 - accuracy: 0.7569 - val_loss: 0.5297 - val_accuracy: 0.7292 - 112ms/epoch - 4ms/step
# Epoch 35/100
# 27/27 - 0s - loss: 0.5004 - accuracy: 0.7662 - val_loss: 0.5322 - val_accuracy: 0.7292 - 158ms/epoch - 6ms/step
# Epoch 36/100
# 27/27 - 0s - loss: 0.4937 - accuracy: 0.7639 - val_loss: 0.5436 - val_accuracy: 0.7500 - 158ms/epoch - 6ms/step
# Epoch 37/100
# 27/27 - 0s - loss: 0.5009 - accuracy: 0.7500 - val_loss: 0.5295 - val_accuracy: 0.7292 - 151ms/epoch - 6ms/step
# Epoch 38/100
# 27/27 - 0s - loss: 0.5013 - accuracy: 0.7685 - val_loss: 0.5344 - val_accuracy: 0.7292 - 102ms/epoch - 4ms/step
# Epoch 39/100
# 27/27 - 0s - loss: 0.4738 - accuracy: 0.7847 - val_loss: 0.5312 - val_accuracy: 0.7292 - 121ms/epoch - 4ms/step
# Epoch 40/100
# 27/27 - 0s - loss: 0.5068 - accuracy: 0.7824 - val_loss: 0.5276 - val_accuracy: 0.7292 - 149ms/epoch - 6ms/step
# Epoch 41/100
# 27/27 - 0s - loss: 0.4937 - accuracy: 0.7454 - val_loss: 0.5355 - val_accuracy: 0.7292 - 96ms/epoch - 4ms/step
# Epoch 42/100
# 27/27 - 0s - loss: 0.4904 - accuracy: 0.7708 - val_loss: 0.5312 - val_accuracy: 0.7500 - 129ms/epoch - 5ms/step
# Epoch 43/100
# 27/27 - 0s - loss: 0.4978 - accuracy: 0.7523 - val_loss: 0.5285 - val_accuracy: 0.7500 - 100ms/epoch - 4ms/step
# Epoch 44/100
# 27/27 - 0s - loss: 0.4889 - accuracy: 0.7639 - val_loss: 0.5391 - val_accuracy: 0.7708 - 78ms/epoch - 3ms/step
# Epoch 45/100
# 27/27 - 0s - loss: 0.4906 - accuracy: 0.7569 - val_loss: 0.5330 - val_accuracy: 0.7500 - 102ms/epoch - 4ms/step
# Epoch 46/100
# 27/27 - 0s - loss: 0.4934 - accuracy: 0.7569 - val_loss: 0.5271 - val_accuracy: 0.7500 - 129ms/epoch - 5ms/step
# Epoch 47/100
# 27/27 - 0s - loss: 0.4810 - accuracy: 0.7731 - val_loss: 0.5336 - val_accuracy: 0.7500 - 122ms/epoch - 5ms/step
# Epoch 48/100
# 27/27 - 0s - loss: 0.4925 - accuracy: 0.7662 - val_loss: 0.5312 - val_accuracy: 0.7500 - 85ms/epoch - 3ms/step
# Epoch 49/100
# 27/27 - 0s - loss: 0.4986 - accuracy: 0.7616 - val_loss: 0.5279 - val_accuracy: 0.7292 - 69ms/epoch - 3ms/step
# Epoch 50/100
# 27/27 - 0s - loss: 0.5034 - accuracy: 0.7546 - val_loss: 0.5271 - val_accuracy: 0.7292 - 71ms/epoch - 3ms/step
# Epoch 51/100
# 27/27 - 0s - loss: 0.4852 - accuracy: 0.7662 - val_loss: 0.5389 - val_accuracy: 0.7708 - 120ms/epoch - 4ms/step
# Epoch 52/100
# 27/27 - 0s - loss: 0.4872 - accuracy: 0.7523 - val_loss: 0.5270 - val_accuracy: 0.7500 - 100ms/epoch - 4ms/step
# Epoch 53/100
# 27/27 - 0s - loss: 0.4827 - accuracy: 0.7639 - val_loss: 0.5273 - val_accuracy: 0.7292 - 119ms/epoch - 4ms/step
# Epoch 54/100
# 27/27 - 0s - loss: 0.4956 - accuracy: 0.7731 - val_loss: 0.5254 - val_accuracy: 0.7917 - 124ms/epoch - 5ms/step
# Epoch 55/100
# 27/27 - 0s - loss: 0.4755 - accuracy: 0.7593 - val_loss: 0.5282 - val_accuracy: 0.7708 - 83ms/epoch - 3ms/step
# Epoch 56/100
# 27/27 - 0s - loss: 0.4890 - accuracy: 0.7616 - val_loss: 0.5362 - val_accuracy: 0.7500 - 84ms/epoch - 3ms/step
# Epoch 57/100
# 27/27 - 0s - loss: 0.4747 - accuracy: 0.7824 - val_loss: 0.5265 - val_accuracy: 0.7500 - 110ms/epoch - 4ms/step
# Epoch 58/100
# 27/27 - 0s - loss: 0.4822 - accuracy: 0.7731 - val_loss: 0.5247 - val_accuracy: 0.7708 - 87ms/epoch - 3ms/step
# Epoch 59/100
# 27/27 - 0s - loss: 0.4816 - accuracy: 0.7986 - val_loss: 0.5252 - val_accuracy: 0.7708 - 78ms/epoch - 3ms/step
# Epoch 60/100
# 27/27 - 0s - loss: 0.4807 - accuracy: 0.7870 - val_loss: 0.5259 - val_accuracy: 0.7708 - 100ms/epoch - 4ms/step
# Epoch 61/100
# 27/27 - 0s - loss: 0.4860 - accuracy: 0.7569 - val_loss: 0.5249 - val_accuracy: 0.7708 - 130ms/epoch - 5ms/step
# Epoch 62/100
# 27/27 - 0s - loss: 0.4819 - accuracy: 0.7731 - val_loss: 0.5297 - val_accuracy: 0.7500 - 120ms/epoch - 4ms/step
# Epoch 63/100
# 27/27 - 0s - loss: 0.4666 - accuracy: 0.7917 - val_loss: 0.5239 - val_accuracy: 0.7500 - 76ms/epoch - 3ms/step
# Epoch 64/100
# 27/27 - 0s - loss: 0.4671 - accuracy: 0.7731 - val_loss: 0.5235 - val_accuracy: 0.7917 - 86ms/epoch - 3ms/step
# Epoch 65/100
# 27/27 - 0s - loss: 0.4774 - accuracy: 0.7685 - val_loss: 0.5244 - val_accuracy: 0.7708 - 125ms/epoch - 5ms/step
# Epoch 66/100
# 27/27 - 0s - loss: 0.4688 - accuracy: 0.7801 - val_loss: 0.5313 - val_accuracy: 0.7292 - 128ms/epoch - 5ms/step
# Epoch 67/100
# 27/27 - 0s - loss: 0.4817 - accuracy: 0.7801 - val_loss: 0.5327 - val_accuracy: 0.7292 - 110ms/epoch - 4ms/step
# Epoch 68/100
# 27/27 - 0s - loss: 0.4738 - accuracy: 0.7662 - val_loss: 0.5235 - val_accuracy: 0.7917 - 84ms/epoch - 3ms/step
# Epoch 69/100
# 27/27 - 0s - loss: 0.4879 - accuracy: 0.7778 - val_loss: 0.5365 - val_accuracy: 0.7292 - 77ms/epoch - 3ms/step
# Epoch 70/100
# 27/27 - 0s - loss: 0.4772 - accuracy: 0.7685 - val_loss: 0.5361 - val_accuracy: 0.7500 - 80ms/epoch - 3ms/step
# Epoch 71/100
# 27/27 - 0s - loss: 0.4788 - accuracy: 0.7755 - val_loss: 0.5358 - val_accuracy: 0.7917 - 118ms/epoch - 4ms/step
# Epoch 72/100
# 27/27 - 0s - loss: 0.4788 - accuracy: 0.7778 - val_loss: 0.5321 - val_accuracy: 0.7917 - 104ms/epoch - 4ms/step
# Epoch 73/100
# 27/27 - 0s - loss: 0.4671 - accuracy: 0.7731 - val_loss: 0.5306 - val_accuracy: 0.7917 - 122ms/epoch - 5ms/step
# Epoch 74/100
# 27/27 - 0s - loss: 0.4545 - accuracy: 0.7778 - val_loss: 0.5356 - val_accuracy: 0.7708 - 98ms/epoch - 4ms/step
# Epoch 75/100
# 27/27 - 0s - loss: 0.4634 - accuracy: 0.7870 - val_loss: 0.5399 - val_accuracy: 0.7292 - 108ms/epoch - 4ms/step
# Epoch 76/100
# 27/27 - 0s - loss: 0.4903 - accuracy: 0.7708 - val_loss: 0.5345 - val_accuracy: 0.7708 - 99ms/epoch - 4ms/step
# Epoch 77/100
# 27/27 - 0s - loss: 0.4692 - accuracy: 0.7801 - val_loss: 0.5356 - val_accuracy: 0.7708 - 97ms/epoch - 4ms/step
# Epoch 78/100
# 27/27 - 0s - loss: 0.4675 - accuracy: 0.7755 - val_loss: 0.5233 - val_accuracy: 0.8125 - 117ms/epoch - 4ms/step
# Epoch 79/100
# 27/27 - 0s - loss: 0.4644 - accuracy: 0.7708 - val_loss: 0.5352 - val_accuracy: 0.7500 - 97ms/epoch - 4ms/step
# Epoch 80/100
# 27/27 - 0s - loss: 0.4710 - accuracy: 0.7662 - val_loss: 0.5347 - val_accuracy: 0.7500 - 121ms/epoch - 4ms/step
# Epoch 81/100
# 27/27 - 0s - loss: 0.4600 - accuracy: 0.7870 - val_loss: 0.5326 - val_accuracy: 0.7708 - 91ms/epoch - 3ms/step
# Epoch 82/100
# 27/27 - 0s - loss: 0.4672 - accuracy: 0.7685 - val_loss: 0.5398 - val_accuracy: 0.7917 - 107ms/epoch - 4ms/step
# Epoch 83/100
# 27/27 - 0s - loss: 0.4632 - accuracy: 0.7870 - val_loss: 0.5429 - val_accuracy: 0.7500 - 209ms/epoch - 8ms/step
# Epoch 84/100
# 27/27 - 0s - loss: 0.4567 - accuracy: 0.7940 - val_loss: 0.5331 - val_accuracy: 0.7917 - 92ms/epoch - 3ms/step
# Epoch 85/100
# 27/27 - 0s - loss: 0.4671 - accuracy: 0.8032 - val_loss: 0.5257 - val_accuracy: 0.7917 - 117ms/epoch - 4ms/step
# Epoch 86/100
# 27/27 - 0s - loss: 0.4716 - accuracy: 0.7870 - val_loss: 0.5322 - val_accuracy: 0.7917 - 93ms/epoch - 3ms/step
# Epoch 87/100
# 27/27 - 0s - loss: 0.4627 - accuracy: 0.7940 - val_loss: 0.5380 - val_accuracy: 0.7917 - 111ms/epoch - 4ms/step
# Epoch 88/100
# 27/27 - 0s - loss: 0.4658 - accuracy: 0.7847 - val_loss: 0.5398 - val_accuracy: 0.7917 - 135ms/epoch - 5ms/step
# Epoch 89/100
# 27/27 - 0s - loss: 0.4624 - accuracy: 0.7801 - val_loss: 0.5388 - val_accuracy: 0.7500 - 137ms/epoch - 5ms/step
# Epoch 90/100
# 27/27 - 0s - loss: 0.4593 - accuracy: 0.7801 - val_loss: 0.5316 - val_accuracy: 0.7917 - 109ms/epoch - 4ms/step
# Epoch 91/100
# 27/27 - 0s - loss: 0.4614 - accuracy: 0.7894 - val_loss: 0.5303 - val_accuracy: 0.7917 - 113ms/epoch - 4ms/step
# Epoch 92/100
# 27/27 - 0s - loss: 0.4622 - accuracy: 0.7824 - val_loss: 0.5268 - val_accuracy: 0.7917 - 82ms/epoch - 3ms/step
# Epoch 93/100
# 27/27 - 0s - loss: 0.4554 - accuracy: 0.7963 - val_loss: 0.5397 - val_accuracy: 0.7500 - 90ms/epoch - 3ms/step
# Epoch 94/100
# 27/27 - 0s - loss: 0.4636 - accuracy: 0.7755 - val_loss: 0.5423 - val_accuracy: 0.7500 - 103ms/epoch - 4ms/step
# Epoch 95/100
# 27/27 - 0s - loss: 0.4824 - accuracy: 0.7616 - val_loss: 0.5324 - val_accuracy: 0.7917 - 76ms/epoch - 3ms/step
# Epoch 96/100
# 27/27 - 0s - loss: 0.4541 - accuracy: 0.7755 - val_loss: 0.5548 - val_accuracy: 0.7292 - 101ms/epoch - 4ms/step
# Epoch 97/100
# 27/27 - 0s - loss: 0.4677 - accuracy: 0.7731 - val_loss: 0.5316 - val_accuracy: 0.7917 - 103ms/epoch - 4ms/step
# Epoch 98/100
# 27/27 - 0s - loss: 0.4686 - accuracy: 0.7894 - val_loss: 0.5408 - val_accuracy: 0.7708 - 110ms/epoch - 4ms/step
# Epoch 99/100
# 27/27 - 0s - loss: 0.4571 - accuracy: 0.7778 - val_loss: 0.5317 - val_accuracy: 0.7917 - 111ms/epoch - 4ms/step
# Epoch 100/100
# 27/27 - 0s - loss: 0.4470 - accuracy: 0.7894 - val_loss: 0.5310 - val_accuracy: 0.8125 - 79ms/epoch - 3ms/step

# %% [markdown]
# Evaluate the model

# %%
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, confusion_matrix, classification_report
)

# Predict probabilities
y_pred_prob = model.predict(X_test).ravel()

# Convert to binary output
y_pred = (y_pred_prob >= 0.5).astype(int)

# Classification report
print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))

# Confusion Matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# Predict probabilities and convert to binary
y_pred_prob = model.predict(X_test).ravel()
y_pred = (y_pred_prob >= 0.5).astype(int)

# Generate confusion matrix
cm = confusion_matrix(y_test, y_pred)
labels = ['No Diabetes', 'Diabetes']

# Plot
plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels)

plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.tight_layout()
plt.show()


# Individual metrics
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Precision:", precision_score(y_test, y_pred))
print("Recall:", recall_score(y_test, y_pred))
print("F1 Score:", f1_score(y_test, y_pred))
# Out:
# 2/2 [==============================] - 0s 5ms/step
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#            0       0.62      0.73      0.67        22
#            1       0.79      0.69      0.73        32
#
#     accuracy                           0.70        54
#    macro avg       0.70      0.71      0.70        54
# weighted avg       0.72      0.70      0.71        54
#
# 2/2 [==============================] - 0s 4ms/step
# Accuracy: 0.7037037037037037
# Precision: 0.7857142857142857
# Recall: 0.6875
# F1 Score: 0.7333333333333334

# %%
import matplotlib.pyplot as plt

# Plot training & validation accuracy
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plot training & validation loss
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
from sklearn.metrics import roc_curve, roc_auc_score

# Predict probabilities for the test set
y_pred_prob = model.predict(X_test).ravel()  # Already flattened

# Calculate ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)

# Calculate AUC score
auc_score = roc_auc_score(y_test, y_pred_prob)

# Plot ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC Curve (AUC = {auc_score:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')  # Diagonal line
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.grid(True)
plt.show()
# Out:
# 2/2 [==============================] - 0s 7ms/step
